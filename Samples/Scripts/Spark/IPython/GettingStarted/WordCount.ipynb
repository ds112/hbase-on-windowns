# %%
from pyspark import SparkContext

# Read the input file
text_file = sc.textFile("/Data/WarPeace.txt")

# Splits each word by space and collect the words using flatMap function
# Creates the Key-Value pair with each word as the key and the integer 1 as the value using map function
# Reduces the Key-Value pair with each word as the key and the corresponding word count as the value using reduceByKey function
counts = text_file.flatMap(lambda line: line.split(" ")).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)

# Saves the created Key-Value pair in text file
counts.saveAsTextFile("/Data/Output/WordCountPython")
for count in counts.collect():
    print(count)
# Out:
# (u'', 13598)
# (u'instinctive,', 1)
# (u'interpreter.', 2)
# (u'shouted,', 31)
# (u'Virgin.', 1)
# (u'shouted.', 17)
# (u'Hill,', 1)
# (u'yellow', 11)
# (u'four', 85)
# (u'young...."', 1)
# (u'S--', 2)
# (u'"Fool,', 1)
# (u'proposes,', 1)
# (u'verses', 14)
# (u'"Surrounded!', 1)
# (u'better!', 2)
# (u'shouted:', 4)
# (u'booths.', 1)
# (u'treading', 5)
# (u'Mecklenburgers,', 1)
# (u'Mary--who', 1)
# (u'pardon', 4)
# (u'inheritance.', 2)
# (u'battalions,', 4)
# (u'rupture', 7)
# (u'battalions.', 3)
# (u'Moscow)', 2)
# (u'scold', 3)
# (u'propounded', 1)
# (u'"uncle";', 1)
# (u'gruel', 1)
# (u'tabletop.', 1)
# (u'Elder!...', 1)
# (u"diplomat's", 1)
# (u'dance?', 1)
# (u'war!"', 1)
# (u'wuined', 1)
# (u'Cases', 1)
# (u'write,"', 1)
# (u'polite,', 1)
# (u'recollection.', 6)
# (u'drunkenness,', 1)
# (u'sinking', 16)
# (u'shielding', 1)
# (u'rational', 2)
# (u'appeals,', 1)
# (u"Magnitski's", 1)
# (u'trumpeters,', 1)
# (u'Nizhni', 5)
# (u'levy', 2)
# (u'wood,', 14)
# (u'bile', 2)
# (u'wood.', 15)
# (u'friends--come', 1)
# (u'whispered)', 1)
# (u'"Dearest,"', 1)
# (u'tantalizing', 1)
# (u'foul', 3)
# (u'utilized', 2)
# (u'fingers.', 12)
# (u'Old', 22)
# (u'fingers,', 10)
# (u'bringing', 23)
# (u'ruinous', 4)
# (u'writing.', 6)
# (u'devil...', 1)
# (u'identity', 2)
# (u'stiffness', 1)
# (u'wooded', 6)
# (u'coverlet', 1)
# (u'uttering', 17)
# (u'grains', 1)
# (u'wooden', 15)
# (u'see..."', 5)
# (u'ladies--frightening', 1)
# (u'halfway.', 3)
# (u'this..."', 6)
# (u'Feel', 2)
# (u'persisted', 2)
# (u"Nothing's", 1)
# (u'sacks', 2)
# (u'men?...', 1)
# (u'feigned.', 1)
# (u'this....', 1)
# (u'straight', 93)
# (u"'dog,'", 1)
# (u'charter', 1)
# (u'affright,', 1)
# (u'admitted?', 1)
# (u"friend's", 17)
# (u'ate,', 1)
# (u'quicker!"', 1)
# (u'her!', 8)
# (u'27,', 1)
# (u'motions', 1)
# (u'pulse', 2)
# (u'continued--', 1)
# (u'Annette', 2)
# (u'atom.', 1)
# (u'race.', 4)
# (u'said--met', 1)
# (u'candles,', 4)
# (u'valiant', 4)
# (u'intellect.', 1)
# (u'END', 1)
# (u'Feoktist,', 1)
# (u'loathing', 2)
# (u'"Natalya', 2)
# (u'mistake!"', 1)
# (u'abundantly', 1)
# (u'rug-covered', 1)
# (u'woman?"', 1)
# (u'commissions.', 1)
# (u'merveille.*(2)', 1)
# (u'apartments?"', 1)
# (u'nature,', 8)
# (u'nature.', 4)
# (u"'You", 2)
# (u'contributed', 2)
# (u'him--yet', 1)
# (u"madman's", 1)
# (u'unfair.', 2)
# (u'boy!...', 1)
# (u'"Peace', 1)
# (u'understood,', 6)
# (u'home!...', 1)
# (u'pawed', 1)
# (u'carp', 1)
# (u'exclamations', 3)
# (u'staggering,', 1)
# (u'grace.', 2)
# (u'deceased,"', 1)
# (u'crouch', 1)
# (u'wings.', 1)
# (u'bay.', 1)
# (u'Apsheron', 4)
# (u'interrupt', 5)
# (u'Amuse', 1)
# (u'dahe', 1)
# (u'swoon.', 1)
# (u'unseemly', 4)
# (u'people?"', 1)
# (u'Brother.', 1)
# (u"Bezukhova's", 6)
# (u'glass.', 15)
# (u'glass,', 11)
# (u'hers', 15)
# (u'Voronezh.', 5)
# (u'shriek', 1)
# (u'fret.', 1)
# (u'radiating', 1)
# (u'natured', 3)
# (u'shock.', 2)
# (u'Salzeneck,', 1)
# (u'granting', 1)
# (u'Salzeneck.', 1)
# (u"Zdrzhinski's", 3)
# (u'Miss', 1)
# (u'elaborate', 1)
# (u'"why', 2)
# (u'unfriendly', 2)
# (u'reports', 40)
# (u'hit--a', 1)
# (u'courteous,"', 1)
# (u'electricity', 1)
# (u'finger,', 8)
# (u'stallions', 1)
# (u'powdering', 1)
# (u'Bourienne--I', 1)
# (u'Sokolniki', 4)
# (u'DAMAGE.', 1)
# (u'Annette,"', 1)
# (u'sugar,', 2)
# (u'"who', 1)
# (u'furnish', 3)
# (u'course...', 2)
# (u'criticism', 5)
# (u'crotchety!', 1)
# (u'schoolboy,', 1)
# (u'positions,', 3)
# (u'Recalling', 2)
# (u'astronomy.', 1)
# (u'Campan', 4)
# (u'enthusiasm--news', 1)
# (u'equality,"', 1)
# (u'ankle-deep', 1)
# (u'remnant', 2)
# (u'resulted--moment', 1)
# (u'precision!"', 1)
# (u'anywhere.', 5)
# (u'Frise', 1)
# (u'Ivanovich,"', 1)
# (u'impossible--in', 1)
# (u'him--who', 1)
# (u'fire;', 1)
# (u'unit', 3)
# (u'frustrated', 1)
# (u'fame.', 1)
# (u'presents', 18)
# (u'force."', 1)
# (u'saffron-', 1)
# (u'"forgive', 1)
# (u"pupil's,", 1)
# (u'dispatches', 2)
# (u'Chekmar', 1)
# (u'Czartoryski....', 1)
# (u'leading,', 1)
# (u'occupying', 10)
# (u'Bismarck', 1)
# (u'fly.\'"', 1)
# (u'music', 27)
# (u'fire?', 1)
# (u'footman.', 3)
# (u'strike', 8)
# (u'up:', 3)
# (u'Alpatych;', 1)
# (u'venal.', 1)
# (u'waist,', 3)
# (u'missis,"', 1)
# (u'attendre.', 1)
# (u'higher,', 4)
# (u'peace...', 1)
# (u'Nonsense!"', 1)
# (u'paperwork', 1)
# (u'relay', 4)
# (u'successful', 6)
# (u'diaphanous', 1)
# (u'Konigsberg.', 1)
# (u'whirling', 3)
# (u'outskirts,', 1)
# (u'canonized', 1)
# (u'Never!"', 1)
# (u'still-deeper', 1)
# (u'pardon?', 1)
# (u'"Yes!"', 1)
# (u'sad!"', 2)
# (u'Thuerassa,', 1)
# (u'stumps', 1)
# (u'asile.', 1)
# (u'trunks,', 2)
# (u'shakos,', 4)
# (u'sorry', 60)
# (u'mirth,', 1)
# (u'desk,', 2)
# (u'madam!"', 2)
# (u'since.', 2)
# (u'locked', 7)
# (u'trunks.', 1)
# (u'Napoleon."', 1)
# (u'pursue', 5)
# (u'famed', 1)
# (u'plunged', 10)
# (u'desk.', 1)
# (u'laughter;', 1)
# (u'Assumption--it', 1)
# (u'excellency..."', 1)
# (u'pound--who', 1)
# (u'Rostov!"', 1)
# (u'"That\'ll', 2)
# (u'stooped,', 1)
# (u'identical', 3)
# (u'victim,"', 1)
# (u'misfortunes', 11)
# (u'Emperor--he', 1)
# (u'Napoleon)', 1)
# (u'anyhow."', 2)
# (u'triple', 2)
# (u'Russian--but', 1)
# (u'reported.', 2)
# (u'household', 30)
# (u'everything...."', 1)
# (u'ungraceful', 1)
# (u'BUT', 1)
# (u'Napoleon;', 2)
# (u'stoves', 1)
# (u'malign', 1)
# (u'Napoleon?', 1)
# (u'kingdoms', 1)
# (u'want', 211)
# (u'ha!"', 4)
# (u'Sonya--should', 1)
# (u'organizer', 1)
# (u'happened:', 1)
# (u'statistics,', 1)
# (u'happiness--ever', 1)
# (u'Denisov!"', 2)
# (u'around.', 15)
# (u'superseded', 2)
# (u'around,', 13)
# (u"aime'", 1)
# (u'stifling', 2)
# (u'complaining', 2)
# (u'good-natured,', 7)
# (u'travel', 7)
# (u'gosling', 1)
# (u'thundercloud,', 1)
# (u'machine', 9)
# (u'hot', 32)
# (u'win.', 3)
# (u'reviewed,', 1)
# (u'win,', 1)
# (u'listless,', 1)
# (u'it"--and', 1)
# (u'blue-black', 1)
# (u'cher?', 1)
# (u'preferable', 1)
# (u'void', 1)
# (u'cher;', 1)
# (u'wish--to', 1)
# (u'renounced', 4)
# (u'uselessness', 2)
# (u'replying;', 1)
# (u'beauty', 34)
# (u'grenadiers', 4)
# (u'capitals,', 1)
# (u'forward;', 1)
# (u'Russen!', 1)
# (u'dragon,', 1)
# (u'cold."', 1)
# (u'wrong', 36)
# (u'scornfully.', 2)
# (u'"King', 1)
# (u'destined', 5)
# (u'pondered,', 4)
# (u'Council?', 1)
# (u'pondered.', 5)
# (u'crooking', 2)
# (u'reproachfully,', 2)
# (u'types', 2)
# (u'chere', 4)
# (u'attentive,', 2)
# (u'persuasiveness', 1)
# (u'calves', 1)
# (u'houses--in', 1)
# (u'effective', 1)
# (u'called),', 1)
# (u'attracts', 2)
# (u'powder,', 3)
# (u'Only,"', 1)
# (u'sickening', 2)
# (u'fetching', 3)
# (u'directing;', 1)
# (u'Another', 35)
# (u'1.A.', 1)
# (u'rearguard', 8)
# (u'"To', 59)
# (u'l\'Empereur."', 1)
# (u"'Uncle's'", 1)
# (u'playfulness,', 1)
# (u'wind', 22)
# (u'man--that', 1)
# (u'departed.', 2)
# (u'Even', 28)
# (u'enlightenment.', 1)
# (u'fine."', 1)
# (u'laughter-loving,', 1)
# (u'effect.', 5)
# (u'mere"', 1)
# (u'concurrence', 2)
# (u'administered.', 1)
# (u"m'a", 1)
# (u'ministers!"', 1)
# (u'fowls', 1)
# (u'advice;', 1)
# (u'reaction.', 2)
# (u'marshy', 1)
# (u'Voltaire', 3)
# (u'"Give', 13)
# (u'fetched', 5)
# (u'Smolensk', 63)
# (u'effect:', 1)
# (u'voit', 1)
# (u'fir', 4)
# (u'shorter', 2)
# (u'Drubetskaya', 4)
# (u'lovingly', 1)
# (u'merrier,', 1)
# (u'fit', 27)
# (u'wide-open,', 1)
# (u'screaming', 5)
# (u'fix', 10)
# (u'closed;', 2)
# (u'discourse', 1)
# (u'ready?', 2)
# (u'ready!', 1)
# (u'rescued', 6)
# (u'silent!"', 1)
# (u'Viens', 1)
# (u'approve', 9)
# (u'accentuating', 2)
# (u'success--a', 1)
# (u'hidden', 20)
# (u'admirable', 6)
# (u'equals,', 2)
# (u'represent,', 1)
# (u'general!"', 4)
# (u'"Mummy!...', 1)
# (u'welcome.', 1)
# (u'grievous', 1)
# (u'copying', 5)
# (u'Vilna--his', 1)
# (u'strings.', 1)
# (u'aware).', 1)
# (u'strings,', 3)
# (u'disturb', 6)
# (u'gambols', 1)
# (u'perplexity?', 1)
# (u"Wouldn't", 1)
# (u'fruschtique', 1)
# (u'Robbery', 2)
# (u'schools', 3)
# (u'Emperors--that', 1)
# (u'good?"', 1)
# (u'forgotten...."', 1)
# (u'careful,', 2)
# (u'Sonya--who', 1)
# (u'fancies!', 1)
# (u'acme', 2)
# (u'girls--', 1)
# (u'houses--it', 1)
# (u'anticipation,', 1)
# (u'soaring', 1)
# (u'grief', 18)
# (u'seven;', 1)
# (u'auditor,', 1)
# (u'Vistula.', 1)
# (u'Emperor!"', 6)
# (u'intimidate', 1)
# (u'arrow', 1)
# (u"'All", 1)
# (u'retainers', 1)
# (u'uninfluenced', 1)
# (u'object,', 3)
# (u'well-set-up', 1)
# (u'someday...', 1)
# (u'blushed', 35)
# (u'expectancy', 1)
# (u'Malvintseva,', 1)
# (u'intended,', 2)
# (u'dark-faced', 2)
# (u'brain,', 4)
# (u'woes', 1)
# (u'correct.', 8)
# (u'porch,', 14)
# (u'correct,', 4)
# (u'Malvintseva.', 1)
# (u'cushion', 3)
# (u'temper.', 6)
# (u'reassured,', 1)
# (u'Khamovniki,', 1)
# (u'porch.', 35)
# (u'fortnight', 12)
# (u'displeased', 14)
# (u'allay', 2)
# (u'Crowds', 5)
# (u'temper,', 4)
# (u'distinguee,', 1)
# (u'Empewah?', 1)
# (u'self-', 16)
# (u'winter),', 1)
# (u'pleasing.', 1)
# (u'prescribed,', 1)
# (u'"Kuzmich...', 1)
# (u"Bonaparte's,", 1)
# (u'XXXV', 2)
# (u'borzoi,', 4)
# (u'convenience', 1)
# (u'borzoi.', 2)
# (u'Elder,', 4)
# (u'spot;', 1)
# (u'encourage', 5)
# (u"Bonaparte's.", 1)
# (u'Miloradoviches.', 1)
# (u'Knyazkovo.', 1)
# (u'Prokofy,', 2)
# (u'outburst', 6)
# (u'rented', 1)
# (u'ever-living,', 1)
# (u'Word', 2)
# (u'by:', 1)
# (u'assured', 13)
# (u'generals!"', 1)
# (u'mot,', 1)
# (u'instants', 1)
# (u'threatened', 12)
# (u'surveys', 1)
# (u'Worn', 1)
# (u'fugitives.', 1)
# (u'fugitives,', 1)
# (u"won't--not", 1)
# (u'(4)', 1)
# (u'Ulm.', 3)
# (u'Trinity', 2)
# (u'revolutions,', 3)
# (u'checked', 13)
# (u'estimate', 3)
# (u'knit', 5)
# (u'Mortemart', 3)
# (u'occasionally.', 2)
# (u'blessing!"', 1)
# (u'enormous', 43)
# (u'Disgrace', 1)
# (u'district', 11)
# (u'wefused', 1)
# (u'"They\'ve', 6)
# (u'offense.', 2)
# (u'house!"', 2)
# (u'disapprovingly.', 2)
# (u'field!"', 1)
# (u'disapprovingly,', 1)
# (u'useful."', 2)
# (u'satisfactorily.', 1)
# (u'fruit,', 1)
# (u'Hors', 1)
# (u'Orel--where', 1)
# (u'speedy', 3)
# (u'offense,', 2)
# (u'Human', 1)
# (u'empty."', 1)
# (u'earth--to', 1)
# (u'sellers,', 1)
# (u'fruit.', 2)
# (u"women's.", 1)
# (u'(probably', 1)
# (u'assigned', 11)
# (u'angelic', 2)
# (u'can...."', 1)
# (u'meadows.', 1)
# (u'"Vereshchagin', 2)
# (u'fatherland.', 4)
# (u'Please', 12)
# (u'her)', 1)
# (u'maladies', 1)
# (u'Gutenberg"),', 1)
# (u'spinning', 2)
# (u'divisions,', 5)
# (u'doubtful,', 1)
# (u'likes.', 1)
# (u'Margaux', 1)
# (u'reward,', 2)
# (u'dormir!"', 1)
# (u'households', 2)
# (u'contingent,', 1)
# (u'barrel."', 1)
# (u'service', 54)
# (u'nickname', 3)
# (u'marry!', 1)
# (u'straps,', 2)
# (u'cooling', 1)
# (u'meadows...', 1)
# (u'"ulyulyu!"', 1)
# (u'lisping.', 1)
# (u'master', 34)
# (u'event!"', 1)
# (u'soundly.', 1)
# (u'times!"', 2)
# (u'sure,', 3)
# (u'cordially', 4)
# (u'hay,', 5)
# (u'falling?', 1)
# (u'mists,', 1)
# (u'was;', 1)
# (u'ganze', 2)
# (u'pillaging--', 1)
# (u'was?', 1)
# (u'children--that', 1)
# (u'cushions', 3)
# (u'sewing,', 1)
# (u'landowners,', 1)
# (u'frowned', 20)
# (u'expend', 1)
# (u'Semenovna,', 1)
# (u'Andrew?"', 5)
# (u'equitable,', 1)
# (u'was!', 2)
# (u'sulphur', 1)
# (u'crawl', 3)
# (u'Naples!"', 1)
# (u'positively', 6)
# (u'Beautiful', 1)
# (u'her;', 13)
# (u'look!"', 4)
# (u'mining', 1)
# (u'leg,', 10)
# (u'lozenge,', 1)
# (u'leg.', 8)
# (u'(everything', 1)
# (u'old;', 1)
# (u'Nikulins\'!"', 1)
# (u'tree', 17)
# (u'second', 99)
# (u'nowadays--but', 1)
# (u'"author!', 1)
# (u'project', 9)
# (u'So-and-so', 2)
# (u'"L\'Urope', 1)
# (u'her?', 11)
# (u'tres', 4)
# (u'doubts.', 1)
# (u'old-', 1)
# (u'colonel!"', 1)
# (u'life--the', 1)
# (u'intoxicated.', 1)
# (u'well?', 4)
# (u'well;', 2)
# (u'nation--should', 1)
# (u'semicouncil', 1)
# (u'shyly', 8)
# (u'keeper', 2)
# (u'larks', 2)
# (u'colonel).', 1)
# (u'well-', 4)
# (u"'Fire!'", 1)
# (u'joins', 2)
# (u'else,', 27)
# (u'difference,', 4)
# (u'meekness,', 2)
# (u'thaw', 1)
# (u"huntsman's", 2)
# (u'well!', 1)
# (u'exacting.', 1)
# (u'heads;', 1)
# (u'Presnya,', 1)
# (u'"You,', 4)
# (u'morrow', 2)
# (u'Negro,"', 2)
# (u'Moskva,', 1)
# (u'courier', 20)
# (u'What?', 6)
# (u'Thee', 3)
# (u'drunk,', 5)
# (u"masters'", 1)
# (u'affirmative.', 2)
# (u'"Liar,', 1)
# (u'recommended', 7)
# (u'absorbed', 32)
# (u'quill', 3)
# (u'They', 357)
# (u'willing,', 2)
# (u'flags', 3)
# (u'willing.', 2)
# (u'romance,"', 1)
# (u'ambuscade', 1)
# (u'yours!"', 1)
# (u'disdainfully', 2)
# (u'even', 466)
# (u'links', 4)
# (u'feverishly.', 1)
# (u'feverishly,', 1)
# (u'thrilled', 1)
# (u'screwing', 10)
# (u'mystery....', 1)
# (u'diminishing', 1)
# (u'seemed.', 1)
# (u'looming', 1)
# (u"aunt's", 2)
# (u'toil', 5)
# (u'fees.', 1)
# (u'mouth', 44)
# (u'bees.', 2)
# (u'reverence', 1)
# (u'manly-', 1)
# (u'Bucharest--', 1)
# (u'drought', 1)
# (u'difficulties,', 1)
# (u'difficulties.', 3)
# (u'insignificance--particularly', 1)
# (u'expound', 2)
# (u'hut', 33)
# (u'singer', 2)
# (u'episode', 6)
# (u'commissions,', 1)
# (u'Mere,', 1)
# (u'affair:', 1)
# (u'oft-repeated', 1)
# (u"d'azur--maison", 1)
# (u'explode', 1)
# (u'retreated,', 3)
# (u'Bezubova', 1)
# (u'retreated.', 2)
# (u'mash,', 1)
# (u'singed', 1)
# (u'unchanged', 3)
# (u'another,"', 5)
# (u'often...', 1)
# (u'verses?', 1)
# (u'observations,', 1)
# (u'affair.', 8)
# (u'practicing?', 1)
# (u"L'amour", 1)
# (u'Nominally', 1)
# (u'Class.', 1)
# (u'Napoleon,"', 1)
# (u'prim', 1)
# (u'transfers,', 1)
# (u'Commentaries),', 1)
# (u'insects', 1)
# (u'orchestra', 6)
# (u'oaths', 1)
# (u'Volga,"', 1)
# (u'Preussisch-Eylau', 2)
# (u'echoing', 1)
# (u'fifty-year-old', 2)
# (u'padded', 2)
# (u'occupation,', 5)
# (u'cannot,', 7)
# (u'Louise--who', 1)
# (u'necks.', 1)
# (u'tempted', 1)
# (u'"Non,', 2)
# (u'mellow', 1)
# (u'occupation.', 4)
# (u'sewn.', 1)
# (u'Rostova?"', 1)
# (u'lessons', 8)
# (u'fun,"', 1)
# (u'touches', 1)
# (u'clicked', 3)
# (u'springs.', 1)
# (u'vexations', 1)
# (u'quaint', 1)
# (u'first-rate,', 2)
# (u'exultation,', 1)
# (u"baby's", 6)
# (u'ceased,', 9)
# (u'"Why\'s', 1)
# (u'Who?"', 3)
# (u'bliss', 4)
# (u'in--his', 1)
# (u'rich', 34)
# (u'heartily', 4)
# (u'understood.', 8)
# (u'them--and', 2)
# (u'"J\'ai', 1)
# (u'self-derision,', 1)
# (u'angrier,', 1)
# (u'arrangements.)', 1)
# (u'beaten?"', 2)
# (u'spheres.', 2)
# (u'reverently', 1)
# (u'lady,"', 1)
# (u'matter.', 20)
# (u'undivided,', 1)
# (u'"Les', 1)
# (u'pocket', 16)
# (u'vileness,', 3)
# (u'"Defects,"', 1)
# (u'lies.', 2)
# (u'matter,', 20)
# (u'kittenish', 1)
# (u'listened;', 1)
# (u"French!'", 1)
# (u'taunted', 1)
# (u'darling!..."', 1)
# (u'riverside', 1)
# (u'incredible,', 1)
# (u'deny', 1)
# (u'Bourienne', 58)
# (u'noiselessly.', 1)
# (u'Pointing', 2)
# (u'them?', 8)
# (u'supple,', 1)
# (u'Andrusha,"', 1)
# (u'Chasseurs', 3)
# (u'them;', 16)
# (u'SEND', 1)
# (u'men,', 112)
# (u'earth:', 1)
# (u'eyelids', 2)
# (u'cousin.', 6)
# (u'reviving', 1)
# (u'cousin,', 8)
# (u'release', 8)
# (u'reprimanded', 3)
# (u'lesson)', 1)
# (u'wrinkles.', 1)
# (u'boarded', 1)
# (u'mentally--', 1)
# (u'them)', 6)
# (u'money?"', 2)
# (u'fait', 4)
# (u'blew', 6)
# (u'elders.', 1)
# (u'fair', 10)
# (u'smaller.', 1)
# (u'Boris!', 1)
# (u'wolfhounds,', 1)
# (u'power..."', 1)
# (u'so."', 12)
# (u"Boris'", 18)
# (u'unexpectedly', 43)
# (u'seedless', 1)
# (u'Boris;', 1)
# (u'radius', 2)
# (u'discarding', 1)
# (u'Boris?', 1)
# (u'fail', 10)
# (u'hero', 17)
# (u'Souza.', 1)
# (u'afraid?"', 2)
# (u'best', 111)
# (u'earth"', 1)
# (u'conditional,', 1)
# (u'unalterably', 1)
# (u'repugnance', 1)
# (u'lots', 1)
# (u'dishonesty', 1)
# (u"'Papa'", 1)
# (u'loquacity', 1)
# (u'estate)', 1)
# (u"close.'", 1)
# (u'bath--in', 1)
# (u'toyshop,', 1)
# (u'dudgeon,', 1)
# (u'unsaddling,', 1)
# (u'unto', 6)
# (u'unalterable', 1)
# (u'successfully,', 3)
# (u'trigger.', 1)
# (u'convalescent,', 1)
# (u'Terentich,', 2)
# (u'seriously;', 1)
# (u'extremely--whether', 1)
# (u'Here?', 1)
# (u'extend', 4)
# (u'Pierre--or', 1)
# (u'rolled', 22)
# (u'breathless--to', 1)
# (u"n'en", 1)
# (u'roofless,', 1)
# (u'espied', 3)
# (u'Hessians', 2)
# (u'(raw', 1)
# (u'extent', 8)
# (u'passengers,', 1)
# (u'petty,', 1)
# (u'are...."', 1)
# (u'thief?"', 1)
# (u'extinguish', 1)
# (u'do!"', 6)
# (u'pity', 49)
# (u'hiding.', 2)
# (u'lot?', 1)
# (u'Alliance.', 1)
# (u'Why?"', 1)
# (u'gathering', 7)
# (u'Wednesday,', 1)
# (u'soot.', 2)
# (u'grapeshot."', 2)
# (u'"Heaven', 3)
# (u"today's", 2)
# (u'"It\'ll', 1)
# (u'estates', 30)
# (u'sublime', 6)
# (u'novelty?', 1)
# (u'ambition,', 1)
# (u'china', 4)
# (u'ambition.', 1)
# (u'cases,"', 2)
# (u'adapted', 2)
# (u'admission', 3)
# (u'peu,"*(4)', 1)
# (u'Caucasus', 1)
# (u'mortified', 7)
# (u'unbuttoned', 8)
# (u'25,', 2)
# (u'doubt,', 11)
# (u'things!"', 1)
# (u'doubt.', 3)
# (u'money.', 11)
# (u'money,', 25)
# (u'smithereens', 1)
# (u'102', 2)
# (u'stinging),', 1)
# (u'put;', 1)
# (u'Mother,', 2)
# (u'humming', 4)
# (u'overclean', 1)
# (u'situated,', 2)
# (u'cooking,', 1)
# (u'd\'ordre..."', 1)
# (u'debouching', 1)
# (u'ease', 19)
# (u'self-confidence', 4)
# (u'undertaking,', 3)
# (u'restive:', 1)
# (u'hay.', 2)
# (u'union', 6)
# (u"'come", 1)
# (u'fro', 6)
# (u'Almighty,', 1)
# (u'Shapovalov,', 1)
# (u'breathlessly', 3)
# (u'first!"', 1)
# (u'apples,', 2)
# (u'chucked', 1)
# (u'Hebrew,', 1)
# (u'all--for', 1)
# (u'follow.', 5)
# (u'superhuman', 2)
# (u'foundations--has', 1)
# (u'tears,"', 1)
# (u'conversational', 1)
# (u'life', 330)
# (u'Potocka', 1)
# (u'anybody!"', 1)
# (u'crossroads,', 1)
# (u'twinkled', 1)
# (u'afterwards!"', 1)
# (u'worker', 2)
# (u'needed,', 4)
# (u'athwart', 1)
# (u'snap', 2)
# (u'held.', 5)
# (u'slap', 1)
# (u'held,', 1)
# (u'went."', 1)
# (u'talk."', 3)
# (u'worked', 11)
# (u'spin', 1)
# (u'loftiness', 2)
# (u'13th', 3)
# (u'fr!', 1)
# (u'duke--it', 1)
# (u'sitting.', 4)
# (u'contemplated', 1)
# (u'chevalier', 2)
# (u'Kirilovich,"', 2)
# (u'administrative', 4)
# (u'Beware', 1)
# (u'contingencies', 4)
# (u'inextricably', 1)
# (u'crupper', 2)
# (u'employ', 3)
# (u'Baden,', 2)
# (u'appositely', 1)
# (u'Savelich.', 1)
# (u'ignoramuses--have', 1)
# (u'broad-browed', 1)
# (u'command)', 1)
# (u'flooding', 2)
# (u'k', 1)
# (u'picturing', 6)
# (u'Buonaparte.', 2)
# (u'Buonaparte,', 3)
# (u'congratulation', 1)
# (u'enchanted.', 2)
# (u'said:', 64)
# (u'consent.', 4)
# (u'bought.', 1)
# (u'consent,', 4)
# (u'obeying', 3)
# (u'people--that', 1)
# (u"'My", 1)
# (u'honeymoons,', 1)
# (u'enchanted,', 2)
# (u'"Follow', 1)
# (u'"Grapeshot!"', 1)
# (u'"Blackguards!...', 1)
# (u'said,', 226)
# (u'corps....', 1)
# (u'desperately,', 5)
# (u'restrictions.', 1)
# (u'pressed.', 1)
# (u'damaged', 2)
# (u'Vitebsk,', 3)
# (u'it--take', 1)
# (u'natures--by', 1)
# (u'jolting', 4)
# (u'whim,', 1)
# (u'pieces.', 6)
# (u'exception;', 1)
# (u'Did', 13)
# (u'instincts', 1)
# (u'Understandable', 1)
# (u'Bezukhov', 24)
# (u'babies', 3)
# (u'1812?', 1)
# (u'mead,', 1)
# (u'door--speaking', 1)
# (u'increased.', 2)
# (u'baking', 1)
# (u'increased,', 5)
# (u'"Opinions', 1)
# (u'inadvertently', 1)
# (u'deluded,"', 1)
# (u'arrest.', 1)
# (u'nearer.', 3)
# (u'qualifications', 1)
# (u'Confederation', 1)
# (u'maddened--', 1)
# (u'Contrary', 4)
# (u'arrest,', 1)
# (u'"Excuse', 5)
# (u'learned;', 1)
# (u'slave!', 2)
# (u'confusedly', 1)
# (u"'Count", 1)
# (u'Kuzmich--From', 1)
# (u'further,', 2)
# (u'danced.', 1)
# (u'rest--but', 1)
# (u'danced,', 3)
# (u'hunt.', 2)
# (u'furlough', 3)
# (u'joking!', 1)
# (u'intrusion', 2)
# (u'wetweating.', 1)
# (u'gateway.', 2)
# (u'"become', 1)
# (u'bucket', 1)
# (u'helplessness.', 2)
# (u'watchhouse.', 1)
# (u'stillness', 10)
# (u'thing.', 13)
# (u'arbiters,"', 1)
# (u'which)', 1)
# (u'means,', 5)
# (u'feeble,', 4)
# (u'sweet.', 2)
# (u'addresses.', 1)
# (u'eyebrows', 22)
# (u'outlived', 2)
# (u'pose,', 5)
# (u'away,"', 10)
# (u'pose.', 1)
# (u'heart--watching', 1)
# (u'sleepy', 12)
# (u'age--I', 1)
# (u'"pear"', 1)
# (u'beset', 2)
# (u'laxity.', 1)
# (u'founded;', 1)
# (u'elder.', 1)
# (u'elder,', 5)
# (u'stewards,', 1)
# (u'now--Natasha', 1)
# (u'bit', 19)
# (u'education,', 8)
# (u'self-assured', 6)
# (u'awe-struck', 1)
# (u'reformers', 1)
# (u'THIRTEEN:', 2)
# (u'campaign', 57)
# (u'pas.', 1)
# (u'thinking', 102)
# (u'pistols,', 2)
# (u'Ligne', 1)
# (u'mingled,', 1)
# (u'had', 5305)
# (u'"Morning', 1)
# (u'joking,"', 3)
# (u'frost,', 5)
# (u'imitate', 2)
# (u'capitally."', 1)
# (u'obedient', 2)
# (u'tear-worn', 3)
# (u'beloved', 12)
# (u'potato,', 1)
# (u'reasons..."', 1)
# (u'musketeer', 1)
# (u'match', 17)
# (u'step;', 2)
# (u'worse.', 6)
# (u'Lord,', 12)
# (u'enchantress.', 1)
# (u'godfather,', 1)
# (u'casually', 7)
# (u'sovereign.', 6)
# (u'"shelter"', 2)
# (u'sleep?', 1)
# (u'swelling,', 1)
# (u'vehicles,', 2)
# (u'vehicles.', 2)
# (u'Boulevard,', 2)
# (u'by!"', 1)
# (u'sleep!', 1)
# (u'birth', 3)
# (u'clustered', 1)
# (u'obligingly', 1)
# (u'shadow', 10)
# (u'"Listen', 3)
# (u'Boulevard.', 1)
# (u'opinion,', 9)
# (u'desire', 63)
# (u'power."', 2)
# (u'ha,', 10)
# (u'still-higher', 1)
# (u'react', 2)
# (u"hair'?", 1)
# (u'crushing,', 1)
# (u'war,', 45)
# (u'Thursdays--today', 1)
# (u'cogs', 1)
# (u'festivities', 1)
# (u'steps', 97)
# (u'Belaya', 3)
# (u'"Karay?', 1)
# (u'worse,', 8)
# (u'assembling,', 1)
# (u'peasants.', 7)
# (u'spectacle.', 4)
# (u'bonfires', 2)
# (u'Swedish', 4)
# (u'Kirilych!"', 1)
# (u'casket,', 1)
# (u'drowned', 13)
# (u'crowd', 152)
# (u'entrenchment,', 1)
# (u'vigor', 4)
# (u'twenty-five-ruble', 1)
# (u'"These--yes,', 1)
# (u'easy', 38)
# (u'crown', 2)
# (u'begin', 52)
# (u'All', 223)
# (u'character..."', 1)
# (u'Whatever', 16)
# (u'left,', 45)
# (u'Off', 1)
# (u'left.', 18)
# (u'peasant!"', 1)
# (u'creep', 1)
# (u'aquaintances.', 1)
# (u'project,"', 1)
# (u'Abbe', 3)
# (u'reappeared.', 1)
# (u'soirees.', 2)
# (u'for', 3270)
# (u'forever."', 3)
# (u'fox', 12)
# (u"Lorrain's", 1)
# (u'Meshcherski,', 1)
# (u'Similar', 1)
# (u'witty', 6)
# (u'gentlemen..."', 1)
# (u'exposition', 1)
# (u'shot..."', 1)
# (u'summoned', 18)
# (u'surprise.', 18)
# (u'foh', 1)
# (u'price', 6)
# (u'strivings', 1)
# (u'Later,', 1)
# (u'Russia--were', 1)
# (u'tone;', 1)
# (u'variety,', 2)
# (u'energy', 15)
# (u'circumstance,', 1)
# (u'propriety.', 1)
# (u'"Nothing.', 1)
# (u'latter--unconscious', 1)
# (u'fame,', 1)
# (u'Funke', 3)
# (u'comrades', 22)
# (u'floppy', 1)
# (u'flurried,', 1)
# (u'threadbare', 1)
# (u'shifting', 9)
# (u'starring', 1)
# (u'forever?', 1)
# (u'"Royalty', 1)
# (u'floundered', 1)
# (u'conclusion.', 3)
# (u'"Pierre!', 1)
# (u'restlessness', 3)
# (u'stinginess.', 1)
# (u'sot,', 1)
# (u'recollect', 1)
# (u'reiterated,', 1)
# (u'adjutants-general', 1)
# (u'vodka?', 1)
# (u'repellent', 2)
# (u'life--I', 1)
# (u'nearer,', 4)
# (u'lacked', 8)
# (u'slightly', 52)
# (u'valet--lay', 1)
# (u'yelled,', 1)
# (u'raised', 98)
# (u"don't,", 4)
# (u'ever-recurring', 1)
# (u'imagine!"', 1)
# (u'shopkeepers', 1)
# (u'Italian,', 4)
# (u'exhort', 1)
# (u'(un', 1)
# (u'disentangled', 2)
# (u'Adjutant-General', 1)
# (u'administer', 2)
# (u'clatter', 8)
# (u'beings', 5)
# (u'Italians,', 2)
# (u'antechamber,', 1)
# (u'officer?"', 2)
# (u'wrap', 1)
# (u'octogenarians', 1)
# (u'federal', 2)
# (u'perfume,', 3)
# (u'alleged,', 1)
# (u'due.', 2)
# (u'it--repeatedly', 1)
# (u'due,', 1)
# (u'clever,', 2)
# (u'Gulf', 1)
# (u'clever.', 2)
# (u'Count!', 2)
# (u'Znamenka.', 1)
# (u'Andrusha!..."', 1)
# (u'Mentally', 1)
# (u'husband--as', 1)
# (u'upbringing,', 1)
# (u'scented,', 1)
# (u'avail', 9)
# (u'Pray', 1)
# (u'Count;', 1)
# (u'Count?', 4)
# (u'resulted', 10)
# (u'footman,', 9)
# (u'said?"', 1)
# (u'departure,', 8)
# (u'Bilibin', 33)
# (u'being!', 1)
# (u'ken,', 3)
# (u'monograms', 2)
# (u'spurting', 1)
# (u'course!"', 4)
# (u'fascination', 2)
# (u'magnificent', 2)
# (u'marshal,', 5)
# (u'fleches,', 2)
# (u'forever', 13)
# (u'shrilly', 1)
# (u'right,', 83)
# (u'fighting."', 1)
# (u'perfumed', 2)
# (u'Hessian', 4)
# (u'Greek,', 1)
# (u'Latin,', 1)
# (u'owed.', 1)
# (u'so;', 4)
# (u'right.', 41)
# (u'so?', 11)
# (u'groom,', 6)
# (u'virtue.', 6)
# (u'congratulations', 4)
# (u'interrupted.', 5)
# (u'sources,', 1)
# (u'mirthless', 2)
# (u'astounded', 1)
# (u'ignorance.', 1)
# (u'inside', 14)
# (u'sobbing.', 2)
# (u'costume,', 3)
# (u'sobbing,', 4)
# (u'somebody,"', 1)
# (u'Oldenburg"--and', 1)
# (u'vanguard', 5)
# (u'ruts', 3)
# (u'hall:', 1)
# (u'Bilibin,"', 2)
# (u'smashed', 4)
# (u'palm', 4)
# (u'wait.', 12)
# (u'Bergs', 2)
# (u'Emperor?"', 2)
# (u'night!"', 1)
# (u'opponent,', 1)
# (u'prevails', 2)
# (u'disgrace', 6)
# (u'interpreter,', 3)
# (u'hysterical', 1)
# (u'Personal', 2)
# (u'visitors.', 9)
# (u'sure!"', 1)
# (u'Emperor?...', 1)
# (u'higher.', 2)
# (u"Bitski's", 1)
# (u'soothe', 4)
# (u'fly', 17)
# (u'injurious--she', 1)
# (u'exist', 14)
# (u'potatoes.', 1)
# (u'later--an', 1)
# (u'triangles', 1)
# (u'say."', 4)
# (u'slurring', 1)
# (u'smelt', 3)
# (u'lungs', 3)
# (u'dotted', 2)
# (u'Rhine,', 1)
# (u'"Sergeants', 1)
# (u'actor', 3)
# (u'uttered', 43)
# (u'count!', 1)
# (u'NOT', 2)
# (u'republic', 2)
# (u'temerity,', 1)
# (u'armchairs,', 2)
# (u'temporarily,', 1)
# (u'sunset', 1)
# (u'enlightenment?"', 1)
# (u'superfluous', 6)
# (u'expose', 9)
# (u'mundi."', 1)
# (u'coming!...', 2)
# (u'dinnerless,', 1)
# (u'death--killed!..."', 1)
# (u'describes!"', 1)
# (u'palms', 1)
# (u'craft.', 1)
# (u'stouter?"', 1)
# (u'hawked', 1)
# (u'transportee', 1)
# (u'Bugler,', 1)
# (u'drops.', 1)
# (u'rulers.', 3)
# (u'intent', 5)
# (u"'a", 3)
# (u'rolling', 16)
# (u'entrust', 2)
# (u'dissented', 1)
# (u'killed,', 15)
# (u'transfigured', 1)
# (u'excellence', 1)
# (u'snore', 1)
# (u'happened!"', 1)
# (u'benefactor.', 2)
# (u'"Never', 4)
# (u'confused.', 8)
# (u'typically', 1)
# (u'confused,', 10)
# (u'ended?"', 1)
# (u'commander?"', 2)
# (u'than:', 1)
# (u'Madeira', 1)
# (u"'A", 2)
# (u'will..."', 1)
# (u'signs.', 1)
# (u'banners', 3)
# (u'crown!', 1)
# (u'detachments?"', 1)
# (u'"Idiot!"', 1)
# (u'scoundrel', 10)
# (u'Montesquieu,"', 2)
# (u'uninterested', 1)
# (u'Vanya--clear', 1)
# (u'count?', 1)
# (u'chain', 7)
# (u'Bedouin,', 4)
# (u'novelty', 6)
# (u'stay.', 3)
# (u'divining', 2)
# (u'chivalry!', 1)
# (u'larvae,', 1)
# (u'Moroseyka,', 2)
# (u'shakos.', 1)
# (u'Sophie--I', 1)
# (u"bit--we'll", 1)
# (u'"Vereshchagin!', 1)
# (u'jarring', 1)
# (u'touchingly', 2)
# (u'chair', 43)
# (u'ooh,', 1)
# (u'hole', 5)
# (u'irrecoverable', 2)
# (u'emerges.', 1)
# (u'ballet', 3)
# (u'pagodes', 1)
# (u'"Qu\'on', 1)
# (u'men--who', 1)
# (u'enemy?...', 1)
# (u'lover--assumed', 1)
# (u'rousing', 1)
# (u'cases--began', 1)
# (u'pen', 2)
# (u'vex', 2)
# (u'time...', 2)
# (u'tea.', 10)
# (u'tea,', 14)
# (u'salver.', 1)
# (u'road--is', 2)
# (u'quickening', 1)
# (u'projections,', 1)
# (u'tenacious', 1)
# (u'glad,"', 5)
# (u'jerk', 3)
# (u'"Dunyasha', 1)
# (u'child:', 2)
# (u'ridicule...', 1)
# (u'capitally', 1)
# (u'peoples--at', 1)
# (u'anguish', 1)
# (u'rapturous', 19)
# (u'parents."', 1)
# (u'knapsack', 5)
# (u'kriegs-wurst-Raths', 1)
# (u'actresses--with', 1)
# (u'pranced', 3)
# (u'child,', 21)
# (u'child.', 13)
# (u'Killed!...', 1)
# (u'say!', 3)
# (u'pride,', 10)
# (u'cooks', 1)
# (u'sorrowful', 6)
# (u'howling,', 1)
# (u'murder,', 2)
# (u'tear', 9)
# (u'aflame', 1)
# (u'phrases.', 2)
# (u'malheureux', 1)
# (u'cameo', 1)
# (u'leave', 169)
# (u'properly.', 1)
# (u'serving?"', 1)
# (u'good.', 17)
# (u'unchangingly,', 1)
# (u'jesting!"', 1)
# (u'compressed.', 1)
# (u'compressed,', 4)
# (u'bonfire', 1)
# (u'aims;', 1)
# (u'blend--and', 1)
# (u'either!"', 1)
# (u'musket.', 1)
# (u'musket,', 3)
# (u"Fabvier's", 1)
# (u'procession:', 1)
# (u'DONATIONS', 1)
# (u'diary', 2)
# (u'Count,"', 14)
# (u'magnates', 2)
# (u'thrumming', 1)
# (u'long-suffering', 1)
# (u'candlestick', 2)
# (u'"Help', 2)
# (u'strategics,', 1)
# (u'depression', 9)
# (u'sink.', 1)
# (u'"everything', 1)
# (u'carpet,', 3)
# (u'hothouse,', 1)
# (u'carpet.', 2)
# (u'though,', 3)
# (u'Lopukhin', 2)
# (u'roans', 3)
# (u'heart,', 29)
# (u'cleanliness', 3)
# (u'secretly.', 2)
# (u"Langeron's", 3)
# (u'entrusts', 1)
# (u'arm,', 38)
# (u'melt', 2)
# (u'bibulous,', 1)
# (u'current', 17)
# (u'remembered', 99)
# (u'"Grounds', 1)
# (u'all-powerful', 1)
# (u'same....', 2)
# (u'eyeglass.', 1)
# (u'Dementyev', 1)
# (u'minimize', 1)
# (u'Me', 1)
# (u'apartments.', 2)
# (u'jury', 1)
# (u'blushes,', 2)
# (u'contiguous', 1)
# (u'shirt.', 6)
# (u'Bolkonski?"', 4)
# (u'shirt,', 7)
# (u'spilled', 3)
# (u'Europe;', 2)
# (u"hunter's", 2)
# (u'guise', 3)
# (u'grain."', 3)
# (u'gratefully,', 2)
# (u'considerations,', 3)
# (u'yards', 17)
# (u'he!"', 1)
# (u'alone', 154)
# (u'reclining', 1)
# (u'along', 201)
# (u'My', 54)
# (u'blameworthy.', 1)
# (u'momentous', 1)
# (u'me--not', 1)
# (u'directeur', 1)
# (u"l'honneur,", 2)
# (u'appreciated.', 1)
# (u'exploded,', 1)
# (u'dusty', 13)
# (u'root', 1)
# (u'JULIE', 1)
# (u'wherever', 9)
# (u'commonly', 1)
# (u'seen:', 1)
# (u'accomplished', 15)
# (u'chemical', 3)
# (u'sprouted', 2)
# (u'Jack,', 1)
# (u'inkpot,', 1)
# (u'Guerrilla', 1)
# (u'studies', 1)
# (u'botany,', 1)
# (u'rider.', 1)
# (u'places."', 1)
# (u'rider,', 1)
# (u'love', 345)
# (u'inevitably,', 1)
# (u'*Catherine.', 1)
# (u'Continuing', 1)
# (u'flank?"', 2)
# (u'terribly.', 2)
# (u'vodka', 11)
# (u'logical', 8)
# (u'Friedland', 1)
# (u'inquisitively', 2)
# (u"'AS-IS'", 1)
# (u'betraying', 9)
# (u'Tushin,', 14)
# (u'invented.', 1)
# (u"relations'", 1)
# (u'wegular', 1)
# (u"Katie's,", 1)
# (u'verlegt', 1)
# (u'insult.', 1)
# (u'slept,', 2)
# (u'meaningless.', 4)
# (u'slept.', 5)
# (u'wounded?"', 2)
# (u'"Wherefore?"', 1)
# (u'working', 15)
# (u'perished', 13)
# (u'valley,', 2)
# (u'angry', 86)
# (u'fourth;', 1)
# (u'"Alpatych,', 1)
# (u'Rascals!', 1)
# (u'favorable.', 1)
# (u'traps.', 1)
# (u'cherished', 1)
# (u'valley.', 4)
# (u'wondering', 9)
# (u'returns."', 1)
# (u'fichu', 2)
# (u'Those', 30)
# (u'Vaska,', 1)
# (u'STAFF,', 1)
# (u'met--coming', 1)
# (u'series,', 1)
# (u'heathens!', 1)
# (u'triumphantly.', 1)
# (u'laughs', 2)
# (u'triumphantly,', 2)
# (u'random,', 1)
# (u'Domain', 1)
# (u'refrain', 16)
# (u'Mimi', 2)
# (u'Tushin.', 10)
# (u'Poniatowski,', 2)
# (u'faculty,', 1)
# (u'far', 153)
# (u'Lukich,"', 1)
# (u'much?"', 3)
# (u'blood.', 6)
# (u"hair's", 5)
# (u'blood,', 7)
# (u'Lyubim', 1)
# (u'behalf', 8)
# (u'writing!"', 1)
# (u'forefinger,', 1)
# (u'est...', 1)
# (u'deserved', 7)
# (u'Pope', 1)
# (u'adroit,', 1)
# (u'seen.', 29)
# (u'glad....', 1)
# (u'Prusse..."', 1)
# (u'Volkonski,', 5)
# (u'imagination,', 7)
# (u'nether', 1)
# (u'gallop,', 7)
# (u'already?"', 4)
# (u'values', 3)
# (u'slowness', 2)
# (u'author:', 1)
# (u'believed', 36)
# (u'renew', 7)
# (u'"Turn', 2)
# (u'Timokhin!"', 1)
# (u'her?--The', 1)
# (u'sentiment."', 2)
# (u'tears."', 1)
# (u'Holding', 1)
# (u'instance...', 1)
# (u'possesses:', 1)
# (u'bust', 1)
# (u'application.', 1)
# (u'Luther', 1)
# (u'remounts,', 1)
# (u'candles?...', 1)
# (u'personages,', 1)
# (u'heard.', 50)
# (u'heard,', 24)
# (u'solicitude,', 1)
# (u'stole', 1)
# (u'kindness.', 1)
# (u'wicked.', 1)
# (u'actions?', 1)
# (u'fire....', 1)
# (u'definition,', 1)
# (u'savor', 1)
# (u'cruel', 20)
# (u'revoir!"--', 1)
# (u'poking', 2)
# (u'ambush', 4)
# (u'thunder,', 1)
# (u'thanking', 1)
# (u'veneration--especially', 1)
# (u'(overcoming', 1)
# (u'three-ruble', 1)
# (u'Frenchies', 2)
# (u'brother-in-', 2)
# (u'undertook', 3)
# (u'listen,', 8)
# (u'listen.', 9)
# (u'strictness', 2)
# (u"hors-d'oeuvres.", 1)
# (u'sixth,', 1)
# (u'begging', 6)
# (u'spot', 39)
# (u'greasy,', 1)
# (u'ruin."', 1)
# (u'wrinkled', 12)
# (u'horrified,', 1)
# (u'heard!"', 1)
# (u'plood!"', 1)
# (u'space.', 5)
# (u'listen:', 1)
# (u'mirror,', 3)
# (u'cher!', 1)
# (u'fellow--your', 1)
# (u'reviendra.', 1)
# (u'stable.', 2)
# (u'lids', 2)
# (u'individual,', 1)
# (u'disagreeable', 9)
# (u'stress', 1)
# (u'numbed,', 1)
# (u'natural', 36)
# (u'provisions."', 1)
# (u'arshin,', 1)
# (u'Frenchie!', 1)
# (u'Villains!', 1)
# (u'irresolution,', 1)
# (u'standards!"', 1)
# (u'si', 2)
# (u'enemy.', 22)
# (u'so', 1460)
# (u"'Where", 2)
# (u'And..."', 1)
# (u'wolves', 8)
# (u'pulled', 32)
# (u'reproached,', 1)
# (u'se', 1)
# (u'drunken', 16)
# (u'ran,"', 1)
# (u'unsolicited', 2)
# (u'course-"', 1)
# (u'lighter', 2)
# (u'haute', 1)
# (u'monsieur,"', 1)
# (u'favors.)', 1)
# (u'spoken,"', 1)
# (u'clerks', 1)
# (u'two--morality', 1)
# (u'unsuitable', 2)
# (u'maneuvered', 1)
# (u'surprise!"', 1)
# (u'subordinate,', 1)
# (u'unfavorable', 2)
# (u'goods.', 1)
# (u'Danube,', 6)
# (u'adding,', 2)
# (u'tore', 10)
# (u'accurately.', 1)
# (u'limbs', 3)
# (u'yawning', 1)
# (u'manuscripts', 2)
# (u'paraded', 1)
# (u'troubles', 6)
# (u'stupidity', 4)
# (u'Suvorov...,"', 1)
# (u'reverberate', 1)
# (u'cropped;', 1)
# (u'reproche', 1)
# (u'liquid', 3)
# (u'greatcoat,', 3)
# (u'celebrate', 3)
# (u'admired,', 1)
# (u'impetuous..."', 1)
# (u'inconvenience--in', 1)
# (u'somehow,', 1)
# (u'tribunals.', 1)
# (u'causation', 2)
# (u'petition', 9)
# (u'coherence,', 1)
# (u'cela,', 1)
# (u'belts.', 1)
# (u'unheard-', 1)
# (u'sharpshooter', 1)
# (u'year:', 3)
# (u'3', 3)
# (u'matches', 2)
# (u'Duroc', 1)
# (u'bashful', 1)
# (u'life--not', 2)
# (u'unsatisfactory,', 1)
# (u'year,', 8)
# (u'confessor,', 1)
# (u'year.', 9)
# (u'compelled', 8)
# (u'boy,', 30)
# (u'pain?', 1)
# (u'24', 2)
# (u'arriving', 11)
# (u'pinnacle', 1)
# (u'mastery', 1)
# (u'gratitude--this', 1)
# (u'concluded..."', 1)
# (u'runners', 5)
# (u'parade.', 3)
# (u'animal."', 2)
# (u'parade,', 3)
# (u'joked', 2)
# (u'hiccough', 1)
# (u'fruitful--probably', 1)
# (u'conclusions,', 2)
# (u'fully.', 2)
# (u'appropriate', 3)
# (u'released,', 2)
# (u'too...', 3)
# (u'agriculturists,', 1)
# (u'exactitude', 1)
# (u'"Makar', 1)
# (u'dignified', 6)
# (u'harp.', 2)
# (u'countess,"', 1)
# (u'hope?', 3)
# (u"nurse's", 8)
# (u'cordiality', 3)
# (u'next.', 5)
# (u'live?', 2)
# (u'turtle', 2)
# (u'A', 373)
# (u'sternly;', 1)
# (u'bursting', 5)
# (u'out--well,', 1)
# (u'sliding,', 1)
# (u'adored.', 1)
# (u'adored,', 1)
# (u'remembrance', 4)
# (u'God...', 1)
# (u'girdled', 2)
# (u'entering', 47)
# (u'adored:', 1)
# (u'right.)', 1)
# (u'show!"', 1)
# (u'superior,', 1)
# (u'joking."', 1)
# (u'canvas', 2)
# (u'Pierre.', 219)
# (u'Remembering', 1)
# (u'Pierre,', 265)
# (u'squared', 1)
# (u'astray', 2)
# (u'planets', 2)
# (u'definitely!"', 1)
# (u'seriously', 15)
# (u'decreased.', 1)
# (u'Yells', 1)
# (u'co-operated', 1)
# (u'suggesting', 7)
# (u'indeed!...', 2)
# (u'works,', 6)
# (u'Pierre:', 5)
# (u'stupid.', 6)
# (u'calming', 2)
# (u'disaster,', 1)
# (u'probably,', 1)
# (u'disintegrated', 1)
# (u'servants--the', 1)
# (u'siege', 4)
# (u'misfortune?', 2)
# (u'down?', 2)
# (u'seventh', 11)
# (u'striven', 3)
# (u'possibility', 55)
# (u'20', 3)
# (u'inwardly', 3)
# (u'complicated', 12)
# (u'despondent', 1)
# (u'plea', 4)
# (u'(God)', 1)
# (u'remainder', 3)
# (u'Dolokhov,"', 2)
# (u'commander-in-chief--a', 1)
# (u'shores', 1)
# (u'training', 3)
# (u'instructions!"', 1)
# (u'gentlemen."', 1)
# (u'square.', 3)
# (u'queenless', 3)
# (u'advancing."', 1)
# (u'discussing', 8)
# (u'collapsing', 2)
# (u'protection,', 1)
# (u'modest', 6)
# (u'that")', 1)
# (u'sticky,', 2)
# (u'crossness', 1)
# (u'impure', 1)
# (u'tolerate', 1)
# (u'Ermolov,', 8)
# (u'Bridgehead.', 1)
# (u'Ermolov.', 2)
# (u'Cookshops', 1)
# (u'cob,', 1)
# (u'edition.', 1)
# (u'accouterments', 1)
# (u'hey!"', 1)
# (u'puny', 1)
# (u'emotion', 14)
# (u'justice--a', 1)
# (u'folk."', 1)
# (u'saving', 18)
# (u'err', 1)
# (u'symmetry', 2)
# (u'spoken', 46)
# (u'22', 1)
# (u'"Nicholas!', 2)
# (u'firing?"', 2)
# (u'tableaux', 1)
# (u'conscientiously', 2)
# (u'Voyna', 1)
# (u'generosity.', 1)
# (u'utensils,', 1)
# (u'generosity,', 3)
# (u'despicable', 2)
# (u'way....', 2)
# (u'teatime', 1)
# (u'reached,', 1)
# (u'smoked,', 3)
# (u'Drubetskoy--awaited', 1)
# (u"artillerymen's", 1)
# (u'shining,', 3)
# (u'excellency,"', 24)
# (u'thyself;', 1)
# (u'High', 1)
# (u'delegation', 1)
# (u'convent', 1)
# (u'campstool,', 2)
# (u'we--you', 1)
# (u'bite', 1)
# (u"Shinshin's", 3)
# (u'pronunciation', 1)
# (u'coat,', 31)
# (u'life--is', 1)
# (u'physically', 15)
# (u'favor.', 4)
# (u'grew.', 3)
# (u'favor,', 4)
# (u'tradesman', 2)
# (u'Street,', 5)
# (u'bits', 6)
# (u'unmarried', 2)
# (u'Thoughts', 3)
# (u'YOU', 6)
# (u'inactivity', 2)
# (u'adjutant.)', 1)
# (u'on.', 95)
# (u'on,', 114)
# (u'nuns,"', 1)
# (u'fallen!', 1)
# (u'spoke,', 4)
# (u'much,', 20)
# (u'wight!', 2)
# (u'much.', 17)
# (u'on:', 5)
# (u'chess.', 1)
# (u'spot,"', 1)
# (u'either,', 2)
# (u'Tsar', 32)
# (u'imagining', 14)
# (u'funny!"', 1)
# (u'attempt', 13)
# (u'1.E.7', 2)
# (u'representing', 7)
# (u'rogues.', 1)
# (u'bags.', 1)
# (u'emulation,', 1)
# (u'queen,', 2)
# (u'overtaken', 6)
# (u'Go."', 1)
# (u'depressed', 5)
# (u'Occasionally,', 1)
# (u"on!--you've", 1)
# (u'bit!', 2)
# (u"Speranski's:", 1)
# (u'fattened.', 1)
# (u'upright', 4)
# (u'appreciation.', 1)
# (u'grade."', 1)
# (u'gase,"', 1)
# (u'wandering', 4)
# (u'youths', 1)
# (u'prospect', 6)
# (u'important!"', 1)
# (u'addressing', 69)
# (u'can\'t,"', 4)
# (u'flatly', 1)
# (u'peasants?"', 1)
# (u'sumptuous', 1)
# (u'fourteenth', 4)
# (u'turned', 381)
# (u'cellaret', 1)
# (u'minded.', 1)
# (u'tastes', 3)
# (u'caustic,', 1)
# (u'presiding', 2)
# (u'obtained;', 1)
# (u'uninterrupted', 3)
# (u'bloom,"', 1)
# (u'Gascons.)', 1)
# (u'decide', 16)
# (u'noonday:', 1)
# (u'balls.', 4)
# (u'differently,', 3)
# (u'law,', 8)
# (u'law.', 7)
# (u'"Always', 5)
# (u'inches', 3)
# (u'ax:', 1)
# (u'niches)', 1)
# (u'illness.', 5)
# (u'bad;', 1)
# (u'"Especially', 1)
# (u'horse,"', 4)
# (u'note', 27)
# (u'thickest.', 1)
# (u'intends', 5)
# (u'anyone?', 1)
# (u'revoir.', 1)
# (u'intonation,', 1)
# (u'revoir,', 4)
# (u'tourments', 1)
# (u'recruiting."', 1)
# (u'convulsive', 5)
# (u'relaxed', 1)
# (u'ax,', 3)
# (u'towers', 1)
# (u'ironically', 8)
# (u'altered', 12)
# (u'danger),', 1)
# (u'syllable', 2)
# (u'discerning', 2)
# (u'werden.', 1)
# (u'Jesuit', 2)
# (u'afternoon.', 3)
# (u'afternoon,', 2)
# (u'laden.', 1)
# (u'Novosiltsev,', 2)
# (u'nice,', 6)
# (u'nice.', 2)
# (u'inserted', 2)
# (u'wealthiest', 1)
# (u'hero--but', 1)
# (u'action?', 1)
# (u'Peterkin--and', 1)
# (u'something:', 1)
# (u'wearing;', 1)
# (u'City,', 1)
# (u'Salomoni!', 1)
# (u'average', 1)
# (u'housing', 1)
# (u'blockhead', 1)
# (u'Vesenya!', 1)
# (u'bit....', 1)
# (u'something.', 41)
# (u'crooked', 3)
# (u'bade', 1)
# (u'own--that', 1)
# (u'Zakhar!"', 1)
# (u'costume.', 2)
# (u'legs,', 25)
# (u'pursuits,', 2)
# (u'exceeds', 1)
# (u'Oestreicher!', 1)
# (u'everyone,', 10)
# (u'Sevres', 2)
# (u'equipage.', 1)
# (u'operations', 6)
# (u'walking', 39)
# (u'murmurs', 1)
# (u'remember--yet', 1)
# (u'Lord!"', 6)
# (u'come!', 4)
# (u'"Brothers!', 2)
# (u'antagonism.', 1)
# (u'merit', 8)
# (u'battalion,', 8)
# (u'refutations,', 1)
# (u'battalion.', 4)
# (u'potato.', 1)
# (u'minuteness,', 1)
# (u'minuteness.', 1)
# (u'Gwiska--my', 1)
# (u'Mummy,"', 1)
# (u'aggressive', 1)
# (u'imagined', 38)
# (u'terrible--disgusting,"', 1)
# (u'arms,', 29)
# (u'Makarka,', 1)
# (u'weapons', 5)
# (u'serait', 1)
# (u'decisions;', 1)
# (u'surrounded.', 1)
# (u'reconciling', 1)
# (u'case..."', 1)
# (u'water,"', 2)
# (u'myself..."', 1)
# (u'robs', 1)
# (u'come?', 3)
# (u'aimlessly', 2)
# (u'priding', 2)
# (u'betrothal', 3)
# (u'lanterns,', 1)
# (u'Ilynich...', 1)
# (u'lanterns.', 2)
# (u'Convention,', 2)
# (u'Przazdziecka', 1)
# (u'complexion', 1)
# (u'entreaties', 3)
# (u'guile,', 1)
# (u'alone--the', 1)
# (u'tethered,', 1)
# (u"I'll", 147)
# (u'hindmost', 2)
# (u'usual,', 15)
# (u'come;', 2)
# (u'usual.', 15)
# (u'System,', 2)
# (u'tilting', 2)
# (u'clang', 1)
# (u'you,"', 78)
# (u'wrinkles,', 3)
# (u'outside--gradually', 1)
# (u'rejoices', 2)
# (u'imagine,', 1)
# (u'whizzing', 1)
# (u'imagine.', 1)
# (u'profit,"', 1)
# (u'rejection', 1)
# (u'awkwardly,', 3)
# (u"XIV's", 1)
# (u'F3.', 1)
# (u'comment', 1)
# (u'going?...', 1)
# (u'(one', 5)
# (u'shatters', 1)
# (u'resource', 2)
# (u'keenly', 3)
# (u'Terror', 1)
# (u'advantageously,', 1)
# (u"hare's", 3)
# (u'name--well,', 1)
# (u'recurred', 7)
# (u'Colosseum.', 1)
# (u'punch,', 2)
# (u'parlor--the', 1)
# (u'haul', 2)
# (u'whipped', 2)
# (u'maps,', 3)
# (u'Vilna.', 3)
# (u'"We\'ve', 5)
# (u'where', 520)
# (u'Napoleon--hardly', 1)
# (u'vision', 2)
# (u'across?"', 1)
# (u'smoke."', 1)
# (u'Wintzingerodes!', 1)
# (u'marrying.', 1)
# (u'marrying,', 1)
# (u'affinity', 1)
# (u'order.', 28)
# (u'comedian', 1)
# (u'notice', 57)
# (u'foreseen,', 2)
# (u'responsive', 1)
# (u'foreseen.', 2)
# (u'specimen,"', 1)
# (u'outrageous!', 1)
# (u'hastened', 21)
# (u'aroused', 28)
# (u'rewarded', 1)
# (u'naked;', 1)
# (u'furniture,', 5)
# (u'compliance.', 1)
# (u'"Shouldn\'t', 1)
# (u'mystical', 4)
# (u'concentrate.', 1)
# (u'doffed', 3)
# (u'Masons,', 2)
# (u'slander', 1)
# (u'Religion,', 2)
# (u'uhlans.', 5)
# (u'dear..."', 1)
# (u'man"', 1)
# (u'bureau', 2)
# (u'helpless!', 1)
# (u'sable', 7)
# (u'affecting', 3)
# (u"d'ame,", 1)
# (u'enjoys', 3)
# (u'estrangement,', 1)
# (u'take,', 1)
# (u'man.', 69)
# (u'rage,', 3)
# (u'admirably', 2)
# (u'rage.', 3)
# (u'impression.', 5)
# (u'robust,', 1)
# (u'impression,', 1)
# (u'oh-ing', 1)
# (u'screen', 7)
# (u'coming...', 2)
# (u'hobbledehoy', 1)
# (u'rapidly', 69)
# (u'awards', 1)
# (u'sores,', 1)
# (u'day!"', 1)
# (u'menacing', 9)
# (u'then.', 11)
# (u'spark', 3)
# (u'suppressed', 11)
# (u'nine."', 1)
# (u'concentrated', 19)
# (u'blame', 39)
# (u'it?"--"Because', 1)
# (u'conversed', 2)
# (u'majestically', 2)
# (u'mop:', 1)
# (u'moon,', 8)
# (u'conveyed,', 2)
# (u'one-sided,', 1)
# (u'west.', 2)
# (u'confidence,"', 1)
# (u'west,', 3)
# (u'madcap', 1)
# (u'stuttering,', 1)
# (u's', 2)
# (u'matter--has', 1)
# (u'dangers.', 2)
# (u'floundering', 4)
# (u'mission.', 3)
# (u'expression', 235)
# (u'God!"', 13)
# (u"can't", 164)
# (u'tenaciously,', 1)
# (u'Prince?"', 7)
# (u'inclining', 1)
# (u'affectionate.', 1)
# (u'reading:', 1)
# (u'Kutuzov!"', 1)
# (u'"Thought...', 1)
# (u'want?', 7)
# (u'genial', 1)
# (u'conquerors,', 1)
# (u'reading,', 8)
# (u'reading.', 10)
# (u'manuscript--', 1)
# (u'pierce', 1)
# (u'nursery,', 2)
# (u'"Save', 1)
# (u'dislocation', 1)
# (u'dutiful', 1)
# (u'Apollon', 1)
# (u'good-by', 6)
# (u'better', 126)
# (u'Germans."', 1)
# (u'second-grade', 1)
# (u'stretch', 6)
# (u'iniquities!', 1)
# (u'feel?', 1)
# (u'vous!"', 1)
# (u'squeeze,', 1)
# (u'collided', 1)
# (u'gravely,', 1)
# (u'motives', 3)
# (u'Georgian', 2)
# (u'see!', 7)
# (u'puckered.', 1)
# (u'only..."', 3)
# (u'tenaciously.', 1)
# (u'virtuous.', 2)
# (u'abandoned,', 5)
# (u'spyglass', 1)
# (u'wants', 27)
# (u'way;', 1)
# (u'consider,', 3)
# (u'admit,"', 1)
# (u"actor's", 1)
# (u'questions--the', 1)
# (u'hung', 34)
# (u'thousand', 143)
# (u'sturdily', 1)
# (u'cupboards', 1)
# (u'administrator', 2)
# (u'Allies', 1)
# (u'about..."', 1)
# (u'presided', 1)
# (u'half-shaven', 2)
# (u'squadron--that', 1)
# (u'vices,', 1)
# (u'unclouded', 2)
# (u"out--that's", 1)
# (u'close-clinging', 1)
# (u'bewildered.', 2)
# (u'audibly.', 1)
# (u'foraging,', 1)
# (u'guffaw', 1)
# (u'"There\'s', 13)
# (u'Kremlin.', 4)
# (u'crackled,', 1)
# (u'Redoubt', 10)
# (u'yes,"', 17)
# (u'coincidence,', 1)
# (u'intimately', 3)
# (u'his,', 9)
# (u'Swedes--it', 1)
# (u'allait-il', 1)
# (u'overcome', 9)
# (u'Ilyin;', 1)
# (u'squeezed', 8)
# (u'ravine.', 2)
# (u'endured', 4)
# (u'stupidest', 3)
# (u'languor,', 1)
# (u'penthouse', 1)
# (u'downy', 7)
# (u'croaked', 1)
# (u'infamies', 1)
# (u'countermanded', 1)
# (u'"Annette,', 1)
# (u'two!"', 1)
# (u'engaged', 24)
# (u'rubbishy', 1)
# (u'scoundwels...', 1)
# (u'Looking', 10)
# (u'lost;', 1)
# (u'regularity', 2)
# (u'farmer:', 1)
# (u'Cossack--"were', 1)
# (u'irrevocable,', 2)
# (u'management,', 2)
# (u'hands--hands', 1)
# (u'management.', 1)
# (u'Smolensk"--he', 1)
# (u'Vicomte,"', 2)
# (u'rebuild?', 1)
# (u'Copenhagen--a', 1)
# (u'shuts', 1)
# (u'train,', 2)
# (u'shiningly', 1)
# (u'preparatory', 2)
# (u'coincidence.', 1)
# (u'cost,', 1)
# (u'lump', 4)
# (u'thief,', 1)
# (u'lady-killer.', 1)
# (u'visualized', 1)
# (u'drunkenness.', 2)
# (u'Through', 17)
# (u'clapping', 6)
# (u'decreases', 1)
# (u'flush.', 2)
# (u'sisters;', 1)
# (u'cupolas', 3)
# (u'rescue.', 2)
# (u'you..."', 18)
# (u'edged', 1)
# (u"deceased's", 1)
# (u'alight,', 1)
# (u'I', 3225)
# (u'"Lie', 3)
# (u'Oo...!"', 1)
# (u'births', 1)
# (u'you....', 4)
# (u'XVI', 33)
# (u'reluctantly', 5)
# (u'authors,', 2)
# (u'Drissa;', 1)
# (u'Clean', 1)
# (u'six.', 1)
# (u'cheery', 1)
# (u'motionless,', 7)
# (u'wheels', 23)
# (u'motionless.', 3)
# (u'fellows!"', 6)
# (u'talking,', 14)
# (u'"Back', 1)
# (u'impatiently,', 2)
# (u'excused', 3)
# (u'impatiently.', 2)
# (u'Slav', 1)
# (u'Moment', 1)
# (u'pacing', 22)
# (u'S.S.', 1)
# (u'peculiarities', 4)
# (u'scar,', 1)
# (u'engulfing', 1)
# (u'comes', 49)
# (u'reporting:', 1)
# (u'Telling', 1)
# (u'Nataly.', 1)
# (u'Nataly,', 1)
# (u'blessedness', 3)
# (u'persistently', 4)
# (u'inaudibly', 1)
# (u'Really,', 2)
# (u'neighborhood', 4)
# (u'steamed', 1)
# (u'bared,', 1)
# (u'being', 445)
# (u'officers,', 44)
# (u'disconcert', 2)
# (u'wound?', 1)
# (u'rest', 70)
# (u'famished,', 1)
# (u'Cards', 1)
# (u'Trunila', 2)
# (u'tide', 1)
# (u'fateful', 1)
# (u'snarled', 1)
# (u'difficulty.)', 1)
# (u'married?"', 1)
# (u'officers:', 1)
# (u'beaux', 1)
# (u'eBook,', 1)
# (u'perdere', 1)
# (u'occasional', 7)
# (u'now--there', 1)
# (u'repentance,', 1)
# (u'swaggering', 1)
# (u'nuisance,"', 1)
# (u'Forminsk.', 1)
# (u'Forminsk,', 1)
# (u'plunderers', 2)
# (u'conceptions', 6)
# (u'furs--so', 1)
# (u'bricks', 1)
# (u'loudly,', 6)
# (u'saddened', 1)
# (u'Anonymous', 2)
# (u'town,"', 1)
# (u'plumes', 8)
# (u'actors', 3)
# (u'strange.', 3)
# (u'woman!"', 5)
# (u'Outside', 2)
# (u'Ivanushka,', 2)
# (u'correcting', 1)
# (u'ask..."', 1)
# (u'starving', 2)
# (u'senator,', 2)
# (u'sorry?', 1)
# (u'pedestrian,', 1)
# (u'unerring', 1)
# (u'6,', 1)
# (u'naively,', 1)
# (u'groups;', 1)
# (u'bony', 7)
# (u'gestures', 4)
# (u'scraps', 1)
# (u'Aunt', 1)
# (u'6.', 1)
# (u'trousers,', 4)
# (u'unmistakably', 1)
# (u'decomposes', 1)
# (u'orders,', 31)
# (u'dare', 36)
# (u'posted,', 1)
# (u'satisfaction', 25)
# (u'noble,', 6)
# (u'stranger', 17)
# (u'hunger,', 2)
# (u'succeeded;', 1)
# (u'hunger.', 2)
# (u'Share', 1)
# (u"return....'", 1)
# (u'committeemen.', 1)
# (u'Wostovs', 1)
# (u'superiority', 8)
# (u'Medyn', 1)
# (u'Notwithstanding', 1)
# (u'gentleman..."', 1)
# (u'stationary', 2)
# (u'loudest.', 1)
# (u'snow.', 9)
# (u'conciliation', 1)
# (u'satisfactory', 3)
# (u"'Is", 1)
# (u'learning', 10)
# (u'gifts?', 1)
# (u'putrefaction', 1)
# (u'"\'Grant', 1)
# (u'presentation', 3)
# (u'dreamer,', 1)
# (u'angle--so', 1)
# (u'story--they', 1)
# (u'raveled', 1)
# (u'dozed,', 1)
# (u'Gazing', 1)
# (u'expended,', 1)
# (u'destroy,', 1)
# (u'droll', 1)
# (u'copse,', 2)
# (u'out...', 1)
# (u'fright!', 1)
# (u'(does', 1)
# (u"serfs'", 8)
# (u'noon', 4)
# (u'acres,', 1)
# (u'faraway', 4)
# (u'dimpled', 2)
# (u'sins.', 3)
# (u'glory?', 1)
# (u'champagne.', 1)
# (u'countenances', 1)
# (u'"There!', 7)
# (u'sutlers.', 1)
# (u'count--Count', 1)
# (u'"Caps', 1)
# (u'charmer,', 1)
# (u'tubs', 4)
# (u'ordered;', 1)
# (u'restoring', 1)
# (u'think.', 3)
# (u'"She\'ll', 3)
# (u'think,', 26)
# (u'barbarians,', 1)
# (u'signet', 1)
# (u'zest', 2)
# (u'Tula', 6)
# (u'dwown', 1)
# (u'ladies."', 1)
# (u'world--overflowed', 1)
# (u'imminence', 1)
# (u'forgetfulness', 2)
# (u"You'll", 16)
# (u'Miraculous', 1)
# (u'ardor,', 1)
# (u'standpoint', 2)
# (u'me-r-r-y', 1)
# (u'moment,"', 5)
# (u'forgetting...', 1)
# (u'lively.', 2)
# (u'stone', 15)
# (u'dimple.', 1)
# (u'Vasilevna', 1)
# (u'joyfully', 24)
# (u'cakes;', 1)
# (u'conversation--"and', 1)
# (u'shaved,', 2)
# (u'favorite', 30)
# (u'lively,', 1)
# (u'slender', 18)
# (u'itself--how', 1)
# (u'"believe', 1)
# (u'neighbor', 7)
# (u'investigate', 1)
# (u'foregathered', 1)
# (u'cutup', 1)
# (u'Hi!...', 1)
# (u'rebuild', 3)
# (u'countess."', 2)
# (u'positions.', 2)
# (u'colored.', 1)
# (u'purse,"', 1)
# (u'perturbed', 5)
# (u'fortunately', 3)
# (u'silk-embroidered', 1)
# (u'"Because', 13)
# (u'Urged', 1)
# (u'choppers', 1)
# (u'cares?"', 1)
# (u'image', 3)
# (u'preceded', 3)
# (u'legged', 3)
# (u'Dronushka."', 1)
# (u'prepares', 1)
# (u'garnering', 1)
# (u'But', 829)
# (u'homeless', 1)
# (u'wit,', 1)
# (u'financial', 2)
# (u'(made', 1)
# (u'worried.', 1)
# (u'jerks', 1)
# (u'trip,', 1)
# (u'her', 3883)
# (u'abuse,', 5)
# (u'abuse.', 3)
# (u'shove,"', 1)
# (u'rag.', 1)
# (u'"Gott,', 1)
# (u'No!...', 1)
# (u'loathsome.', 1)
# (u'torrents,', 1)
# (u'late,"', 4)
# (u'leaflets', 2)
# (u'sealed', 2)
# (u'punished', 10)
# (u'hen', 1)
# (u'checks,', 1)
# (u'mallet.', 1)
# (u'20%', 1)
# (u'another;', 6)
# (u'Learned', 1)
# (u'"General', 2)
# (u'delicious', 3)
# (u'emergence', 1)
# (u'firmly:', 1)
# (u'N.', 5)
# (u'"Mot', 2)
# (u'Strange,', 1)
# (u'men...', 1)
# (u'dearest?"', 1)
# (u'Bosse.', 1)
# (u"j'avoue", 1)
# (u'crafty,', 1)
# (u'another-', 1)
# (u'drones,', 1)
# (u'tunic', 2)
# (u'another!', 2)
# (u'with', 5521)
# (u'soul--vividly,', 1)
# (u'man),', 1)
# (u'abused', 5)
# (u'rush', 16)
# (u'billet', 1)
# (u'world?"', 2)
# (u'involuntarily:', 1)
# (u'capitulation?"', 2)
# (u'colony', 1)
# (u'Ours.', 1)
# (u'detachment,', 8)
# (u'Recognizing', 1)
# (u'detachment.', 4)
# (u'flirt', 4)
# (u'valuables', 2)
# (u'blacksmiths', 1)
# (u'bookcase,', 1)
# (u'pleasure!"', 1)
# (u'he"', 3)
# (u'girl."', 1)
# (u'attentions.', 1)
# (u'age', 20)
# (u'painter..."', 1)
# (u'detailed', 8)
# (u'engine', 2)
# (u'"They\'d', 2)
# (u'speech,"', 1)
# (u'fright', 7)
# (u'pity!', 1)
# (u'conversations.', 1)
# (u"Bourienne's", 13)
# (u'am', 502)
# (u'skeleton,', 1)
# (u'wartime', 2)
# (u'as', 3699)
# (u'au', 10)
# (u'wildly:', 1)
# (u'midwife', 4)
# (u'shrieking,', 1)
# (u'tranquil', 17)
# (u'attendance,', 2)
# (u'whit', 1)
# (u'qualities)', 1)
# (u'uplifts', 1)
# (u'isn\'t?..."', 1)
# (u'Vasili', 168)
# (u'renewal.', 1)
# (u'drafts', 1)
# (u'August.', 2)
# (u'Nikitski', 1)
# (u'"Oh!', 8)
# (u'novice', 1)
# (u'sympathetically', 3)
# (u'unnamed,', 1)
# (u'justice,"', 1)
# (u'scarred.', 1)
# (u'learn.', 2)
# (u'whip', 21)
# (u'querulous', 4)
# (u'trick!', 1)
# (u'Lannes,', 2)
# (u'predestined', 8)
# (u'fours', 1)
# (u'disgraceful', 4)
# (u'oh,', 4)
# (u'conjectures', 6)
# (u'indemnify', 1)
# (u'sofas,', 1)
# (u'XXXVI', 2)
# (u'walk,', 8)
# (u'walk.', 6)
# (u'place..."', 1)
# (u'frost-bound', 1)
# (u'waving', 14)
# (u'Spain."', 1)
# (u'Literary', 13)
# (u'implored', 6)
# (u'subjects.', 2)
# (u'cellar,', 1)
# (u'pitiable', 1)
# (u'(always', 2)
# (u'friend..."', 3)
# (u'admires', 1)
# (u'me."', 42)
# (u'across,', 2)
# (u'happy).', 1)
# (u'tricks', 1)
# (u'Suddenly', 43)
# (u'mask', 1)
# (u'which--with', 1)
# (u'dyed', 1)
# (u'wag', 2)
# (u'desertest', 1)
# (u'at.', 8)
# (u'impossibility', 9)
# (u'passed', 171)
# (u'"Andre,"', 1)
# (u'token', 8)
# (u'cheekbones,', 3)
# (u'tales', 7)
# (u'nobody--there', 1)
# (u'axles', 1)
# (u'evenly,', 3)
# (u'externally', 3)
# (u'(it', 15)
# (u'merriest,', 1)
# (u'elements.', 3)
# (u'jostle,', 1)
# (u'self-perfecting.', 1)
# (u'aide-de-camp.', 3)
# (u'emerges--by', 1)
# (u'aide-de-camp,', 7)
# (u'Adieu,', 2)
# (u'nation,', 4)
# (u"go!'", 1)
# (u'upkeep', 1)
# (u'partial', 2)
# (u'Vincent', 1)
# (u'causes', 35)
# (u'content', 11)
# (u'dusk.', 2)
# (u"commander's,", 1)
# (u'hunting', 14)
# (u'"heroes")', 1)
# (u'Donations', 2)
# (u'ruby', 1)
# (u'woolwork;', 1)
# (u'Natasha,', 205)
# (u'dreadfully--and', 1)
# (u'Natasha.', 140)
# (u'constructed.', 1)
# (u'tail', 18)
# (u'Water-Carrier,', 1)
# (u'robber', 2)
# (u'Providence,', 1)
# (u'handkerchief?', 1)
# (u'him--his', 2)
# (u'start.', 5)
# (u'premeditation', 1)
# (u'Natasha--are', 1)
# (u'splashing', 13)
# (u'mufti', 1)
# (u'paying', 16)
# (u'Scarcely', 5)
# (u'appointment', 16)
# (u'Special', 1)
# (u'Smolensk."', 2)
# (u'crumpling', 3)
# (u'Elder?"', 2)
# (u'saved', 27)
# (u'accidently."', 1)
# (u'burgher', 1)
# (u'capotes', 1)
# (u'mutilation', 1)
# (u'"Fetch', 2)
# (u'stabling', 1)
# (u'24th', 1)
# (u'authentic', 3)
# (u'fan', 3)
# (u'condition', 58)
# (u'you...."),', 1)
# (u'confinements,', 1)
# (u'17th', 1)
# (u'confession.', 2)
# (u'mammas', 1)
# (u'proceeded', 5)
# (u'officials,', 6)
# (u'strategist', 2)
# (u'eventuality,', 1)
# (u'laying', 8)
# (u'errors.', 1)
# (u'insufficiently', 2)
# (u'large', 149)
# (u'life?', 4)
# (u'sand', 1)
# (u'different....', 1)
# (u'beekeeper,', 1)
# (u'small', 156)
# (u'gloomy,', 5)
# (u'dinner--I', 1)
# (u'riot?', 1)
# (u'mount', 7)
# (u'phase', 1)
# (u'has,', 4)
# (u'nations,', 1)
# (u'has.', 1)
# (u'educated,', 2)
# (u'Bazaar.', 1)
# (u'educated.', 1)
# (u'civilian,', 3)
# (u'life;', 6)
# (u'standard!"', 1)
# (u'mop,', 1)
# (u'"Rugayushka!"', 1)
# (u'powdered', 9)
# (u'past', 120)
# (u'amiss', 1)
# (u'carriages', 24)
# (u'Pfuel,', 12)
# (u'sighs,', 1)
# (u'discernible,', 2)
# (u'aid.', 1)
# (u'Department!', 1)
# (u'magical,', 1)
# (u'greatly.', 1)
# (u'chessmen', 3)
# (u'heavy."', 1)
# (u'funny).', 1)
# (u'(his', 3)
# (u'schemes,', 1)
# (u'disintegration', 3)
# (u'section', 8)
# (u'corked', 2)
# (u'receiving,', 1)
# (u'curses,', 1)
# (u'her--not', 1)
# (u'Kutaysov', 1)
# (u'of--that', 1)
# (u'destroyed', 33)
# (u'whirled', 4)
# (u'nurse', 29)
# (u'writer,', 1)
# (u'contrast', 14)
# (u'revealing', 3)
# (u'Jests', 1)
# (u'origin);', 1)
# (u'escaping', 6)
# (u'"Lucky', 1)
# (u'pas,', 2)
# (u'shouting.', 8)
# (u'display,', 2)
# (u'"Why?', 6)
# (u'hours', 29)
# (u'dregs', 1)
# (u"Denisov's.", 1)
# (u'(How', 1)
# (u"Denisov's,", 1)
# (u'hast', 6)
# (u'buzzing', 8)
# (u'carriage;', 1)
# (u'Know,', 1)
# (u'Silence', 2)
# (u'piti,"', 1)
# (u'4x', 1)
# (u'solid', 1)
# (u'different--', 1)
# (u'morose,', 3)
# (u'Almost', 6)
# (u'morose.', 2)
# (u'hundwed', 3)
# (u'embarrassed', 8)
# (u'experience', 30)
# (u'yourself,', 16)
# (u'yourself.', 8)
# (u'life)', 1)
# (u'cherish.', 1)
# (u'lowest-grade', 1)
# (u'Ulm,', 3)
# (u'Zakret,', 1)
# (u'plaited', 3)
# (u'embroidering:', 1)
# (u'Pierre.)', 1)
# ...
# (u'impressing', 1)
# (u'belt', 4)
# (u'property', 22)
# (u'freedom!', 1)
# (u'Can', 22)
# (u'ambition', 3)
# (u'truce.', 1)
# (u'republican', 2)
# (u'exchanging,', 1)
# (u'herself...', 1)
# (u'napkin', 9)
# (u'successor', 1)
# (u'crowd.', 30)
# (u'crowd,', 24)
# (u'"ke-e-e-e,"', 1)
# (u"night's", 5)
# (u'Yauza', 5)
# (u'crops,', 1)
# (u'bubbling', 1)
# (u'crossly:', 1)
# (u'censers,', 1)
# (u'trimmed', 3)
# (u'ship,', 3)
# (u'trap', 13)
# (u'yesterday?', 1)
# (u"'How", 4)
# (u'cigar', 1)
# (u'mouth--seemed', 1)
# (u'"...of', 1)
# (u'round!', 1)
# (u'cry', 46)
# (u"traveler's", 1)
# (u'Bonaparte', 43)
# (u'centuries', 6)
# (u'caught,', 1)
# (u'tossed,', 1)
# (u'bowled', 1)
# (u'Next', 47)
# (u'meditated.', 1)
# (u'capital;', 1)
# (u'truce,', 2)
# (u'interplay', 2)
# (u'yellow-faced,', 1)
# (u'sob', 4)
# (u'ambassadors', 1)
# (u'bunks,', 1)
# (u'brother."', 1)
# (u'sleeves,', 3)
# (u'sleeves.', 1)
# (u'performance."', 1)
# (u'respects', 5)
# (u'reverberated', 4)
# (u'Moreau', 3)
# (u'assured.', 2)
# (u'frontier', 8)
# (u'casket', 2)
# (u'gossamer', 1)
# (u'chaos', 1)
# (u'ferocity', 2)
# (u'trodden-down', 3)
# (u'settlement', 1)
# (u'principes,', 1)
# (u'heartless,', 1)
# (u'Nearly', 4)
# (u'Beausset,', 5)
# (u'narrative', 2)
# (u'astounded.', 1)
# (u'honorable', 11)
# (u'Pavlograds', 7)
# (u'worker,', 1)
# (u"Ecka'tshausen", 1)
# (u'slept,"', 2)
# (u'write,', 4)
# (u'lad.', 4)
# (u'ambassador\'s,"', 1)
# (u'granddaughter', 1)
# (u'"Wait,', 3)
# (u'raises', 1)
# (u'act."', 1)
# (u'dishes,', 1)
# (u'Poland.', 2)
# (u'repelled', 1)
# (u'Poland,', 8)
# (u'bristled', 1)
# (u'Natalie?', 1)
# (u'"tongue"--that', 1)
# (u'"From', 13)
# (u'marriage--Khvostikov,', 1)
# (u'murmur.', 1)
# (u'figure"', 1)
# (u'chuckle,', 2)
# (u'sinner,"', 1)
# (u'hear:', 1)
# (u'enough!"', 2)
# (u'additional', 6)
# (u'support.', 3)
# (u'originated.', 1)
# (u'on--', 1)
# (u'dogs?', 1)
# (u'someday', 2)
# (u'phrases', 6)
# (u'thinking.', 5)
# (u'tombstones,', 1)
# (u'unexecuted.', 2)
# (u'walls.', 2)
# (u'walls,', 5)
# (u'best--recollections', 1)
# (u'hot!"', 2)
# (u'Ulm', 2)
# (u"j'ai", 1)
# (u'Formerly,', 2)
# (u'1.D.', 1)
# (u'foreheads,', 1)
# (u'Sometimes--when', 1)
# (u'biting', 6)
# (u'Regulations,', 1)
# (u'Divine', 2)
# (u'"general"', 1)
# (u'picture!', 1)
# (u'so...', 8)
# (u'quilts,', 1)
# (u'God!..."', 1)
# (u'stupidity.', 1)
# (u'creature."', 1)
# (u'Natalie,"', 2)
# (u'relish', 1)
# (u'echo', 2)
# (u'budding,', 1)
# (u'Mamma!"', 1)
# (u'choose', 21)
# (u'western', 1)
# (u'sublieutenancy."', 1)
# (u'noticed', 167)
# (u'partake', 2)
# (u'Petersburg-', 1)
# (u'lifts!', 1)
# (u"doesn't", 34)
# (u'hear.', 3)
# (u'droop', 2)
# (u"'faithful", 1)
# (u'unknown', 52)
# (u'creator', 1)
# (u'Pakhra?', 1)
# (u'proved.', 2)
# (u'favorite:', 1)
# (u'their', 1408)
# (u'chagrin', 1)
# (u'difference,"', 1)
# (u'enough.', 6)
# (u'now--with', 1)
# (u'enough,', 7)
# (u'epaulets', 1)
# (u'delaying', 1)
# (u'lighthearted!', 1)
# (u'vexation,', 3)
# (u'results;', 1)
# (u'lads,', 2)
# (u'shell', 9)
# (u'spectators.', 1)
# (u'learned:', 1)
# (u'comments.', 1)
# (u'consoling', 3)
# (u'shelf', 1)
# (u'edge', 22)
# (u'shallow', 2)
# (u'"Perhaps', 10)
# (u'bird;', 1)
# (u'Germans,', 1)
# (u'learned.', 1)
# (u'regards', 7)
# (u'Przebyszewski', 2)
# (u'Natasha!..."', 1)
# (u'hood.', 2)
# (u'diminish', 2)
# (u'policeman', 7)
# (u'institution', 2)
# (u'remember', 79)
# (u'wretches', 2)
# (u'superfluity', 1)
# (u'irregularly', 2)
# (u'stir),', 1)
# (u'retraite,', 1)
# (u'not?"', 12)
# (u'retreat,', 18)
# (u'chattered', 5)
# (u'arouse', 10)
# (u'Chichagov', 2)
# (u'heirs.', 1)
# (u'kidnap....', 1)
# (u'Chigirin', 1)
# (u'selling', 8)
# (u'Peter', 31)
# (u'"may', 1)
# (u'faints', 1)
# (u'colors,', 1)
# (u'scoundrels!"', 1)
# (u'unaccountable', 2)
# (u'surgeon,', 1)
# (u'contemporaneously,', 1)
# (u'likelier', 1)
# (u'Anton', 1)
# (u'brightened.', 2)
# (u'him--thereby', 1)
# (u'accountant.', 1)
# (u'affairs--this', 1)
# (u'accountant,', 3)
# (u'plan?', 1)
# (u'III,', 1)
# (u'Ivanich', 1)
# (u'sincerity', 4)
# (u'instant).', 1)
# (u'retinue', 1)
# (u'"dispositions."', 1)
# (u'adversary.', 1)
# (u'"Charming,', 1)
# (u'linked', 5)
# (u'Tatarinova', 2)
# (u'"Platonic', 1)
# (u'purple,', 1)
# (u'convicts', 5)
# (u'afraid', 116)
# (u'pupils', 3)
# (u'people,"', 9)
# (u'XV,', 1)
# (u'etes', 2)
# (u'for...', 1)
# (u"m'\xeatre", 1)
# (u'wounds,', 3)
# (u'swelling', 6)
# (u"gendarmes'", 1)
# (u'west--similar', 1)
# (u'retrospection,', 1)
# (u'Rostov."', 3)
# (u'once."', 3)
# (u'easygoing', 1)
# (u'friends?"', 1)
# (u'loudest', 1)
# (u'glancing', 69)
# (u'(available', 1)
# (u'hesitated.', 2)
# (u'everyone--', 1)
# (u'So-and-so,', 1)
# (u'tunneled', 1)
# (u'think."', 2)
# (u'bandaged,', 2)
# (u'hatchet!...', 1)
# (u'III.', 1)
# (u'dresses.', 3)
# (u'complaints,', 1)
# (u'pitiful,', 4)
# (u'grievance', 1)
# (u'ribbons,', 5)
# (u'assez', 1)
# (u'ribbons.', 1)
# (u'amphitheater,', 2)
# (u'Nikolaevich,', 1)
# (u'alarmed', 9)
# (u'why', 217)
# (u'definite:', 1)
# (u'couture,*(3)', 1)
# (u'victim,', 2)
# (u'recovering.', 1)
# (u'shameless,', 1)
# (u'refreshing', 2)
# (u'XXVIII', 6)
# (u'acting:', 1)
# (u'neighboring', 10)
# (u'Song', 1)
# (u'storming', 1)
# (u'prisoners.', 12)
# (u'prisoners,', 25)
# (u'1.E', 1)
# (u'tapers', 2)
# (u'inheritance', 3)
# (u'hollow-cheeked', 1)
# (u'healthy,', 3)
# (u'hopelessness)--at', 1)
# (u'"Perched', 1)
# (u'father--who', 1)
# (u'Asiatic', 3)
# (u'Whose', 3)
# (u'announced.', 1)
# (u"'minister'", 1)
# (u'doubt."', 1)
# (u'pockets,', 1)
# (u'word,', 31)
# (u'*Poisonous', 1)
# (u'sphinx,', 1)
# (u'Karataev,"', 1)
# (u'calculations,', 1)
# (u'wanting', 2)
# (u'planning', 6)
# (u'Nikolaevich.', 1)
# (u'religious,', 1)
# (u'triumph.', 4)
# (u'utter', 26)
# (u"Gerasim's", 1)
# (u'one;', 2)
# (u'pleased', 75)
# (u'ruddy', 4)
# (u'nearer', 60)
# (u'wry', 2)
# (u'Mansfeld.', 1)
# (u'Bazdeev,', 2)
# (u'densely', 1)
# (u'disgracing', 1)
# (u'"Ilyin?', 1)
# (u'combs', 1)
# (u'trotting', 1)
# (u'Channel.', 1)
# (u'eat', 30)
# (u'surroundings', 8)
# (u'know."', 6)
# (u'palace!"', 1)
# (u'refilling', 1)
# (u"sovereign's", 4)
# (u'"Finally', 1)
# (u'undermining', 3)
# (u'announced,', 3)
# (u'indignant', 1)
# (u"Metivier's", 3)
# (u'intruding,"', 1)
# (u'please:', 1)
# (u'occurred,"', 1)
# (u'depressed,', 1)
# (u'comforts', 9)
# (u'harmed', 1)
# (u'Ryazan,"', 1)
# (u'proposals,', 2)
# (u'Egyptians', 1)
# (u'machine.', 1)
# (u'barrier!"', 1)
# (u'deed--interrupted', 1)
# (u'agree?', 1)
# (u'flogged', 2)
# (u'triumph,', 2)
# (u'please,', 17)
# (u"valet's", 1)
# (u'please.', 3)
# (u'master),', 1)
# (u'praiseworthy', 1)
# (u'weather;', 1)
# (u'Theology', 1)
# (u'crupper.', 1)
# (u'nearly', 52)
# (u'Karataev', 36)
# (u'profligacy.', 1)
# (u'working.', 1)
# (u'thousand,', 12)
# (u'result?', 1)
# (u'brain', 3)
# (u'deceiver', 1)
# (u'Paris--left', 1)
# (u'stumbling,', 1)
# (u'philosophizing,"', 1)
# (u'Gradually,', 1)
# (u'disclaimer', 2)
# (u'ascertain', 5)
# (u'"Uncle,"', 7)
# (u'sparrows', 1)
# (u'Suvorovs', 2)
# (u'endowed', 5)
# (u'rafts', 1)
# (u'Vistula', 3)
# (u'unwell', 6)
# (u'temptation--the', 1)
# (u'out--wearing', 1)
# (u'good-by!"', 5)
# (u'stout,', 13)
# (u'Chief.', 1)
# (u'scurry.', 1)
# (u'absent-mindedness', 5)
# (u'employed', 10)
# (u'violet', 1)
# (u'exactly....', 1)
# (u'quite', 360)
# (u'instance..."', 1)
# (u'cweation...', 1)
# (u'orderlies,', 2)
# (u'vocation', 5)
# (u'(The', 9)
# (u'Communion:', 1)
# (u'Gospel:', 2)
# (u'monstrous', 4)
# (u"Rostov's", 56)
# (u'comprehensible--it', 1)
# (u"revelers',", 1)
# (u'favor', 18)
# (u'conjugal', 1)
# (u'projecting', 1)
# (u'do?..."', 1)
# (u'ground;', 1)
# (u'enraptured,', 2)
# (u'squirrel-fur', 1)
# (u'"nothing', 1)
# (u'ceilings,', 1)
# (u'bought', 18)
# (u'glory.', 1)
# (u'earth."', 1)
# (u'ideas;', 1)
# (u'opening', 28)
# (u'peace."', 2)
# (u'columns.', 5)
# (u'columns,', 7)
# (u'embarrassment', 10)
# (u'apes', 1)
# (u'bees--tamed', 1)
# (u'oats."', 1)
# (u'self-preservation,', 1)
# (u'depends.', 1)
# (u'unity,', 1)
# (u'smarten', 1)
# (u'"Ugh.', 1)
# (u'guests--the', 1)
# (u'"Ugh,', 1)
# (u'constraint', 5)
# (u'who..."', 3)
# (u'valve', 1)
# (u'disadvantageous', 2)
# (u'fleissig?"', 1)
# (u'Dokhturov', 19)
# (u'incessantly,', 6)
# (u'incessantly.', 2)
# (u'pretty,', 12)
# (u'Confused', 1)
# (u'Russians?"', 1)
# (u'Petersburg,"', 4)
# (u'deter', 1)
# (u'XII', 35)
# (u'tactical', 3)
# (u'Burned,', 1)
# (u'grounds', 3)
# (u'wobber', 1)
# (u'designs,', 1)
# (u'everywhere:', 1)
# (u'diligently', 2)
# (u'shoving', 3)
# (u'Hochgeboren!', 1)
# (u'wonder', 13)
# (u'1805:', 1)
# (u'walk', 28)
# (u'subscribe', 2)
# (u'faculties', 5)
# (u'Thwee!"', 1)
# (u'innkeepers,', 1)
# (u'wobbed', 1)
# (u'stretching,"', 1)
# (u'1805.', 3)
# (u'closing.', 1)
# (u'1805,', 11)
# (u'art.)', 1)
# (u'unhappiness', 2)
# (u"commander's", 8)
# (u'flashes', 1)
# (u'it--ensure', 1)
# (u'choice;', 1)
# (u'commander--as', 1)
# (u'decent', 4)
# (u'truth...', 1)
# (u'Alliance', 1)
# (u'snort', 3)
# (u'know)', 1)
# (u'white!"', 1)
# (u'offers', 6)
# (u'condemn', 6)
# (u'gallantly;', 1)
# (u"Poniatowski's", 2)
# (u'impetuously', 4)
# (u'head.)', 1)
# (u'Vrazhok,', 1)
# (u'girl!"', 1)
# (u'bwushed', 1)
# (u'conductors.', 1)
# (u'tray,', 1)
# (u'tray.', 1)
# (u'anteroom', 14)
# (u'others."', 3)
# (u'snacks."', 1)
# (u'jaded', 1)
# (u'scrutiny', 1)
# (u'line?"', 2)
# (u'undergraduate,', 1)
# (u'ensuring', 2)
# (u'busy."', 1)
# (u'confers', 1)
# (u'square--for', 1)
# (u'paroxysm', 1)
# (u'unmoved', 1)
# (u'vanity', 14)
# (u'repetition', 2)
# (u'withdraw.', 1)
# (u'self-esteem', 2)
# (u'kerchief', 8)
# (u'Factories', 1)
# (u'consent."', 1)
# (u'why--rode', 1)
# (u'indubitable.', 1)
# (u'lightly,', 5)
# (u'wished,', 3)
# (u'wished.', 1)
# (u'protested', 2)
# (u'lemonade', 1)
# (u'black-eyed', 2)
# (u'ticket,', 1)
# (u'gallops', 1)
# (u'ourselves."', 1)
# (u'chattering', 4)
# (u'province,', 5)
# (u'province.', 3)
# (u'supply', 9)
# (u'Mack,', 5)
# (u'Mack.', 3)
# (u'footgear', 1)
# (u'ringing', 18)
# (u'throng,', 1)
# (u'Father?"', 2)
# (u'wallflower,"', 1)
# (u'detonators', 1)
# (u'disapprove', 2)
# (u'piteously', 4)
# (u'"Dere', 1)
# (u'lonely', 2)
# (u'"Telyanin!', 1)
# (u'"Uncle', 2)
# (u'desires.', 3)
# (u"Russia's", 6)
# (u'thud', 7)
# (u'elbow,', 7)
# (u'Alley!"', 1)
# (u'stands', 10)
# (u'disapprovingly', 5)
# (u'education', 9)
# (u'element', 5)
# (u'horse!...', 1)
# (u'craftsmanship,', 1)
# (u'dreamers;', 1)
# (u'fling', 2)
# (u'cross', 49)
# (u'Bory?"', 1)
# (u'nights,"', 1)
# (u'wasted,', 1)
# (u'improper.', 1)
# (u'ants.', 1)
# (u'simultaneously.', 3)
# (u'largest', 11)
# (u'west--Paris--and', 1)
# (u'gets', 16)
# (u'crown.', 1)
# (u'difficult', 72)
# (u'"they', 6)
# (u'Suvorov-', 1)
# (u'soothed', 1)
# (u'tucked-up', 1)
# (u'husband...', 1)
# (u'statesman', 2)
# (u'audience.', 5)
# (u'audience,', 4)
# (u'Mummy,', 2)
# (u'mazurka,', 4)
# (u'dignitaries.', 1)
# (u'Mere', 1)
# (u'fine?"', 1)
# (u'starting,', 1)
# (u'Sasha!', 1)
# (u'eagle").', 1)
# (u'ignorant,', 1)
# (u'collar', 15)
# (u'for...."', 1)
# (u'Doctors', 1)
# (u'correspondent', 1)
# (u'partition', 4)
# (u'plowed', 4)
# (u'Moscow\'?"', 1)
# (u'rotary', 1)
# (u'feverishly', 5)
# (u'banging', 2)
# (u'object', 39)
# (u'light-blue', 5)
# (u'music:', 1)
# (u'surlier', 1)
# (u'fourteen-year-old', 2)
# (u'privilege,', 1)
# (u'get?', 1)
# (u'undertaken', 6)
# (u'submissive,', 2)
# (u'smithy,', 1)
# (u"tomorrow's", 8)
# (u'creditors.', 1)
# (u'of--even', 1)
# (u'Never', 6)
# (u'camel', 1)
# (u'Infantry', 1)
# (u'seconds,', 2)
# (u'unfortunate,', 2)
# (u'seconds.', 3)
# (u'obtain', 25)
# (u'egotistic.', 1)
# (u'cries', 14)
# (u'recollection', 16)
# (u'fishing', 1)
# (u'animated;', 1)
# (u'forest."', 1)
# (u'Nicholas', 378)
# (u'only:', 2)
# (u"'corner'", 1)
# (u'seemliness,', 1)
# (u'toilets', 1)
# (u'rapid', 41)
# (u'longer,"', 1)
# (u'golden-tinted', 1)
# (u'hard,"', 1)
# (u'physiological,', 2)
# (u'courtesy,', 1)
# (u'Club,', 5)
# (u'Club.', 1)
# (u'coronet)', 1)
# (u'ignorance', 4)
# (u'Koslovski,', 1)
# (u'Francis', 8)
# (u'Prince."', 3)
# (u'two!..."', 1)
# (u'consent,"', 1)
# (u'volleys', 1)
# (u'this-"', 1)
# (u'self-possessed,', 1)
# (u"Dimmler--isn't", 1)
# (u'background,', 1)
# (u'Jaffa', 1)
# (u'frieze', 9)
# (u'came.', 5)
# (u'came,', 12)
# (u'dictation.', 1)
# (u"who's", 7)
# (u'FIVE:', 2)
# (u'reasonable.', 2)
# (u"else's", 4)
# (u'yellow.', 2)
# (u'denser', 3)
# (u'blow!"', 1)
# (u'"awl,', 1)
# (u'coincidence', 4)
# (u'untying', 1)
# (u'intrigues', 8)
# (u'LIMITED', 3)
# (u'gbnewby@pglaf.org', 1)
# (u'women--even', 1)
# (u'helpful', 1)
# (u'car', 1)
# (u'Canal.', 1)
# (u'"Talk', 1)
# (u'pomp,', 1)
# (u'Within', 5)
# (u'widows', 1)
# (u'mother-in-law', 2)
# (u'Mouton,', 1)
# (u'loses', 3)
# (u'levying', 1)
# (u'now;', 1)
# (u'instantaneously.', 1)
# (u'feigned', 3)
# (u'storeroom', 1)
# (u'Cossacks:', 1)
# (u'helped,', 1)
# (u'sloping', 4)
# (u'fond--and', 1)
# (u'inaudibly,', 2)
# (u'really!', 2)
# (u'wonders', 3)
# (u'self-justifications', 1)
# (u'because', 438)
# (u'well-preserved', 1)
# (u'shabby', 6)
# (u'smoothly', 5)
# (u'wobbewy...', 1)
# (u'celui', 2)
# (u'church', 32)
# (u'naval', 6)
# (u'searching', 16)
# (u"Ermolov's", 4)
# (u'mosquitoes', 1)
# (u'center--the', 1)
# (u'yellow,', 4)
# (u'growth', 2)
# (u'past,', 25)
# (u'indubitable,', 1)
# (u'past.', 23)
# (u'omnipotence,', 1)
# (u'Or--go', 1)
# (u"'That", 1)
# (u'form,', 5)
# (u'dramshop,', 1)
# (u'weeks.', 3)
# (u'Like', 18)
# (u"no'", 1)
# (u'Wafting', 1)
# (u'throughout', 8)
# (u'strange,"', 1)
# (u'showed.', 1)
# (u'flowers?', 1)
# (u'gardening,', 1)
# (u'leaded', 1)
# (u'sake,', 15)
# (u'(what', 3)
# (u'hussars?"', 2)
# (u'1.F.2.', 1)
# (u'because..."', 6)
# (u'bursts', 4)
# (u'whomever', 2)
# (u'taken...', 1)
# (u'remnant,', 1)
# (u'earrings', 2)
# (u'thrusting', 6)
# (u'suitors.', 1)
# (u'leader', 8)
# (u'paperweight', 2)
# (u'match...', 1)
# (u'Unable', 1)
# (u'beverage', 1)
# (u'mania', 2)
# (u"capital!'", 1)
# (u'obey', 17)
# (u'Nikolievich,', 1)
# (u'reveal', 3)
# (u'Ptolemaic', 2)
# (u'"Onto', 1)
# (u'disputing--Pierre', 1)
# (u'thirty-six', 2)
# (u'ashamed?"', 2)
# (u'suspects,', 1)
# (u'conveyed', 6)
# (u'confined,', 1)
# (u'Princesses', 1)
# (u'world."', 3)
# (u'Raevskis,', 1)
# (u'beat.', 1)
# (u'awards,', 2)
# (u'after', 623)
# (u'reward', 15)
# (u'all--everything,"', 1)
# (u'Anatole', 141)
# (u'gathered,', 2)
# (u'francais', 1)
# (u'carried', 96)
# (u'ruts.', 1)
# (u'saddle', 17)
# (u'distinctness', 2)
# (u'himself-', 1)
# (u'collapse;', 1)
# (u'smote', 2)
# (u'courtyard,', 3)
# (u'regiment."', 3)
# (u'courtyard.', 2)
# (u'marker,', 1)
# (u'twenty-second', 2)
# (u'swear', 3)
# (u'misfortunes,', 1)
# (u'herself,', 57)
# (u'dreamest', 1)
# (u'wastage', 1)
# (u'udder', 1)
# (u'emperor', 2)
# (u'transcend', 1)
# (u'himself;', 4)
# (u'mouth,', 19)
# (u'own', 444)
# (u'cocked', 4)
# (u"Nesvitski's", 5)
# (u'good-by:', 1)
# (u'command:', 1)
# (u'triumphant,', 1)
# (u'imagine--I', 1)
# (u'Writing', 1)
# (u'They,', 2)
# (u'good-by,', 9)
# (u'attachments', 1)
# (u'weather', 15)
# (u'brush', 4)
# (u'lawful', 1)
# (u'ville!', 1)
# (u'"Will', 20)
# (u'forget', 63)
# (u'brother,"', 2)
# (u'contest', 2)
# (u'significantly', 6)
# (u'indolence,', 1)
# (u'Danilovna', 7)
# (u'infant.', 2)
# (u'verses...', 1)
# (u'transfer', 7)
# (u'gentlemen"', 2)
# (u'*', 249)
# (u'vous,"', 1)
# (u'Essen', 1)
# (u'soldierly,', 1)
# (u'captains', 2)
# (u'intention', 31)
# (u'fertilizes', 1)
# (u'dropping', 14)
# (u'visitor', 21)
# (u'cakelike', 1)
# (u'"Lovely,', 1)
# (u"fool.'", 1)
# (u'mad?', 1)
# (u'Dover', 1)
# (u'mouth.', 10)
# (u'desecrate', 2)
# (u'"That,', 1)
# (u'hinder.', 1)
# (u"ba'cawolla--I", 1)
# (u'nourish', 2)
# (u'adaptations', 1)
# (u'cringing', 1)
# (u'Hendrikhovna', 8)
# (u'affairs--which', 1)
# (u'Social,"', 1)
# (u'range,', 1)
# (u'mutter', 1)
# (u'Napoleon--his', 1)
# (u'pensively.', 1)
# (u'astray.', 1)
# (u'pensively,', 1)
# (u'fast,', 2)
# (u'stamp.', 1)
# (u'deuce', 1)
# (u'ANY', 3)
# (u'Translators:', 1)
# (u'made', 445)
# (u'Saxons,', 1)
# (u'serfs.', 8)
# (u'Adieu!', 1)
# (u'captain;', 1)
# (u"her--Denisov's", 1)
# (u'eyelids.', 1)
# (u'attempt.', 2)
# (u'Sparrow', 4)
# (u'comprehended,', 1)
# (u'this,', 86)
# (u'this.', 37)
# (u'him--those', 1)
# (u'proper,', 1)
# (u'Julner,', 1)
# (u'represents', 1)
# (u'ruling', 4)
# (u'us:', 1)
# (u'demonstrate', 2)
# (u'this:', 16)
# (u'however,"', 1)
# (u'Petersburg', 137)
# (u'unfolding', 4)
# (u'EBOOK', 2)
# (u'property--and', 1)
# (u'toast,', 2)
# (u'intimidating', 1)
# (u'inadequate', 2)
# (u'"Vera\'s', 1)
# (u'meaningless', 10)
# (u'roar,', 3)
# (u'here--that', 1)
# (u'Maman,"', 1)
# (u'is?"', 2)
# (u'Gibbon', 1)
# (u'zides,', 1)
# (u'restraining', 6)
# (u'kind.', 7)
# (u'reflecting', 4)
# (u'kind,', 31)
# (u'Eugene', 1)
# (u"visitor's", 3)
# (u'observed.', 3)
# (u'lapsing', 1)
# (u'avoided', 19)
# (u'ferons', 1)
# (u'tipsy,', 2)
# (u'incredible', 3)
# (u'"Somebody', 1)
# (u'Brothers,"', 1)
# (u'silenced', 2)
# (u"borzoi's", 1)
# (u'attack--knew', 1)
# (u'"Love?', 1)
# (u'adequately', 1)
# (u'Yaroslavl,', 4)
# (u'blue,', 6)
# (u'other', 494)
# (u'Bourbons.', 2)
# (u'prochain,', 1)
# (u'normal', 6)
# (u'rank,', 4)
# (u'sutler', 1)
# (u'Marie', 2)
# (u'royalties', 1)
# (u'depths,', 1)
# (u'neither.', 2)
# (u'conclusion', 20)
# (u'spot.', 6)
# (u'mildness', 3)
# (u"O'er", 1)
# (u'nourishment', 3)
# (u'heroes,', 2)
# (u'absurd."', 2)
# (u'prose,', 1)
# (u'accomplish', 4)
# (u'puffing,', 2)
# (u'puffing.', 1)
# (u'supple', 5)
# (u'sparks,', 1)
# (u'BEFORE', 1)
# (u'Russia--barbaric', 1)
# (u'questioningly:', 1)
# (u'upwards', 2)
# (u'Company.', 2)
# (u'precise,', 3)
# (u'coffee.', 1)
# (u'coffee,', 1)
# (u'could,', 10)
# (u'Forminsk,"', 1)
# (u'Spaniards.', 1)
# (u'Spaniards,', 2)
# (u'those...', 2)
# (u'weariness.', 1)
# (u'Smolensk?"', 2)
# (u'conveying', 1)
# (u'not!"', 4)
# (u'Swiss,', 1)
# (u'affirm', 1)
# (u'struggled.', 1)
# (u"propriety's", 1)
