# %%
from pyspark import SparkContext
import re 

# Read the input file 
lines = sc.textFile("/Data/NASA_Access_Log")

# Method to split the input line and returns the word at the index 0
def getKey(line):
	# Replace '- ' with empty value, so input lines are separated only by white space
	str = line.replace("- "," ")
	# Replace multiple spaces by single space
	str = ' '.join(str.split())
	# Split the input line by white space unless text enclosed with in double quotes and '[]' and stores the each field as string array
	str = re.findall('\[[^\]]*\]|\"[^\"]*\"|\S+', str)
	return str[0]

# Creates the Key-Value pair with the Internet Address as the key and the integer 1 as the value
pairs = lines.map(lambda s: (getKey(s), 1))
# Creates the Key-Value pair with the Internet Address as the key and the corresponding count as the value
counts = pairs.reduceByKey(lambda a, b: a + b)
# Creates the sorted Key-Value pair
sortedValue = counts.sortByKey()
# Saves the created Key-Value pair in text file
sortedValue.saveAsTextFile("/Data/Output/SortingPython"); 
for value in sortedValue.collect():
    print(value)
# Out:
# (u'01-dynamic-c.wokingham.luna.net', 31)
# (u'02-17-05.comsvc.calpoly.edu', 8)
# (u'1032015.ksc.nasa.gov', 18)
# (u'128.102.147.16', 12)
# (u'128.126.238.217', 13)
# (u'128.158.133.154', 9)
# (u'128.158.28.118', 30)
# (u'128.158.36.178', 6)
# (u'128.158.38.106', 16)
# (u'128.158.40.216', 17)
# (u'128.158.42.143', 35)
# (u'128.158.46.53', 3)
# (u'128.158.48.26', 5)
# (u'128.158.54.114', 6)
# (u'128.158.54.58', 2)
# (u'128.158.57.112', 5)
# (u'128.159.111.138', 8)
# (u'128.159.111.23', 10)
# (u'128.159.111.26', 15)
# (u'128.159.112.24', 6)
# (u'128.159.121.34', 6)
# (u'128.159.121.64', 20)
# (u'128.159.122.104', 12)
# (u'128.159.122.110', 40)
# (u'128.159.122.113', 24)
# (u'128.159.122.119', 10)
# (u'128.159.122.134', 6)
# (u'128.159.122.144', 5)
# (u'128.159.122.15', 10)
# (u'128.159.122.155', 6)
# (u'128.159.122.160', 10)
# (u'128.159.122.174', 16)
# (u'128.159.122.190', 25)
# (u'128.159.122.21', 15)
# (u'128.159.122.38', 13)
# (u'128.159.122.72', 12)
# (u'128.159.122.93', 6)
# (u'128.159.123.150', 12)
# (u'128.159.123.34', 6)
# (u'128.159.123.38', 79)
# (u'128.159.123.57', 16)
# (u'128.159.123.58', 10)
# (u'128.159.124.16', 12)
# (u'128.159.124.17', 19)
# (u'128.159.127.18', 6)
# (u'128.159.127.26', 12)
# (u'128.159.127.36', 6)
# (u'128.159.127.65', 16)
# (u'128.159.129.117', 9)
# (u'128.159.129.170', 24)
# (u'128.159.129.199', 15)
# (u'128.159.129.221', 60)
# (u'128.159.129.222', 9)
# (u'128.159.129.38', 22)
# (u'128.159.132.13', 6)
# (u'128.159.132.56', 6)
# (u'128.159.132.61', 6)
# (u'128.159.135.66', 12)
# (u'128.159.135.72', 6)
# (u'128.159.135.73', 6)
# (u'128.159.135.97', 6)
# (u'128.159.137.81', 6)
# (u'128.159.140.55', 26)
# (u'128.159.144.130', 6)
# (u'128.159.144.131', 6)
# (u'128.159.144.184', 9)
# (u'128.159.144.83', 25)
# (u'128.159.145.21', 6)
# (u'128.159.145.44', 6)
# (u'128.159.154.115', 18)
# (u'128.159.154.116', 6)
# (u'128.159.154.142', 15)
# (u'128.159.154.153', 12)
# (u'128.159.168.162', 11)
# (u'128.159.177.119', 1)
# (u'128.159.53.131', 6)
# (u'128.159.63.159', 79)
# (u'128.159.76.133', 17)
# (u'128.159.76.142', 1)
# (u'128.159.76.152', 20)
# (u'128.159.76.30', 12)
# (u'128.159.76.97', 48)
# (u'128.163.13.59', 47)
# (u'128.164.162.182', 14)
# (u'128.165.118.25', 8)
# (u'128.183.18.45', 17)
# (u'128.184.12.3', 1)
# (u'128.192.43.3', 4)
# (u'128.194.44.213', 26)
# (u'128.203.7.224', 3)
# (u'128.206.53.41', 6)
# (u'128.206.98.202', 2)
# (u'128.217.61.126', 9)
# (u'128.217.61.14', 1)
# (u'128.217.61.141', 12)
# (u'128.217.61.15', 6)
# (u'128.217.61.184', 12)
# (u'128.217.61.192', 13)
# (u'128.217.61.27', 6)
# (u'128.217.61.57', 6)
# (u'128.217.61.8', 6)
# (u'128.217.61.98', 16)
# (u'128.217.62.1', 61)
# (u'128.217.62.2', 20)
# (u'128.217.62.224', 12)
# (u'128.217.62.226', 6)
# (u'128.217.62.45', 6)
# (u'128.217.62.48', 12)
# (u'128.217.62.97', 2)
# (u'128.217.63.27', 24)
# (u'128.217.63.64', 10)
# (u'128.217.63.77', 23)
# (u'128.220.81.135', 5)
# (u'128.226.105.3', 1)
# (u'128.226.105.7', 5)
# (u'128.227.158.89', 8)
# (u'128.227.242.135', 18)
# (u'128.252.178.183', 6)
# (u'128.253.204.227', 5)
# (u'128.39.174.58', 14)
# (u'128.95.198.46', 17)
# (u'128.95.36.16', 8)
# (u'128.96.54.34', 13)
# (u'129.107.2.32', 31)
# (u'129.130.115.7', 6)
# (u'129.130.25.139', 2)
# (u'129.130.25.142', 8)
# (u'129.130.87.118', 6)
# (u'129.132.164.70', 9)
# (u'129.15.54.22', 5)
# (u'129.164.50.103', 4)
# (u'129.164.50.105', 4)
# (u'129.164.50.108', 6)
# (u'129.172.174.167', 3)
# (u'129.193.18.15', 30)
# (u'129.198.30.228', 14)
# (u'129.228.192.115', 1)
# (u'129.237.82.102', 3)
# (u'129.237.82.105', 3)
# (u'129.237.82.110', 3)
# (u'129.237.82.112', 3)
# (u'129.237.82.115', 6)
# (u'129.237.82.120', 3)
# (u'129.237.82.124', 4)
# (u'129.237.82.125', 3)
# (u'129.237.82.126', 4)
# (u'129.237.82.128', 4)
# (u'129.237.82.139', 3)
# (u'129.237.82.141', 3)
# (u'129.237.82.142', 3)
# (u'129.237.82.149', 1)
# (u'129.243.214.199', 3)
# (u'129.243.222.20', 60)
# (u'129.252.125.153', 8)
# (u'129.252.125.156', 1)
# (u'129.55.10.111', 1)
# (u'129.55.20.2', 1)
# (u'129.60.81.6', 6)
# (u'129.79.71.33', 6)
# (u'130.101.57.20', 9)
# (u'130.109.116.175', 1)
# (u'130.163.101.78', 19)
# (u'130.225.40.78', 22)
# (u'130.38.178.248', 9)
# (u'130.60.208.48', 29)
# (u'131.110.50.36', 20)
# (u'131.115.37.150', 5)
# (u'131.115.70.209', 14)
# (u'131.123.250.6', 5)
# (u'131.176.12.122', 24)
# (u'131.178.202.74', 10)
# (u'131.178.80.46', 6)
# (u'131.178.80.92', 15)
# (u'131.182.122.172', 5)
# (u'131.182.140.91', 13)
# (u'131.182.150.242', 1)
# (u'131.182.171.246', 4)
# (u'131.182.175.107', 20)
# (u'131.182.28.171', 5)
# (u'131.202.12.50', 5)
# (u'131.220.161.166', 1)
# (u'131.230.193.131', 4)
# (u'131.24.148.21', 4)
# (u'131.247.150.133', 2)
# (u'131.4.17.186', 1)
# (u'131.46.21.203', 7)
# (u'131.6.18.156', 6)
# (u'131.96.84.3', 12)
# (u'132.183.200.102', 1)
# (u'132.203.70.17', 4)
# (u'132.206.154.22', 5)
# (u'132.250.35.92', 5)
# (u'133.13.128.141', 9)
# (u'133.23.48.62', 5)
# (u'133.30.112.66', 6)
# (u'133.45.168.21', 7)
# (u'133.50.54.40', 17)
# (u'133.53.64.33', 27)
# (u'133.53.8.33', 13)
# (u'134.10.8.114', 30)
# (u'134.124.43.151', 8)
# (u'134.124.43.166', 10)
# (u'134.130.179.1', 2)
# (u'134.131.22.4', 21)
# (u'134.131.224.45', 3)
# (u'134.131.38.49', 12)
# (u'134.131.38.72', 13)
# (u'134.131.47.86', 9)
# (u'134.131.70.42', 5)
# (u'134.131.8.163', 3)
# (u'134.15.1.6', 33)
# (u'134.157.45.46', 9)
# (u'134.180.115.209', 13)
# (u'134.205.140.131', 14)
# (u'134.209.57.30', 2)
# (u'134.243.65.122', 3)
# (u'134.47.135.54', 10)
# (u'134.57.33.109', 11)
# (u'134.57.49.157', 9)
# (u'134.68.45.56', 1)
# (u'134.75.134.74', 3)
# (u'134.75.215.100', 67)
# (u'135.135.70.145', 11)
# (u'136.183.196.1', 27)
# (u'136.186.130.13', 1)
# (u'136.205.102.72', 31)
# (u'136.205.112.46', 3)
# (u'136.210.100.35', 1)
# (u'137.104.135.187', 8)
# (u'137.133.210.4', 6)
# (u'137.155.22.164', 13)
# (u'137.158.128.152', 15)
# (u'137.197.15.42', 41)
# (u'137.197.42.91', 19)
# (u'137.219.117.24', 1)
# (u'137.219.117.32', 2)
# (u'137.245.232.140', 2)
# (u'137.245.236.137', 4)
# (u'137.33.90.78', 32)
# (u'137.35.116.13', 5)
# (u'137.67.16.115', 9)
# (u'137.96.114.191', 9)
# (u'137.99.56.64', 3)
# (u'138.25.144.113', 1)
# (u'138.26.83.61', 6)
# (u'138.86.14.22', 8)
# (u'138.92.10.170', 6)
# (u'139.102.16.62', 7)
# (u'139.102.16.74', 30)
# (u'139.169.118.116', 3)
# (u'139.169.120.174', 6)
# (u'139.169.174.81', 6)
# (u'139.169.205.45', 12)
# (u'139.169.210.20', 8)
# (u'139.169.211.193', 16)
# (u'139.169.219.164', 6)
# (u'139.169.219.89', 12)
# (u'139.169.229.61', 10)
# (u'139.169.5.244', 18)
# (u'139.169.52.19', 7)
# (u'139.169.52.224', 34)
# (u'139.169.60.15', 7)
# (u'139.169.64.91', 2)
# (u'139.169.64.93', 7)
# (u'139.169.83.53', 3)
# (u'139.169.84.111', 10)
# (u'139.169.99.189', 11)
# (u'139.230.50.74', 2)
# (u'140.120.9.5', 3)
# (u'140.147.17.11', 5)
# (u'140.157.64.182', 1)
# (u'140.171.18.158', 14)
# (u'140.183.24.56', 16)
# (u'140.195.46.42', 4)
# (u'140.198.40.156', 8)
# (u'140.76.40.5', 18)
# (u'140.78.140.23', 16)
# (u'140.82.202.168', 36)
# (u'140.90.239.88', 7)
# (u'140.92.24.70', 17)
# (u'141.102.80.205', 33)
# (u'141.117.223.12', 12)
# (u'141.132.95.72', 6)
# (u'141.205.6.28', 2)
# (u'141.224.128.236', 5)
# (u'141.225.47.102', 1)
# (u'141.225.47.104', 1)
# (u'141.225.47.106', 1)
# (u'141.225.47.118', 1)
# (u'141.225.47.123', 1)
# (u'141.240.210.79', 14)
# (u'141.246.60.11', 22)
# (u'141.80.168.79', 2)
# (u'142.106.138.148', 3)
# (u'142.227.11.190', 1)
# (u'143.107.192.123', 10)
# (u'143.107.192.99', 6)
# (u'143.107.208.166', 5)
# (u'143.206.107.36', 61)
# (u'143.216.14.42', 8)
# (u'144.13.200.112', 4)
# (u'144.170.204.222', 15)
# (u'144.26.32.57', 72)
# (u'146.137.24.11', 6)
# (u'146.152.16.34', 1)
# (u'146.154.25.76', 19)
# (u'146.186.50.89', 3)
# (u'146.189.64.111', 23)
# (u'146.213.16.119', 1)
# (u'146.222.11.39', 38)
# (u'146.58.18.79', 24)
# (u'146.79.30.10', 9)
# (u'146.83.198.111', 3)
# (u'146.9.12.230', 7)
# (u'147.109.73.4', 13)
# (u'147.124.3.107', 6)
# (u'147.129.82.59', 9)
# (u'147.129.82.60', 5)
# (u'147.129.82.67', 7)
# (u'147.140.160.101', 1)
# (u'147.147.191.43', 33)
# (u'147.217.150.13', 15)
# (u'147.221.23.22', 9)
# (u'147.252.163.99', 7)
# (u'147.46.5.50', 8)
# (u'147.46.67.121', 1)
# (u'147.57.105.166', 13)
# (u'147.74.110.108', 12)
# (u'147.74.110.47', 6)
# (u'147.74.110.94', 15)
# (u'147.74.34.188', 7)
# (u'148.114.165.14', 2)
# (u'148.136.113.19', 13)
# (u'148.136.113.208', 10)
# (u'148.136.113.240', 16)
# (u'148.166.1.110', 9)
# (u'148.166.1.117', 13)
# (u'148.202.19.5', 3)
# (u'148.204.244.2', 6)
# (u'148.207.38.37', 10)
# (u'148.211.6.4', 12)
# (u'148.61.231.126', 9)
# (u'148.85.6.161', 21)
# (u'149.127.12.229', 13)
# (u'149.128.166.155', 12)
# (u'149.156.244.1', 18)
# (u'149.168.15.199', 13)
# (u'149.82.197.142', 26)
# (u'149.82.41.79', 16)
# (u'150.140.178.50', 16)
# (u'151.140.10.220', 8)
# (u'151.155.222.90', 1)
# (u'151.156.41.250', 10)
# (u'151.99.164.2', 5)
# (u'151.99.165.73', 8)
# (u'151.99.173.110', 10)
# (u'151.99.240.22', 12)
# (u'151.99.240.7', 20)
# (u'152.106.1.138', 2)
# (u'152.120.119.82', 25)
# (u'152.3.149.64', 8)
# (u'152.3.149.75', 8)
# (u'152.3.67.13', 8)
# (u'152.67.52.10', 5)
# (u'152.91.75.1', 1)
# (u'152.97.85.132', 8)
# (u'153.36.171.4', 2)
# (u'153.76.31.112', 8)
# (u'155.147.48.196', 12)
# (u'155.226.60.128', 12)
# (u'155.229.200.200', 6)
# (u'155.31.11.228', 9)
# (u'155.32.12.101', 8)
# (u'155.79.94.76', 8)
# (u'156.1.196.1', 6)
# (u'156.40.96.220', 7)
# (u'156.50.95.21', 12)
# (u'156.63.176.137', 28)
# (u'156.74.28.36', 15)
# (u'157.158.20.17', 1)
# (u'157.176.76.14', 2)
# (u'158.126.132.111', 1)
# (u'158.250.18.13', 11)
# (u'158.39.79.110', 6)
# (u'159.111.17.198', 11)
# (u'159.111.17.37', 7)
# (u'159.142.145.166', 6)
# (u'159.142.92.108', 23)
# (u'159.198.10.10', 3)
# (u'159.198.169.32', 4)
# (u'159.198.172.50', 11)
# (u'160.205.101.49', 10)
# (u'160.205.122.112', 6)
# (u'160.205.51.120', 8)
# (u'160.45.74.6', 1)
# (u'161.134.124.22', 1)
# (u'161.142.129.52', 4)
# (u'161.200.82.71', 10)
# (u'162.108.180.105', 6)
# (u'162.108.3.67', 16)
# (u'162.108.3.68', 12)
# (u'162.108.3.71', 15)
# (u'162.127.10.243', 48)
# (u'162.127.191.200', 9)
# (u'162.127.191.204', 4)
# (u'163.12.17.53', 2)
# (u'163.135.16.62', 5)
# (u'163.185.148.2', 3)
# (u'163.191.189.164', 1)
# (u'163.203.192.109', 30)
# (u'163.203.193.220', 8)
# (u'163.205.1.19', 66)
# (u'163.205.12.40', 6)
# (u'163.205.12.41', 6)
# (u'163.205.12.7', 24)
# (u'163.205.12.97', 12)
# (u'163.205.121.3', 12)
# (u'163.205.125.17', 6)
# (u'163.205.150.12', 12)
# (u'163.205.150.14', 12)
# (u'163.205.150.22', 12)
# (u'163.205.154.12', 6)
# (u'163.205.156.16', 26)
# (u'163.205.16.100', 24)
# (u'163.205.16.104', 32)
# (u'163.205.16.29', 6)
# (u'163.205.16.75', 6)
# (u'163.205.16.90', 18)
# (u'163.205.16.98', 12)
# (u'163.205.162.54', 1)
# (u'163.205.164.13', 10)
# (u'163.205.166.15', 12)
# (u'163.205.166.3', 6)
# (u'163.205.18.20', 16)
# (u'163.205.18.227', 24)
# (u'163.205.18.47', 12)
# (u'163.205.18.89', 12)
# (u'163.205.180.17', 23)
# (u'163.205.180.32', 29)
# (u'163.205.180.55', 65)
# (u'163.205.181.50', 24)
# (u'163.205.19.20', 54)
# (u'163.205.19.7', 39)
# (u'163.205.2.100', 12)
# (u'163.205.2.107', 6)
# (u'163.205.2.11', 30)
# (u'163.205.2.167', 6)
# (u'163.205.2.178', 36)
# (u'163.205.2.180', 6)
# (u'163.205.2.196', 13)
# (u'163.205.2.204', 12)
# (u'163.205.23.103', 24)
# (u'163.205.23.117', 6)
# (u'163.205.23.125', 6)
# (u'163.205.23.133', 26)
# (u'163.205.23.193', 7)
# (u'163.205.23.41', 12)
# (u'163.205.23.71', 12)
# (u'163.205.23.72', 14)
# (u'163.205.23.74', 6)
# (u'163.205.23.76', 18)
# (u'163.205.23.93', 48)
# (u'163.205.3.104', 73)
# (u'163.205.3.2', 7)
# (u'163.205.3.38', 18)
# (u'163.205.3.43', 12)
# (u'163.205.3.48', 12)
# (u'163.205.42.20', 30)
# (u'163.205.46.95', 30)
# (u'163.205.54.76', 38)
# (u'163.205.69.17', 17)
# (u'163.205.78.66', 12)
# (u'163.205.80.41', 18)
# (u'163.206.10.30', 13)
# (u'163.206.104.17', 12)
# (u'163.206.104.34', 12)
# (u'163.206.104.37', 7)
# (u'163.206.104.94', 66)
# (u'163.206.112.26', 6)
# (u'163.206.113.62', 12)
# (u'163.206.130.137', 5)
# (u'163.206.130.169', 1)
# (u'163.206.130.191', 22)
# (u'163.206.130.46', 19)
# (u'163.206.130.48', 6)
# (u'163.206.130.62', 24)
# (u'163.206.130.93', 12)
# (u'163.206.133.51', 18)
# (u'163.206.133.52', 18)
# (u'163.206.136.1', 6)
# (u'163.206.137.10', 7)
# (u'163.206.137.11', 6)
# (u'163.206.137.12', 2)
# (u'163.206.137.16', 18)
# (u'163.206.137.21', 98)
# (u'163.206.137.6', 2)
# (u'163.206.140.4', 6)
# (u'163.206.140.6', 7)
# (u'163.206.150.30', 1)
# (u'163.206.150.69', 60)
# (u'163.206.150.71', 13)
# (u'163.206.204.11', 6)
# (u'163.206.213.10', 1)
# (u'163.206.43.11', 11)
# (u'163.206.54.130', 6)
# (u'163.206.89.4', 184)
# (u'163.209.138.16', 6)
# (u'163.234.140.22', 21)
# (u'164.115.29.183', 6)
# (u'164.117.197.214', 4)
# (u'164.117.97.48', 1)
# (u'164.145.2.133', 15)
# (u'164.150.66.27', 17)
# (u'165.187.66.2', 5)
# (u'165.213.131.21', 1)
# (u'165.220.36.2', 1)
# (u'165.246.11.65', 1)
# (u'165.254.152.65', 8)
# (u'165.27.101.222', 5)
# (u'165.29.244.17', 16)
# (u'166.32.74.137', 8)
# (u'166.44.2.25', 8)
# (u'166.66.26.38', 13)
# (u'166.82.249.11', 14)
# (u'167.21.71.198', 1)
# (u'168.150.253.69', 1)
# (u'168.80.44.87', 10)
# (u'168.87.24.40', 24)
# (u'168.95.191.15', 2)
# (u'168.95.246.219', 7)
# (u'169.140.8.195', 11)
# (u'169.15.2.68', 5)
# (u'17.127.18.23', 4)
# (u'170.104.203.21', 13)
# (u'170.181.150.151', 16)
# (u'192.106.190.55', 5)
# (u'192.112.22.119', 22)
# (u'192.112.22.166', 12)
# (u'192.112.22.167', 12)
# (u'192.112.22.239', 18)
# (u'192.112.239.127', 6)
# (u'192.112.239.177', 6)
# (u'192.112.239.200', 6)
# (u'192.112.239.213', 12)
# (u'192.127.22.151', 12)
# (u'192.127.22.55', 32)
# (u'192.127.28.16', 5)
# (u'192.127.30.115', 2)
# (u'192.134.163.34', 3)
# (u'192.148.226.83', 4)
# (u'192.150.115.120', 26)
# (u'192.190.49.127', 14)
# (u'192.190.49.128', 11)
# (u'192.192.147.185', 3)
# (u'192.195.197.57', 44)
# (u'192.197.64.57', 11)
# (u'192.213.154.220', 4)
# (u'192.214.82.67', 25)
# (u'192.216.64.153', 10)
# (u'192.227.35.67', 11)
# (u'192.228.240.4', 3)
# (u'192.246.118.62', 3)
# (u'192.247.19.117', 50)
# (u'192.252.66.34', 6)
# (u'192.253.114.40', 6)
# (u'192.36.226.111', 6)
# (u'192.43.251.145', 21)
# (u'192.51.251.35', 2)
# (u'192.55.134.3', 4)
# (u'192.67.113.130', 18)
# (u'192.67.113.95', 5)
# (u'193.112.165.160', 2)
# (u'193.132.228.150', 20)
# (u'193.133.120.20', 8)
# (u'193.141.107.78', 1)
# (u'193.141.60.59', 3)
# (u'193.143.192.92', 9)
# (u'193.146.250.146', 2)
# (u'193.178.53.180', 2)
# (u'193.221.170.196', 5)
# (u'193.224.48.186', 7)
# (u'193.232.22.86', 1)
# (u'193.42.224.161', 2)
# (u'193.45.115.28', 19)
# (u'193.59.51.15', 8)
# (u'193.70.248.32', 18)
# (u'193.76.221.3', 9)
# (u'193.81.242.30', 13)
# (u'193.83.20.61', 7)
# (u'193.87.225.45', 11)
# (u'193.88.52.101', 18)
# (u'193.88.88.9', 9)
# (u'193.97.36.47', 8)
# (u'194.129.164.223', 1)
# (u'194.129.192.53', 7)
# (u'194.129.5.18', 1)
# (u'194.137.26.2', 9)
# (u'194.142.184.17', 1)
# (u'194.16.73.52', 2)
# (u'194.16.79.113', 1)
# (u'194.166.40.217', 2)
# (u'194.2.193.100', 7)
# (u'194.2.214.74', 12)
# (u'194.20.184.125', 7)
# (u'194.21.19.200', 2)
# (u'194.71.117.22', 3)
# (u'194.72.181.105', 16)
# (u'194.72.181.97', 6)
# (u'194.72.183.137', 6)
# (u'194.72.34.200', 3)
# (u'194.72.68.183', 3)
# (u'194.81.170.1', 11)
# (u'194.90.19.68', 1)
# (u'194.97.78.24', 7)
# (u'196.14.218.106', 2)
# (u'196.23.39.16', 3)
# (u'196.4.24.150', 12)
# (u'198-112-179-1.ichange.com', 6)
# (u'198.104.162.30', 1)
# (u'198.105.193.47', 20)
# (u'198.108.150.51', 7)
# (u'198.113.160.87', 13)
# (u'198.134.145.23', 12)
# (u'198.140.144.150', 4)
# (u'198.142.52.25', 2)
# (u'198.142.9.12', 5)
# (u'198.165.3.2', 8)
# (u'198.168.48.41', 7)
# (u'198.189.52.107', 21)
# (u'198.209.180.235', 11)
# (u'198.209.88.42', 14)
# (u'198.209.89.121', 26)
# (u'198.213.190.86', 4)
# (u'198.248.59.13', 36)
# (u'198.250.198.42', 6)
# (u'198.252.88.171', 48)
# (u'198.30.207.209', 6)
# (u'198.30.29.129', 9)
# (u'198.4.94.6', 1)
# (u'198.53.152.141', 5)
# (u'198.53.161.50', 5)
# (u'198.53.165.111', 70)
# (u'198.53.172.23', 12)
# (u'198.53.20.3', 1)
# (u'198.59.150.174', 44)
# (u'198.6.245.66', 1)
# (u'198.6.9.136', 19)
# (u'198.62.139.36', 3)
# (u'198.70.174.198', 17)
# (u'198.70.185.114', 31)
# (u'198.70.185.116', 14)
# (u'198.70.210.47', 4)
# (u'198.70.240.25', 1)
# (u'198.76.175.66', 5)
# (u'198.77.113.34', 37)
# (u'198.78.48.38', 2)
# (u'198.83.140.48', 7)
# (u'198.83.140.62', 13)
# (u'198.83.214.29', 5)
# (u'198.99.237.123', 12)
# (u'199-186.ico.att.net', 3)
# (u'199.0.14.45', 1)
# (u'199.1.106.13', 8)
# (u'199.1.106.15', 8)
# (u'199.1.106.17', 11)
# (u'199.1.106.20', 11)
# (u'199.1.106.24', 8)
# (u'199.1.106.6', 21)
# (u'199.117.159.32', 4)
# (u'199.120.116.41', 16)
# (u'199.166.232.111', 6)
# (u'199.166.254.11', 14)
# (u'199.166.254.12', 2)
# (u'199.166.254.13', 2)
# (u'199.166.254.16', 5)
# (u'199.166.254.17', 1)
# (u'199.166.6.130', 3)
# (u'199.17.232.106', 4)
# (u'199.171.22.44', 3)
# (u'199.171.27.219', 8)
# (u'199.182.75.129', 1)
# (u'199.183.254.15', 7)
# (u'199.190.97.100', 16)
# (u'199.199.168.54', 2)
# (u'199.199.168.70', 6)
# (u'199.2.205.168', 4)
# (u'199.201.186.104', 51)
# (u'199.227.10.143', 4)
# (u'199.45.127.119', 2)
# (u'199.48.9.176', 5)
# (u'199.5.172.217', 10)
# (u'199.67.37.206', 2)
# (u'199.67.49.22', 5)
# (u'199.67.49.23', 5)
# (u'199.67.49.25', 21)
# (u'199.67.53.202', 9)
# (u'199.72.95.162', 8)
# (u'199.78.120.2', 2)
# (u'199.78.224.27', 13)
# (u'199.78.224.29', 13)
# (u'199.90.218.62', 23)
# (u'199.93.170.211', 17)
# (u'199.93.170.212', 28)
# (u'199.93.170.225', 20)
# (u'20.7.170.95', 2)
# (u'200.17.4.201', 2)
# (u'200.246.227.120', 8)
# (u'200.246.227.133', 5)
# (u'200.246.227.143', 6)
# (u'200.246.227.69', 8)
# (u'200.246.240.75', 30)
# (u'202.13.236.91', 13)
# (u'202.2.4.5', 4)
# (u'202.21.140.16', 7)
# (u'202.234.12.3', 18)
# (u'202.239.121.10', 9)
# (u'202.239.2.100', 1)
# (u'202.239.22.66', 19)
# (u'202.244.2.71', 3)
# (u'202.244.22.68', 15)
# (u'202.244.224.73', 21)
# (u'202.244.224.77', 4)
# (u'202.244.224.85', 9)
# (u'202.244.225.74', 6)
# (u'202.244.226.92', 4)
# (u'202.244.227.71', 9)
# (u'202.244.231.143', 13)
# (u'202.244.231.146', 1)
# (u'202.244.231.52', 33)
# (u'202.244.46.131', 74)
# (u'202.245.29.72', 4)
# (u'202.248.44.130', 6)
# (u'202.248.77.10', 27)
# (u'202.249.142.4', 6)
# (u'202.252.105.119', 9)
# (u'202.32.48.43', 10)
# (u'202.32.8.81', 17)
# (u'202.33.55.71', 3)
# (u'202.36.124.90', 1)
# (u'202.37.110.37', 1)
# (u'202.51.128.83', 4)
# (u'202.96.32.54', 16)
# (u'203.10.67.29', 4)
# (u'203.248.72.16', 8)
# (u'203.249.126.6', 5)
# (u'203.251.193.32', 6)
# (u'203.255.112.33', 7)
# (u'203.255.208.24', 15)
# (u'203.63.58.133', 1)
# (u'203.63.58.134', 6)
# (u'203.63.58.136', 9)
# (u'203.63.58.137', 1)
# (u'203.9.0.20', 6)
# (u'204.101.235.25', 2)
# (u'204.101.235.4', 9)
# (u'204.101.77.110', 6)
# (u'204.101.85.101', 9)
# (u'204.112.94.51', 4)
# (u'204.112.94.59', 11)
# (u'204.119.59.130', 1)
# (u'204.120.134.10', 1)
# (u'204.120.34.200', 5)
# (u'204.134.97.30', 10)
# (u'204.138.95.106', 6)
# (u'204.138.95.111', 22)
# (u'204.145.251.3', 8)
# (u'204.147.236.17', 13)
# (u'204.149.228.64', 3)
# (u'204.149.228.72', 4)
# (u'204.149.90.43', 3)
# (u'204.157.204.213', 4)
# (u'204.164.190.112', 18)
# (u'204.170.30.11', 1)
# (u'204.170.97.175', 20)
# (u'204.174.10.4', 13)
# (u'204.174.10.5', 9)
# (u'204.174.70.33', 6)
# (u'204.174.70.36', 5)
# (u'204.176.127.20', 1)
# (u'204.176.215.64', 1)
# (u'204.176.47.150', 14)
# (u'204.179.110.29', 14)
# (u'204.180.235.13', 6)
# (u'204.182.67.69', 4)
# (u'204.184.20.252', 1)
# (u'204.189.54.252', 3)
# (u'204.19.121.111', 44)
# (u'204.19.123.34', 24)
# (u'204.19.123.40', 1)
# (u'204.19.238.205', 2)
# (u'204.192.8.15', 9)
# (u'204.199.131.107', 5)
# (u'204.199.131.77', 9)
# (u'204.209.114.43', 19)
# (u'204.209.114.50', 6)
# (u'204.212.63.40', 1)
# (u'204.213.177.9', 8)
# (u'204.221.10.194', 22)
# (u'204.234.211.11', 10)
# (u'204.234.211.15', 9)
# (u'204.235.85.13', 1)
# (u'204.239.157.2', 9)
# (u'204.240.48.13', 3)
# (u'204.242.188.9', 38)
# (u'204.244.4.6', 14)
# (u'204.249.225.120', 23)
# (u'204.249.225.140', 13)
# (u'204.249.225.155', 6)
# (u'204.249.225.66', 9)
# (u'204.250.139.151', 7)
# (u'204.250.21.33', 1)
# (u'204.250.29.105', 6)
# (u'204.251.184.103', 12)
# (u'204.252.77.17', 7)
# (u'204.253.27.51', 1)
# (u'204.255.176.111', 1)
# (u'204.255.214.5', 1)
# (u'204.30.78.136', 5)
# (u'204.32.87.135', 13)
# (u'204.34.23.106', 2)
# (u'204.57.131.23', 9)
# (u'204.57.209.41', 2)
# (u'204.62.245.27', 5)
# (u'204.62.245.32', 8)
# (u'204.64.181.99', 6)
# (u'204.64.198.104', 13)
# (u'204.7.132.72', 27)
# (u'204.71.8.107', 7)
# (u'204.71.90.6', 1)
# (u'204.78.3.8', 9)
# (u'204.87.118.91', 105)
# (u'204.92.246.3', 4)
# (u'204.92.48.29', 5)
# (u'204.92.51.21', 8)
# (u'204.95.4.101', 6)
# (u'204.97.74.34', 16)
# (u'205.133.101.146', 8)
# (u'205.133.22.97', 29)
# (u'205.134.237.142', 8)
# (u'205.134.237.154', 8)
# (u'205.134.237.251', 8)
# (u'205.138.34.13', 4)
# (u'205.138.44.20', 15)
# (u'205.138.53.102', 5)
# (u'205.139.160.12', 1)
# (u'205.139.169.146', 8)
# (u'205.139.169.2', 8)
# (u'205.139.35.43', 6)
# (u'205.139.62.22', 17)
# (u'205.139.62.38', 5)
# (u'205.143.66.162', 6)
# (u'205.148.198.204', 10)
# (u'205.151.62.22', 6)
# (u'205.156.196.77', 9)
# (u'205.160.230.66', 8)
# (u'205.161.163.25', 30)
# (u'205.162.171.107', 22)
# (u'205.164.211.13', 6)
# (u'205.164.211.21', 2)
# (u'205.164.211.31', 9)
# (u'205.164.211.45', 20)
# (u'205.173.169.5', 2)
# (u'205.173.249.21', 35)
# (u'205.173.249.35', 6)
# (u'205.184.141.83', 2)
# (u'205.184.161.45', 6)
# (u'205.188.1.238', 8)
# (u'205.188.2.118', 5)
# (u'205.196.51.2', 4)
# (u'205.205.27.117', 2)
# (u'205.205.27.120', 4)
# (u'205.206.118.111', 4)
# (u'205.206.157.2', 5)
# (u'205.216.179.59', 14)
# (u'205.218.98.61', 6)
# (u'205.219.138.161', 13)
# (u'205.229.177.30', 5)
# (u'205.246.16.104', 6)
# (u'206.12.170.230', 3)
# (u'206.24.43.12', 9)
# (u'206.26.6.41', 9)
# (u'206.27.2.47', 13)
# (u'206.27.236.116', 14)
# (u'206.42.112.202', 8)
# (u'206.43.171.248', 9)
# (u'206.43.37.85', 8)
# (u'206.80.226.13', 15)
# (u'206.9.144.3', 10)
# (u'206.9.64.101', 2)
# (u'3tsp22.calypso.com', 1)
# (u'52.28.med.umich.edu', 34)
# (u'63-60.dse.vic.gov.au', 1)
# (u'6k066.netusa1.net', 24)
# (u'a01.nationalnet.com', 19)
# (u'a03.nationalnet.com', 9)
# (u'a109020.atl1.as.crl.com', 12)
# (u'a1fel.feld.cvut.cz', 1)
# (u'a1p27.connect.net', 4)
# (u'a1p35.connect.net', 32)
# (u'a25.ics.tdsnet.com', 4)
# (u'a5074.dial.tip.net', 7)
# (u'a6r211.cba.uc.edu', 11)
# (u'a8051.dial.tip.net', 2)
# (u'aaiip.minvenw.nl', 7)
# (u'aaisim.cts.com', 13)
# (u'ab.edvz.tuwien.ac.at', 4)
# (u'ab079.du.pipex.com', 23)
# (u'abb-annex1-slip33.cis.mcmaster.ca', 1)
# (u'abc.ksu.ksu.edu', 13)
# (u'aboone.gsfc.nasa.gov', 32)
# (u'abyss.sni-usa.com', 37)
# (u'ac009.pool.dircon.co.uk', 2)
# (u'ac202-2.chemie.unibas.ch', 11)
# (u'academy.bastad.se', 32)
# (u'academy.ppp.america.com', 6)
# (u'acme.freenet.columbus.oh.us', 9)
# (u'acquinas.netmind.com', 3)
# (u'ad002.pool.dircon.co.uk', 26)
# (u'ad01-012.compuserve.com', 2)
# (u'ad01-029.compuserve.com', 6)
# (u'ad02-010.compuserve.com', 16)
# (u'ad02-024.compuserve.com', 6)
# (u'ad02-064.compuserve.com', 8)
# (u'ad03-008.compuserve.com', 9)
# (u'ad03-023.compuserve.com', 12)
# (u'ad04-031.compuserve.com', 13)
# (u'ad041.du.pipex.com', 3)
# (u'ad05-007.compuserve.com', 1)
# (u'ad05-041.compuserve.com', 13)
# (u'ad05-046.compuserve.com', 1)
# (u'ad054.du.pipex.com', 37)
# (u'ad057.du.pipex.com', 1)
# (u'ad06-009.compuserve.com', 12)
# (u'ad06-035.compuserve.com', 1)
# (u'ad07-005.compuserve.com', 12)
# (u'ad08-006.compuserve.com', 9)
# (u'ad08-029.compuserve.com', 10)
# (u'ad09-009.compuserve.com', 9)
# (u'ad09-013.compuserve.com', 8)
# (u'ad09-014.compuserve.com', 1)
# (u'ad09-042.compuserve.com', 11)
# (u'ad10-020.compuserve.com', 8)
# (u'ad11-013.compuserve.com', 6)
# (u'ad11-053.compuserve.com', 3)
# (u'ad12-023.compuserve.com', 2)
# (u'ad12-037.compuserve.com', 8)
# (u'ad12-063.compuserve.com', 6)
# (u'ad13-011.compuserve.com', 2)
# (u'ad13-023.compuserve.com', 5)
# (u'ad13-031.compuserve.com', 10)
# (u'ad13-037.compuserve.com', 1)
# (u'ad13-054.compuserve.com', 6)
# (u'ad14-030.compuserve.com', 16)
# (u'ad14-047.compuserve.com', 11)
# (u'ad14-048.compuserve.com', 1)
# (u'ad15-002.compuserve.com', 8)
# (u'ad15-010.compuserve.com', 21)
# (u'ad15-022.compuserve.com', 1)
# (u'ad15-025.compuserve.com', 4)
# (u'ad16-011.compuserve.com', 16)
# (u'ad16-034.compuserve.com', 6)
# (u'ad16-049.compuserve.com', 1)
# (u'ad16-051.compuserve.com', 31)
# (u'ad16-071.compuserve.com', 8)
# (u'ad18-029.compuserve.com', 9)
# (u'ad19-015.compuserve.com', 3)
# (u'ad21-002.compuserve.com', 6)
# (u'ad21-011.compuserve.com', 3)
# (u'ad21-020.compuserve.com', 14)
# (u'ad21-022.compuserve.com', 3)
# (u'ad21-029.compuserve.com', 23)
# (u'ad21-042.compuserve.com', 10)
# (u'ad21-053.compuserve.com', 14)
# (u'ad21-058.compuserve.com', 4)
# (u'ad22-043.compuserve.com', 6)
# (u'ad22-057.compuserve.com', 1)
# (u'adare.interlog.com', 2)
# (u'aero.snds.com', 24)
# (u'afld.montrealnet.ca', 10)
# (u'agora.carleton.ca', 2)
# (u'agwr6-02.sp.trw.com', 22)
# (u'aharris.hass.usu.edu', 56)
# (u'ai117.du.pipex.com', 2)
# (u'ai124.du.pipex.com', 1)
# (u'ai144.du.pipex.com', 16)
# (u'ainet.com', 1)
# (u'aj143.du.pipex.com', 4)
# (u'ak040.du.pipex.com', 6)
# (u'ak181.du.pipex.com', 8)
# (u'akmac0.ee.ous.ac.jp', 11)
# (u'al-134-145.al.wpafb.af.mil', 102)
# (u'al-134-166.al.wpafb.af.mil', 7)
# (u'aladdin-3.slip.bradley.edu', 5)
# (u'aladdin.esu10.k12.ne.us', 13)
# (u'albundy.demon.co.uk', 8)
# (u'alfa.ist.utl.pt', 23)
# (u'alinga.newcastle.edu.au', 6)
# (u'alize.ere.umontreal.ca', 6)
# (u'alonat-ppp.serv.net', 8)
# (u'alpha.acast.nova.edu', 3)
# (u'alpha1.astro.ruhr-uni-bochum.de', 1)
# (u'alphate.dial.eunet.ch', 7)
# (u'alx27.ecn.purdue.edu', 86)
# (u'amdext.amd.com', 5)
# (u'amraam.comms.unsw.edu.au', 20)
# (u'amsaa-spring.arl.mil', 21)
# (u'amsterdam.knoware.nl', 8)
# (u'an19.lisp.com', 8)
# (u'an35.lisp.com', 6)
# (u'ana0020.deltanet.com', 27)
# (u'anc-p2-70.alaska.net', 13)
# (u'andromeda.tctice.toyota-ct.ac.jp', 9)
# (u'angelou.ucet.ufl.edu', 1)
# (u'annex002.ridgecrest.ca.us', 13)
# (u'annex012.ridgecrest.ca.us', 8)
# (u'annex029.ridgecrest.ca.us', 1)
# (u'annex041.ridgecrest.ca.us', 6)
# (u'annex1p18.sdsu.edu', 9)
# (u'annex2p10.sdsu.edu', 6)
# (u'annexr2-22.slip.uni-koeln.de', 8)
# (u'anonymous.chevron.com', 11)
# (u'anp20.intercon.net', 13)
# (u'anp22.intercon.net', 8)
# (u'antares.omsi.edu', 11)
# (u'antrim.netkonect.co.uk', 5)
# (u'apci.com', 73)
# (u'apocalypse.lpl.arizona.edu', 34)
# (u'apollo.commnet.edu', 3)
# (u'apollo.sfsu.edu', 12)
# (u'apollo.stevens-tech.edu', 5)
# (u'apollo.vsb.cz', 5)
# (u'aporat.dtek.chalmers.se', 5)
# (u'apple.pyrotechnics.com', 43)
# (u'apple1.starpaging.com', 5)
# (u'aragorn183.acns.nwu.edu', 2)
# (u'araras.mec.puc-rio.br', 6)
# (u'arcade-slip8.dynamic.usit.net', 11)
# (u'arcade-slip9.dynamic.usit.net', 20)
# (u'arcadia.cs.rmit.edu.au', 87)
# (u'argeonet.via.at', 11)
# (u'arhppp17.uni-c.dk', 6)
# (u'aries.dnp.co.jp', 35)
# (u'aries.meaddata.com', 16)
# (u'aristotle.algonet.se', 16)
# (u'armorfiends.ee.up.ac.za', 5)
# (u'arn102.neocom.ca', 18)
# (u'arsenal.com', 8)
# (u'arts.usask.ca', 2)
# (u'arwen.unibe.ch', 3)
# (u'as2511-2.sl012.cns.vt.edu', 11)
# (u'as2511-6.sl006.cns.vt.edu', 1)
# (u'asd04-17.dial.xs4all.nl', 11)
# (u'asd06-17.dial.xs4all.nl', 14)
# (u'ashanti.ppp.america.com', 6)
# (u'asn16.whidbey.net', 8)
# (u'asn24.whidbey.net', 4)
# (u'asn54.whidbey.net', 4)
# (u'asn8.whidbey.net', 8)
# (u'asobota.lerc.nasa.gov', 3)
# (u'asst-mgr.uchicago.edu', 31)
# (u'ast-4.eushc.org', 8)
# (u'astro.aeem.iastate.edu', 4)
# (u'astro2.astro.uni.wroc.pl', 9)
# (u'asy136.sicoar.com', 6)
# (u'asy137.sicoar.com', 11)
# (u'async1.ts-bangor.caps.maine.edu', 1)
# (u'async12.ts-bangor.caps.maine.edu', 1)
# (u'async14.city-net.com', 4)
# (u'async3.ts-bangor.caps.maine.edu', 1)
# (u'async4.ts-bangor.caps.maine.edu', 2)
# (u'async5.znet.augusta.ga.us', 11)
# (u'async50.ts-p-caps.caps.maine.edu', 14)
# (u'async77.async.duke.edu', 4)
# (u'async8-16.remote.ualberta.ca', 4)
# (u'asynca3.chatham.ciaccess.com', 30)
# (u'at728.qmced.ac.uk', 6)
# (u'atc.eag.unisysgsg.com', 16)
# (u'ath-gw7.hol.gr', 42)
# (u'ativan.musical.net', 22)
# (u'atlanti.dial.eunet.ch', 1)
# (u'atlantis.actrix.gen.nz', 3)
# (u'aud2.net.org', 14)
# (u'aun.uninett.no', 20)
# (u'aurora.eexi.gr', 1)
# (u'austen.omsi.edu', 16)
# (u'aux60.plano.net', 4)
# (u'azclimate.la.asu.edu', 5)
# (u'b-08.das.mcgill.ca', 1)
# (u'b3.cyberspy.com', 13)
# (u'b37at2a-dyn-02.mit.edu', 3)
# (u'babylon5.arlut.utexas.edu', 78)
# (u'badboy.iprolink.ch', 6)
# (u'bagira.informatik.fh-hamburg.de', 2)
# (u'balder.wwic.com', 8)
# (u'banjo.nc5.infi.net', 1)
# (u'barb.wchat.on.ca', 20)
# (u'barcom.earthlink.net', 8)
# (u'barnton.u-net.com', 11)
# (u'bart.chem-eng.nwu.edu', 5)
# (u'bart.mv.com', 6)
# (u'bass.hooked.net', 67)
# (u'bastion.oecd.org', 35)
# (u'bastuba.ite.his.se', 1)
# (u'batch2164.ucr.edu', 23)
# (u'batemant.nbnet.nb.ca', 1)
# (u'bbs.mpcs.com', 20)
# (u'bbuig150.unisys.com', 10)
# (u'bcfreenet.seflin.lib.fl.us', 39)
# (u'bdurgin.wpi.edu', 7)
# (u'beastie-ppp8.knoware.nl', 9)
# (u'beastie.knoware.nl', 3)
# (u'beglinger.dial-up.bdt.com', 5)
# (u'beliveau.hec.ca', 5)
# (u'bend7.bendnet.com', 8)
# (u'bendel.demon.co.uk', 14)
# (u'benny.westimg.com', 4)
# (u'bensmtp.ksc.nasa.gov', 8)
# (u'benson.nadn.navy.mil', 12)
# (u'beorn.bitmailer.com', 13)
# (u'berlin.snafu.de', 4)
# (u'beta.xerox.com', 1)
# (u'bettong.client.uq.oz.au', 60)
# (u'bianca.osc.on.ca', 1)
# (u'bianca.sdd.trw.com', 3)
# (u'biblio.etse.urv.es', 4)
# (u'big-bird.pinc.com', 24)
# (u'bilbo.ccla.lib.fl.us', 6)
# (u'bill.dra.com', 8)
# (u'bioms.ag.unr.edu', 12)
# (u'bips.eecs.berkeley.edu', 4)
# (u'bissett.mi.net', 13)
# (u'bit.omsi.edu', 34)
# (u'bjk.olivetti.za', 14)
# (u'bjones.oz.net', 9)
# (u'blacksheep.pscni.nasa.gov', 10)
# (u'blitz.ethz.ch', 8)
# (u'blues.surf.tach.net', 16)
# (u'blv-pm0-ip23.halcyon.com', 2)
# (u'blv-pm1-ip16.halcyon.com', 1)
# (u'blv-pm10-ip13.halcyon.com', 4)
# (u'blv-pm10-ip8.halcyon.com', 8)
# (u'blv-pm2-ip13.halcyon.com', 11)
# (u'blv-pm2-ip2.halcyon.com', 10)
# (u'bne01.world.net', 53)
# (u'bne02.world.net', 15)
# (u'bne04.world.net', 7)
# (u'bngrppp39.epix.net', 19)
# (u'bngrppp50.epix.net', 4)
# (u'bocagate.bocaraton.ibm.com', 17)
# (u'bombasto.informatik.rwth-aachen.de', 6)
# (u'bos1d.delphi.com', 4)
# (u'bos1e.delphi.com', 1)
# (u'bos1f.delphi.com', 1)
# (u'bowwow.physics.ucsb.edu', 3)
# (u'bphy90.kfunigraz.ac.at', 3)
# (u'breambay.igrin.co.nz', 2)
# (u'briscoet.jsc.nasa.gov', 5)
# (u'brndts05-p02.mts.net', 6)
# (u'bryton.rand.org', 22)
# (u'bslab39.busfac.calpoly.edu', 19)
# (u'bsmith.intnet.net', 16)
# (u'bud.tic.ab.ca', 8)
# (u'budapest.ozonline.com.au', 5)
# (u'buffnet3.buffnet.net', 1)
# (u'buleria.dit.upm.es', 12)
# (u'burke.nadn.navy.mil', 1)
# (u'burwell.licor.com', 16)
# (u'bway-slip11.dynamic.usit.net', 5)
# (u'bwilson.dial-up.bdt.com', 8)
# (u'c-j-seymour.unh.edu', 8)
# (u'c1122.utc.servtech.com', 20)
# (u'c2.ptw.com', 1)
# (u'c3.reach.net', 33)
# (u'c8.reach.net', 7)
# (u'cad103.cadvision.com', 10)
# (u'cad158.cadvision.com', 4)
# (u'cad168.cadvision.com', 6)
# (u'cad176.cadvision.com', 8)
# (u'cad179.cadvision.com', 4)
# (u'cad211.cadvision.com', 11)
# (u'cafe.ws7.kosone.com', 9)
# (u'cafepc2.intecc.co.uk', 16)
# (u'cais2.cais.com', 3)
# (u'calvin.stemnet.nf.ca', 10)
# (u'cambridge.village.com', 3)
# (u'cap1.capaccess.org', 5)
# (u'capp.cap.se', 26)
# (u'carlton.innotts.co.uk', 71)
# (u'carval.zynet.co.uk', 4)
# (u'castles13.castles.com', 8)
# (u'cba_803.sdsu.edu', 36)
# (u'cbe8.cbe.uiowa.edu', 5)
# (u'cbkpm1-d129.atcon.com', 6)
# (u'cc.math.uconn.edu', 3)
# (u'cc9.uu.net', 1)
# (u'ccfews03.center.osaka-u.ac.jp', 17)
# (u'ccnbak.ccnmuc.net', 18)
# (u'cdfsga.fnal.gov', 14)
# (u'cdr.vitinc.com', 11)
# (u'cfaco2.harvard.edu', 11)
# (u'cft2.ppp245.cftnet.com', 1)
# (u'cft2.ppp248.cftnet.com', 11)
# (u'cft6.ppp244.cftnet.com', 3)
# (u'cg1.psych.arizona.edu', 5)
# (u'cgohpx02.nppdnet.com', 4)
# (u'cgy-p8.supernet.ab.ca', 18)
# (u'chaos.kulnet.kuleuven.ac.be', 2)
# (u'chaos.michsb.trw.com', 31)
# (u'chapman.execpc.com', 14)
# (u'charlotte.anu.edu.au', 29)
# (u'charon.hipsys.co.za', 1)
# (u'chbb-149.ait.ac.nz', 19)
# (u'chi017.wwa.com', 1)
# (u'chiltern.u-net.com', 9)
# (u'chip.ucdavis.edu', 3)
# (u'chispa.planet.net', 3)
# (u'chonbuknms.chonbuk.ac.kr', 1)
# (u'chum.hooked.net', 8)
# (u'cindy.yamato.ibm.co.jp', 12)
# (u'cipr-tech2.mgh.harvard.edu', 3)
# (u'cirrus.actrix.gen.nz', 14)
# (u'cis-ts4-slip7.cis.brown.edu', 3)
# (u'cis.hzeeland.nl', 3)
# (u'cispc12.jrc.it', 8)
# (u'citynet.ci.la.ca.us', 14)
# (u'ck000.pr.mcs.net', 12)
# (u'ckurta.lerc.nasa.gov', 8)
# (u'claris2.claris.com', 4)
# (u'cleo.murdoch.edu.au', 7)
# (u'client-71-114.online.apple.com', 2)
# (u'client-71-240.online.apple.com', 15)
# (u'client-71-69.online.apple.com', 5)
# (u'client16.sedona.net', 6)
# (u'cliffy.lfwc.lockheed.com', 23)
# (u'clives.easynet.co.uk', 6)
# (u'clsmppp10.epix.net', 6)
# (u'clts1-10.cin.net', 9)
# (u'clwfl2-1.gate.net', 11)
# (u'cn14.ppp.synergy.net', 2)
# (u'cn22.ppp.synergy.net', 8)
# (u'cnaef.mnsinc.com', 8)
# (u'cnct.com', 10)
# (u'cnefw.nctsl.navy.mil', 2)
# (u'cnsmac17.jcu.edu.au', 9)
# (u'cnsmac18.jcu.edu.au', 9)
# (u'cnsmac9.jcu.edu.au', 4)
# (u'coa.shape.nato.int', 8)
# (u'cobbbcb.gtri.gatech.edu', 11)
# (u'cobra.umd.edu', 8)
# (u'cocoa06.ksc.nasa.gov', 2)
# (u'cocoapuffs.execpc.com', 8)
# (u'colpc005.estec.esa.nl', 13)
# (u'colt-68.slip.uiuc.edu', 26)
# (u'columbia.acc.brad.ac.uk', 6)
# (u'columbia.ksu.ksu.edu', 6)
# (u'comblab7.ce.gatech.edu', 11)
# (u'confucius.aero.ufl.edu', 3)
# (u'contract.codem.com', 28)
# (u'conveyor.com', 19)
# (u'coopwf93.sp.trw.com', 11)
# (u'copper.compulink.co.uk', 11)
# (u'cornerstone.edu', 1)
# (u'cosmic.gsfc.nasa.gov', 3)
# (u'cosmos.shsw.wisc.edu', 9)
# (u'cosmos03.cfi.waseda.ac.jp', 6)
# (u'cossc.gsfc.nasa.gov', 42)
# (u'coulomb.nagaokaut.ac.jp', 6)
# (u'cow_1.dml.georgetown.edu', 4)
# (u'cpmt2.cyberport.net', 2)
# (u'crc1-fddi.cris.com', 15)
# (u'crc2-fddi.cris.com', 59)
# (u'crc3-fddi.cris.com', 19)
# (u'cremer.mit.edu', 15)
# (u'criba.edu.ar', 1)
# (u'crioux.hip.cam.org', 13)
# (u'crk69.pr.mcs.net', 1)
# (u'crl2.crl.com', 8)
# (u'crow.ksc.nasa.gov', 6)
# (u'crs.atw.fullfeed.com', 11)
# (u'crt.doj.gov', 13)
# (u'cruzio.com', 2)
# (u'crystal.ipac.caltech.edu', 3)
# (u'cs-p5.boston.k12.ma.us', 8)
# (u'cs007p06.mtn.micron.net', 10)
# (u'cs1-03.leh.ptd.net', 8)
# (u'cs1-03.wb.ptd.net', 10)
# (u'cs1-04.leh.ptd.net', 7)
# (u'cs125-13.u.washington.edu', 1)
# (u'cs125-16.u.washington.edu', 1)
# (u'cs1p7.ipswichcity.qld.gov.au', 3)
# (u'cs2-15.ior.com', 3)
# (u'cs22-48.usafa.af.mil', 4)
# (u'cs22port.netvoyage.net', 6)
# (u'cs2p7.ipswichcity.qld.gov.au', 17)
# (u'cs3-07.str.ptd.net', 9)
# (u'cs30-103.usafa.af.mil', 10)
# (u'csa.iitsg.nrc.ca', 20)
# (u'csalegw.canon-sales.co.jp', 19)
# (u'csbtsc01.dcrt.nih.gov', 1)
# (u'csc.sctboces.org', 9)
# (u'csdanxp4.med.utoronto.ca', 15)
# (u'csdanxp5.med.utoronto.ca', 6)
# (u'cse.unl.edu', 6)
# (u'csp16.reuna.cl', 11)
# (u'ct-pc10.massey.ac.nz', 2)
# (u'ctj.treng.ornl.gov', 18)
# (u'ctrlw5.eee.ntu.ac.sg', 3)
# (u'cts106.cts.db.erau.edu', 6)
# (u'ctsdug1.jsc.nasa.gov', 21)
# (u'cus119.lds.loral.com', 3)
# (u'cust10.max4.orlando.fl.ms.uu.net', 5)
# (u'cust11.max8.atlanta.ga.ms.uu.net', 4)
# (u'cust12.max3.chicago.il.ms.uu.net', 35)
# (u'cust13.max1.seattle.wa.ms.uu.net', 11)
# (u'cust16.max2.indianapolis.in.ms.uu.net', 12)
# (u'cust16.max7.los-angeles.ca.ms.uu.net', 9)
# (u'cust19.max3.dallas.tx.ms.uu.net', 11)
# (u'cust2.max2.cleveland.oh.ms.uu.net', 9)
# (u'cust22.max1.san-diego.ca.ms.uu.net', 13)
# (u'cust23.max7.cleveland.oh.ms.uu.net', 6)
# (u'cust24.max3.chicago.il.ms.uu.net', 25)
# (u'cust25.max3.chicago.il.ms.uu.net', 87)
# (u'cust26.max3.los-angeles.ca.ms.uu.net', 9)
# (u'cust27.max3.dallas.tx.ms.uu.net', 5)
# (u'cust31.max1.newark.nj.ms.uu.net', 21)
# (u'cust38.max1.san-francisco.ca.ms.uu.net', 11)
# (u'cust43.max9.los-angeles.ca.ms.uu.net', 21)
# (u'cust52.max1.seattle.wa.ms.uu.net', 6)
# (u'cust52.max2.seattle.wa.ms.uu.net', 9)
# (u'cust56.max3.chicago.il.ms.uu.net', 1)
# (u'cust56.max7.boston.ma.ms.uu.net', 12)
# (u'cust56.max8.atlanta.ga.ms.uu.net', 19)
# (u'cust57.max5.new-york.ny.ms.uu.net', 10)
# (u'cust6.max7.boston.ma.ms.uu.net', 28)
# (u'cust60.max2.seattle.wa.ms.uu.net', 4)
# (u'cust62.max1.chicago.il.ms.uu.net', 27)
# (u'cvdyna11.upol.cz', 10)
# (u'cw-pc15.cso.uiuc.edu', 4)
# (u'cwestcot.interserf.net', 2)
# (u'cyber20.imaginet.fr', 3)
# (u'cyberson.pdial.interpath.net', 48)
# (u'cyclom1-1-6.intersource.com', 30)
# (u'cygnus.omsi.edu', 28)
# (u'cyprus.cc.ece.ntua.gr', 1)
# (u'd-ip-21.trends.ca', 21)
# (u'd04.pm1.nisiq.net', 1)
# (u'd113.aksi.net', 2)
# (u'd117.aksi.net', 41)
# (u'd17.rmc.ca', 19)
# (u'd6208.shv.hb.se', 5)
# (u'd7-ts0.amug.org', 9)
# (u'daffy.itsnet.com', 4)
# (u'daha-9-37.ipt.aol.com', 8)
# (u'daisy.mcm.hp.com', 6)
# (u'dal01-07.ppp.iadfw.net', 10)
# (u'dal02-03.ppp.iadfw.net', 66)
# (u'dal02-19.ppp.iadfw.net', 20)
# (u'dal03-05.ppp.iadfw.net', 15)
# (u'dal04-19.ppp.iadfw.net', 10)
# (u'dal05-06.ppp.iadfw.net', 8)
# (u'dal06-20.ppp.iadfw.net', 37)
# (u'dal06.onramp.net', 10)
# (u'dal07-17.ppp.iadfw.net', 11)
# (u'dal08-21.ppp.iadfw.net', 1)
# (u'dal09-24.ppp.iadfw.net', 10)
# (u'dal10-02.ppp.iadfw.net', 78)
# (u'dal105.computek.net', 8)
# (u'dal362.computek.net', 5)
# (u'dal58.fastlane.net', 7)
# (u'dal80.pic.net', 11)
# (u'dalasdon.pic.net', 14)
# (u'daleth18.netaccess.on.ca', 9)
# (u'dallas.mt.cs.cmu.edu', 3)
# (u'danielc.tushaus.com', 16)
# (u'danube.maths.ox.ac.uk', 13)
# (u'das-slip1.harvard.edu', 10)
# (u'das.wang.com', 24)
# (u'datacube.datacube.com', 7)
# (u'datan.sk.uppsala.se', 7)
# (u'dblachly.lerc.nasa.gov', 7)
# (u'dbms-pc6.cis.nctu.edu.tw', 6)
# (u'dbrunell.mindspring.com', 9)
# (u'dca00773.slip.digex.net', 1)
# (u'dcc05499.slip.digex.net', 6)
# (u'dcn69.dcn.davis.ca.us', 9)
# (u'dcn73.dcn.davis.ca.us', 2)
# (u'dd01-024.compuserve.com', 5)
# (u'dd01-030.compuserve.com', 5)
# (u'dd01-056.compuserve.com', 9)
# (u'dd01-060.compuserve.com', 1)
# (u'dd02-002.compuserve.com', 1)
# (u'dd02-011.compuserve.com', 4)
# (u'dd02-019.compuserve.com', 3)
# (u'dd02-027.compuserve.com', 5)
# (u'dd02-030.compuserve.com', 4)
# (u'dd02-037.compuserve.com', 7)
# (u'dd03-010.compuserve.com', 2)
# (u'dd03-037.compuserve.com', 2)
# (u'dd04-011.compuserve.com', 17)
# (u'dd04-052.compuserve.com', 5)
# (u'dd05-004.compuserve.com', 6)
# (u'dd05-019.compuserve.com', 1)
# (u'dd05-030.compuserve.com', 6)
# (u'dd05-047.compuserve.com', 10)
# (u'dd07-001.compuserve.com', 1)
# (u'dd07-042.compuserve.com', 3)
# (u'dd08-010.compuserve.com', 2)
# (u'dd08-039.compuserve.com', 6)
# (u'dd09-002.compuserve.com', 16)
# (u'dd09-036.compuserve.com', 5)
# (u'dd10-010.compuserve.com', 8)
# (u'dd10-011.compuserve.com', 9)
# (u'dd10-031.compuserve.com', 9)
# (u'dd10-057.compuserve.com', 7)
# (u'dd11-017.compuserve.com', 5)
# (u'dd11-033.compuserve.com', 8)
# (u'dd12-021.compuserve.com', 6)
# (u'dd12-025.compuserve.com', 1)
# (u'dd12-048.compuserve.com', 7)
# (u'dd13-001.compuserve.com', 12)
# (u'dd13-008.compuserve.com', 5)
# (u'dd13-016.compuserve.com', 1)
# (u'dd13-048.compuserve.com', 4)
# (u'dd14-014.compuserve.com', 1)
# (u'dd14-054.compuserve.com', 1)
# (u'dd15-003.compuserve.com', 2)
# (u'dd15-010.compuserve.com', 11)
# (u'dd15-033.compuserve.com', 2)
# (u'dd15-034.compuserve.com', 3)
# (u'dd15-038.compuserve.com', 4)
# (u'dd16-065.compuserve.com', 11)
# (u'dd17-020.compuserve.com', 4)
# (u'dd18-019.compuserve.com', 1)
# (u'dd18-021.compuserve.com', 5)
# (u'dd19-008.compuserve.com', 2)
# (u'dd19-025.compuserve.com', 1)
# (u'dd19-064.compuserve.com', 9)
# (u'dd20-004.compuserve.com', 5)
# (u'dd20-006.compuserve.com', 7)
# (u'dd20-007.compuserve.com', 1)
# (u'dd20-013.compuserve.com', 3)
# (u'dd20-017.compuserve.com', 10)
# (u'dd21-037.compuserve.com', 2)
# (u'dd22-002.compuserve.com', 12)
# (u'dd22-004.compuserve.com', 6)
# (u'dd22-019.compuserve.com', 3)
# (u'dd22-022.compuserve.com', 23)
# (u'dd22-041.compuserve.com', 17)
# (u'dd22-047.compuserve.com', 6)
# (u'dd22-063.compuserve.com', 3)
# (u'dd23-009.compuserve.com', 31)
# (u'dd23-030.compuserve.com', 1)
# (u'dd23-047.compuserve.com', 5)
# (u'dd24-003.compuserve.com', 4)
# (u'dd24-051.compuserve.com', 11)
# (u'ddb3.res.lehigh.edu', 17)
# (u'death.cs.umd.edu', 1)
# (u'deepthought.armory.com', 23)
# (u'default2.sdsc.cerfnet.com', 1)
# (u'defiant.mr.net', 4)
# (u'delacroix.esat.kuleuven.ac.be', 5)
# (u'delevan.oro.net', 4)
# (u'delta-air.com', 13)
# (u'delta.eafit.edu.co', 1)
# (u'demo.niia.net', 8)
# (u'demorgan.uwaterloo.ca', 10)
# (u'demornay.lanl.gov', 2)
# (u'denfield.nadn.navy.mil', 15)
# (u'denise.ele.ufes.br', 2)
# (u'denver.carl.org', 3)
# (u'derec', 96)
# (u'descartes.execpc.com', 3)
# (u'detloff1.bmg.uab.edu', 16)
# (u'dev1.develop1.tafensw.edu.au', 2)
# (u'dfas62.usafa.af.mil', 8)
# (u'dffl5-10.gate.net', 4)
# (u'dffl5-51.gate.net', 6)
# (u'dffl5-6.gate.net', 9)
# (u'dffl6-2.gate.net', 18)
# (u'dffl6-44.gate.net', 42)
# (u'dfklak.slip.lm.com', 9)
# (u'dgable.nifs.ac.jp', 15)
# (u'dharris.interlog.com', 11)
# (u'dhriley.async.csuohio.edu', 2)
# (u'dhs.intnet.net', 11)
# (u'dial-05.roch.millcomm.com', 4)
# (u'dial-17.mpls.millcomm.com', 2)
# (u'dial-6.t1.ncwtmc.sunbelt.net', 6)
# (u'dial-in5.univalle.edu.co', 14)
# (u'dial-ip-11.theramp.net', 28)
# (u'dial-pa1-23.iway.aimnet.com', 6)
# (u'dial-pl1-13.iway.aimnet.com', 31)
# (u'dial0.solutions.net', 6)
# (u'dial02.suba.com', 4)
# (u'dial066.mbnet.mb.ca', 2)
# (u'dial09.lloyd.com', 3)
# (u'dial1-10.cybercom.net', 8)
# (u'dial1.avalon.net', 9)
# (u'dial101.cognet.com', 1)
# (u'dial112.phoenix.net', 5)
# (u'dial12.misha.net', 8)
# (u'dial16.solutions.net', 22)
# (u'dial186049.wbm.ca', 6)
# (u'dial32.phoenix.net', 8)
# (u'dial56.phoenix.net', 9)
# (u'dialin-03.netway.net', 12)
# (u'dialin-128.wustl.edu', 8)
# (u'dialin-ttypb.sky.net', 7)
# (u'dialin-ttyqd.sky.net', 15)
# (u'dialin042.rz.uni-frankfurt.de', 18)
# (u'dialin10.glovalserve.on.ca', 8)
# (u'dialin2.globalserve.on.ca', 8)
# (u'dialin3.wantree.com.au', 8)
# (u'dialin6.eagle.ca', 11)
# (u'dialin9.stdrem.okstate.edu', 5)
# (u'dialip-83.athenet.net', 5)
# (u'dialport-24.sh.lsumc.edu', 82)
# (u'dialup-06.daemon.apana.org.au', 15)
# (u'dialup-064.fyv.intellinet.com', 16)
# (u'dialup-13-c-169.gw.umn.edu', 8)
# (u'dialup-2-112.gw.umn.edu', 10)
# (u'dialup-200.minn.net', 7)
# (u'dialup-3-210.gw.umn.edu', 1)
# (u'dialup-5-100.gw.umn.edu', 1)
# (u'dialup-5-148.gw.umn.edu', 11)
# (u'dialup-pkr-6-16.network.umr.edu', 2)
# (u'dialup-pkr-6-5.network.umr.edu', 20)
# (u'dialup0.afn.org', 29)
# (u'dialup00016.cinet.itl.net', 3)
# (u'dialup004.continet.com', 12)
# (u'dialup013.lava.net', 3)
# (u'dialup10.sos.net', 4)
# (u'dialup104.kersur.net', 9)
# (u'dialup11.fwi.com', 41)
# (u'dialup13.leuven.eunet.be', 2)
# (u'dialup14.fwi.com', 2)
# (u'dialup2.mn.interact.net', 5)
# (u'dialup20.fwi.com', 14)
# (u'dialup23.leuven.eunet.be', 11)
# (u'dialup25.infobahnos.com', 15)
# (u'dialup29.washington.mci.net', 1)
# (u'dialup37.infobahnos.com', 8)
# (u'dialup5.afn.org', 6)
# (u'dialup73.nmia.com', 8)
# (u'dialup778.chicago.mci.net', 43)
# (u'dialup85.nmia.com', 11)
# (u'dialup96-021.swipnet.se', 14)
# (u'dialup97-101.swipnet.se', 5)
# (u'dialupline01.ghgcorp.com', 6)
# (u'dialupline04.ghgcorp.com', 15)
# (u'dialups14.ici.net', 3)
# (u'dick.larc.nasa.gov', 18)
# (u'dino.bci.krakow.pl', 1)
# (u'dip-30.mbay.net', 6)
# (u'dip2.datashopper.dk', 2)
# (u'dip5.datashopper.dk', 10)
# (u'disarray.demon.co.uk', 54)
# (u'disun40.epfl.ch', 1)
# (u'dl1.troja.mff.cuni.cz', 6)
# (u'dlamoreaux.geo.utulsa.edu', 1)
# (u'dlofton.lmk.usace.army.mil', 5)
# (u'dlog.demon.co.uk', 3)
# (u'dmccoy.jsc.nasa.gov', 6)
# (u'dmoc5o.bell.ca', 6)
# (u'dnet026.sat.texas.net', 10)
# (u'dnet044.sat.texas.net', 10)
# (u'dnet047.sat.texas.net', 11)
# (u'dnet058.sat.texas.net', 2)
# (u'dns.uni-trier.de', 12)
# (u'doc.memex.co.uk', 4)
# (u'docclark.demon.co.uk', 1)
# (u'dogru.dial.eunet.ch', 16)
# (u'dolphin-40.netrunner.net', 11)
# (u'domitian.cs.qub.ac.uk', 21)
# (u'dooziew0.montgomery.va.us', 10)
# (u'dos98.c-cafstr.siu.edu', 15)
# (u'dove.ksc.nasa.gov', 9)
# (u'dp2-015.ppp.iglou.com', 4)
# (u'dpa2.network.com', 5)
# (u'dplsp.dp.utexas.edu', 2)
# (u'dppp00.netpoint.net', 11)
# (u'dppp33.buffnet.net', 28)
# (u'drac.medusa.es', 60)
# (u'draco.vr.net', 3)
# (u'dragnet.jpl.nasa.gov', 6)
# (u'dresden.bmc.com', 4)
# (u'drifter.earthlink.net', 4)
# (u'drjo002a089.embratel.net.br', 8)
# (u'drjo004a123.embratel.net.br', 11)
# (u'drjo004a126.embratel.net.br', 13)
# (u'drjo007a187.embratel.net.br', 5)
# (u'drjo009a216.embratel.net.br', 17)
# (u'drjo011a033.embratel.net.br', 2)
# (u'drjo013a073.embratel.net.br', 7)
# (u'drjo013a085.embratel.net.br', 4)
# (u'drjo014a089.embratel.net.br', 3)
# (u'drjo014a092.embratel.net.br', 9)
# (u'drjo014a100.embratel.net.br', 6)
# (u'drjo015a116.embratel.net.br', 2)
# (u'drjo016a125.embratel.net.br', 6)
# (u'drjo016a139.embratel.net.br', 11)
# (u'drjo022a241.embratel.net.br', 1)
# (u'drjo022a244.embratel.net.br', 8)
# (u'dsa_daniel.uqac.uquebec.ca', 6)
# (u'dseaman.iquest.com', 51)
# (u'dslak-remote.dmz.auckland.ac.nz', 3)
# (u'dslip17.cc.utas.edu.au', 5)
# (u'dtw-20.rust.net', 8)
# (u'du-19.du.ibase.org.br', 4)
# (u'du1-07.tcp.co.uk', 8)
# (u'du5-ts1.lascruces.com', 18)
# (u'du50.modems.netaxis.com', 4)
# (u'du81-17.cc.iastate.edu', 46)
# (u'duckling.omsi.edu', 21)
# (u'dungeon.microserve.net', 22)
# (u'durin.bitmailer.com', 6)
# (u'duteinz.et.tudelft.nl', 5)
# (u'dvp.cs.toronto.edu', 4)
# (u'dylras1.dylex.com', 32)
# (u'dyn03.fastnet.co.uk', 2)
# (u'dyn111.dialin.rad.net.id', 1)
# (u'dyna149.magmacom.com', 12)
# (u'dynam18.nbnet.nb.ca', 4)
# (u'e101.unife.it', 4)
# (u'e1c204.can.enternet.com.au', 4)
# (u'e659229.boeing.com', 52)
# (u'e6s111.syd.enternet.com.au', 8)
# (u'eagle23.sasknet.sk.ca', 6)
# (u'earth.planet.net', 1)
# (u'east.ge.com', 18)
# (u'eb1ppp12.globalcom.net', 49)
# (u'eb1ppp16.globalcom.net', 44)
# (u'eb1ppp19.globalcom.net', 2)
# (u'eb1ppp5.globalcom.net', 40)
# (u'eberle.nadn.navy.mil', 2)
# (u'ecb2.res.lehigh.edu', 11)
# (u'eckert.info.polymtl.ca', 1)
# (u'ecn1417058.gsfc.nasa.gov', 11)
# (u'ecs2.biddeford.com', 14)
# (u'edams.ksc.nasa.gov', 191)
# (u'edber.tor.hookup.net', 8)
# (u'edgar.cs.washington.edu', 1)
# (u'edmr7.ccinet.ab.ca', 20)
# (u'edsokc04.tinker.af.mil', 8)
# (u'eepc51.ee.surrey.ac.uk', 16)
# (u'ehdup-a-3.rmt.net.pitt.edu', 9)
# (u'ehdup-g-12.rmt.net.pitt.edu', 3)
# (u'eic88.fiu.edu', 4)
# (u'einstein.ph.ed.ac.uk', 1)
# (u'einstein.technet.sg', 1)
# (u'el0269.lib.okstate.edu', 3)
# (u'elaine19.stanford.edu', 5)
# (u'elec.dap.csiro.au', 2)
# (u'elsahp6.physik.uni-bonn.de', 1)
# (u'elsegundo-ppp16.interworld.net', 30)
# (u'emerald.tufts.edu', 4)
# (u'enadpc39.cc.purdue.edu', 12)
# (u'enc0201.deltanet.com', 11)
# (u'enc0214.deltanet.com', 8)
# (u'enceladus.pt.hk-r.se', 11)
# (u'endbe.laurel.us.net', 9)
# (u'endeavor.fujitsu.co.jp', 10)
# (u'eng-006.afit.af.mil', 8)
# (u'engl20.nmsu.edu', 4)
# (u'eno.ho.bom.gov.au', 25)
# (u'enterprise.america.com', 2)
# (u'envdemo.zynet.co.uk', 4)
# (u'epsongw3.epson.co.jp', 3)
# (u'erc.jscc.cc.tn.us', 3)
# (u'erebus.ibmoto.com', 2)
# (u'ergon.rocketsoft.com', 6)
# (u'erigate.ericsson.se', 14)
# (u'eros.ccs.deakin.edu.au', 10)
# (u'esf.sunspot.noao.edu', 20)
# (u'eskimo.com', 1)
# (u'esperance.extern.ucsd.edu', 23)
# (u'ess_0049.admin.calpoly.edu', 42)
# (u'euas65.eua.ericsson.se', 4)
# (u'eul175.metronet.com', 19)
# (u'eureka.ballarat.edu.au', 2)
# (u'evalserv.demon.co.uk', 11)
# (u'everex2.starpaging.com', 12)
# (u'ew114.eng.ornl.gov', 6)
# (u'ewi.ewi.org', 3)
# (u'expos.qualcomm.com', 5)
# (u'extra.ucc.su.oz.au', 1)
# (u'ez1d-1r.eznet.bull.it', 11)
# (u'ez26.superlink.net', 21)
# (u'ezinfo.ethz.ch', 2)
# (u'faith.waikato.ac.nz', 4)
# (u'far-p9-4.urh.uiuc.edu', 4)
# (u'fastlane.net', 10)
# (u'fat-0.cybergate.com', 5)
# (u'fat-1.cybergate.com', 5)
# (u'fauvx2.acc.fau.edu', 1)
# (u'fcjake2.ncifcrf.gov', 12)
# (u'fclcorp.co.nz', 26)
# (u'fdj.score.com', 81)
# (u'fermi.tellus.vallentuna.se', 8)
# (u'fesmith.tiac.net', 4)
# (u'fhbsun02.fh-brandenburg.de', 43)
# (u'fich.unl.edu.ar', 4)
# (u'finarfin.bitmailer.com', 3)
# (u'findlay-ibmpc19.cac-labs.psu.edu', 16)
# (u'firewall.deere.com', 6)
# (u'fis06.unimo.it', 7)
# (u'fixer.sega.co.jp', 4)
# (u'fjlmac.larc.nasa.gov', 22)
# (u'fkirchman.gsfc.nasa.gov', 27)
# (u'flashes.jpl.nasa.gov', 6)
# (u'fmarshall.gsfc.nasa.gov', 4)
# (u'fmv.kawashin.co.jp', 6)
# (u'fmy17.supernet.net', 8)
# (u'fnts3-3.firn.edu', 14)
# (u'foltzto.iquest.com', 17)
# (u'fop0.dev.esoc.esa.de', 3)
# (u'forth.cst.hw.ac.uk', 1)
# (u'fractal.mech.tohoku.ac.jp', 3)
# (u'franklin.chem.duke.edu', 28)
# (u'freakout.lerc.nasa.gov', 5)
# (u'fred.cs.flinders.edu.au', 3)
# (u'freenet.msp.mn.us', 3)
# (u'freenet.vcu.edu', 1)
# (u'freeway.issy.cnet.fr', 5)
# (u'freya.fokus.gmd.de', 3)
# (u'frogfoot.dsto.defence.gov.au', 1)
# (u'frontier.unl.edu', 1)
# (u'ftp-relay.mv.us.adobe.com', 1)
# (u'ftp.cc.u-tokai.ac.jp', 12)
# (u'ftp.gmesc.com', 7)
# (u'ftp.kornet.nm.kr', 12)
# (u'ftp.mel.aone.net.au', 15)
# (u'funnel01.btx.dtag.de', 57)
# (u'fw.idc.co.jp', 4)
# (u'fwt8.infotech.tu-chemnitz.de', 8)
# (u'fynn.demon.co.uk', 4)
# (u'g0dqw.demon.co.uk', 16)
# (u'g14.ppp.urich.edu', 12)
# (u'gabbara.earthlink.net', 1)
# (u'gaboon.nai.net', 1)
# (u'gacl-0342fe.uark.edu', 34)
# (u'gagnon.cebaf.gov', 8)
# (u'galactica.galactica.it', 2)
# (u'galileo.enc.org', 1)
# (u'ganca207.vol.it', 2)
# (u'gandalf.rutgers.edu', 1)
# (u'ganymedes.pt.hk-r.se', 8)
# (u'garfish.jcu.edu.au', 2)
# (u'garymak.pr.mcs.net', 63)
# (u'gate.kajima.co.jp', 9)
# (u'gate.maloka.waw.pl', 20)
# (u'gate.shell.nl', 10)
# (u'gate0.ftech.net', 19)
# (u'gate3.fmr.com', 7)
# (u'gatekeeper.admin.ch', 6)
# (u'gatekeeper.alcatel.be', 13)
# (u'gatekeeper.cca.rockwell.com', 29)
# (u'gatekeeper.cpe.com.au', 9)
# (u'gatekeeper.icl.co.uk', 6)
# (u'gatekeeper.millipore.com', 1)
# (u'gatekeeper.minedu.govt.nz', 17)
# (u'gatekeeper.mitre.org', 25)
# (u'gatekeeper.sciatl.com', 29)
# (u'gatekeeper.us.oracle.com', 36)
# (u'gateway.deere.com', 12)
# (u'gateway.ppg.com', 4)
# (u'gateway.synoptics.com', 4)
# (u'gatewayx.lsis.loral.com', 14)
# (u'gatordyn37.ac.hillsdale.edu', 1)
# (u'gatsby.hip.berkeley.edu', 11)
# (u'gauss.math.fsu.edu', 3)
# (u'gayle-gaston.tenet.edu', 16)
# (u'gbol0.dct.com', 1)
# (u'gbol19.dct.com', 2)
# (u'gccdup-a-5.rmt.net.pitt.edu', 10)
# (u'gdead.njcc.com', 16)
# (u'generic.augustana.edu', 1)
# (u'genie.com', 2)
# (u'genius.tisl.soft.net', 1)
# (u'gensym.com', 11)
# (u'geoviz5.eng.iastate.edu', 6)
# (u'gep.pr.mcs.net', 4)
# (u'geronimo.dialup.access.net', 5)
# (u'giaeb.cc.monash.edu.au', 5)
# (u'gin.obspm.fr', 2)
# (u'giovannoni-lab.tamu.edu', 10)
# (u'gk-west.usps.gov', 25)
# (u'gknobel.skygames.com', 3)
# (u'gkremer.slip.onu.edu', 3)
# (u'glab-08.hials.no', 4)
# (u'glab-10.hials.no', 2)
# (u'glade.weh.andrew.cmu.edu', 3)
# (u'glader.radek.slu.se', 1)
# (u'gladstone.uoregon.edu', 1)
# (u'glass.iexpress.com', 4)
# (u'global.california.com', 4)
# (u'gmaenner.kimcl.akh-wien.ac.at', 3)
# (u'gmgate.vircom.com', 18)
# (u'gmlink.gmeds.com', 6)
# (u'gn2.getnet.com', 19)
# (u'godai.hq.nasda.go.jp', 19)
# (u'gold.t-informatik.ba-stuttgart.de', 17)
# (u'golde.uni-miskolc.hu', 1)
# (u'goliath.apana.org.au', 1)
# (u'gollum.cm.deakin.edu.au', 47)
# (u'gordillo.dh.i-2000.com', 9)
# (u'gp-pm1-015.cdsnet.net', 1)
# (u'gq.sei.cmu.edu', 1)
# (u'gr02.ppp.alliance.net', 4)
# (u'grail1109.nando.net', 14)
# ...
# (u'sinsen.oslonett.no', 9)
# (u'sinter.feut.utoronto.ca', 1)
# (u'sirius.pixi.com', 10)
# (u'sirius_a.ee.htl-bw.ch', 87)
# (u'sirocco.geol.utas.edu.au', 11)
# (u'sisa0066.inbel.sara.nl', 2)
# (u'sjh.oag.state.tx.us', 8)
# (u'skeria.skelleftea.se', 5)
# (u'skibum.lerc.nasa.gov', 21)
# (u'skuzzy.demon.co.uk', 5)
# (u'sl-000.sl.cybercomm.net', 14)
# (u'slbri1p09.ozemail.com.au', 6)
# (u'slc003.rockymt.net', 12)
# (u'slc53.xmission.com', 9)
# (u'sle4.asb.com', 4)
# (u'slides-ben.princeton.edu', 11)
# (u'slip-199-186-126-58.nmcnj.ico.att.net', 1)
# (u'slip-2-13.afit.af.mil', 14)
# (u'slip-22-14.ots.utexas.edu', 1)
# (u'slip-3-0.shore.net', 5)
# (u'slip-3-28.shore.net', 8)
# (u'slip-36-12.ots.utexas.edu', 3)
# (u'slip-5-12.shore.net', 10)
# (u'slip1.inthenet.com', 10)
# (u'slip1.muscanet.com', 12)
# (u'slip1.vvm.com', 10)
# (u'slip1.yab.com', 4)
# (u'slip11.cs.fsu.edu', 6)
# (u'slip12.hslc.org', 6)
# (u'slip124x.slip.colostate.edu', 8)
# (u'slip131.qlink.queensu.ca', 9)
# (u'slip136-133.pt.uk.ibm.net', 15)
# (u'slip136-196.pt.uk.ibm.net', 10)
# (u'slip136-197.pt.uk.ibm.net', 2)
# (u'slip136-67.pt.uk.ibm.net', 2)
# (u'slip137-2.pt.uk.ibm.net', 21)
# (u'slip141.sirius.com', 13)
# (u'slip145-210.ut.nl.ibm.net', 1)
# (u'slip151.hk.super.net', 6)
# (u'slip152-208.on.ca.ibm.net', 8)
# (u'slip152-224.on.ca.ibm.net', 17)
# (u'slip164-132.on.ca.ibm.net', 19)
# (u'slip168-195.sy.au.ibm.net', 6)
# (u'slip172.hk.super.net', 9)
# (u'slip18-130.ga.us.ibm.net', 9)
# (u'slip20.cei.net', 10)
# (u'slip21.cei.net', 8)
# (u'slip211.hk.super.net', 1)
# (u'slip216.hk.super.net', 23)
# (u'slip231.hk.super.net', 1)
# (u'slip232.netaxis.com', 11)
# (u'slip3-148.fl.us.ibm.net', 8)
# (u'slip3.vvm.com', 1)
# (u'slip37-149.il.us.ibm.net', 18)
# (u'slip37-228-74.ibm.net', 39)
# (u'slip37-247-90.ibm.net', 4)
# (u'slip37-249-74.ibm.net', 7)
# (u'slip37-76.il.us.ibm.net', 9)
# (u'slip39.slip.anl.gov', 1)
# (u'slip4.island.net', 43)
# (u'slip40.beaver.pgh.net', 12)
# (u'slip4057.sirius.com', 3)
# (u'slip4060.sirius.com', 1)
# (u'slip41.cc.flinders.edu.au', 4)
# (u'slip49-83.ca.us.ibm.net', 11)
# (u'slip5.sinet.it', 2)
# (u'slip65.indirect.com', 1)
# (u'slip7.vvm.com', 14)
# (u'slip7.xroads.com', 12)
# (u'slip8-165.beta.delphi.com', 2)
# (u'slip8-178.beta.delphi.com', 4)
# (u'slip8.slip.stolaf.edu', 6)
# (u'slip8135.rmii.com', 15)
# (u'slip9.island.net', 10)
# (u'slip97.slip.upei.ca', 6)
# (u'sliphost43.ade.state.az.us', 9)
# (u'slipper124219.iaccess.za', 6)
# (u'slipper3b.xtalwind.net', 4)
# (u'sloth.njk.co.jp', 5)
# (u'slper1p09.ozemail.com.au', 3)
# (u'sls1.asb.com', 1)
# (u'sls11.asb.com', 10)
# (u'slsyd1p41.ozemail.com.au', 3)
# (u'slsyd2p14.ozemail.com.au', 10)
# (u'slsyd2p17.ozemail.com.au', 7)
# (u'slsyd3p32.ozemail.com.au', 10)
# (u'slsyd4p23.ozemail.com.au', 8)
# (u'slurpee.us.dell.com', 15)
# (u'slwol1p14.ozemail.com.au', 1)
# (u'sm10111.pc.nus.sg', 3)
# (u'sm10112.pc.nus.sg', 2)
# (u'sm20026.pc.nus.sg', 2)
# (u'sm216.weizmann.ac.il', 1)
# (u'smga-a-inst-pc.bu.edu', 3)
# (u'smithers.cnac.gov', 6)
# (u'smokey.arnold.af.mil', 1)
# (u'sms94.bellcore.com', 10)
# (u'smshub.ksc.nasa.gov', 4)
# (u'smuc.demon.co.uk', 8)
# (u'sn-bhaskar.jsc.nasa.gov', 1)
# (u'sn-gastineau.jsc.nasa.gov', 6)
# (u'sn-scharf.jsc.nasa.gov', 3)
# (u'snoopy.jpl.nasa.gov', 19)
# (u'snoopy.tblc.lib.fl.us', 28)
# (u'so.scsnet.com', 5)
# (u'sobenet.winnet.net', 9)
# (u'sol.ccs.deakin.edu.au', 2)
# (u'sol.racsa.co.cr', 8)
# (u'sol.zynet.co.uk', 4)
# (u'solair1.inter.nl.net', 4)
# (u'solar.ple.af.mil', 14)
# (u'soliton.physics.arizona.edu', 3)
# (u'sonic.net', 30)
# (u'sophocles.algonet.se', 18)
# (u'source.vip.best.com', 27)
# (u'sousun4.phys.soton.ac.uk', 4)
# (u'sp.pb.com', 1)
# (u'sp055.cern.ch', 6)
# (u'sp069.cern.ch', 9)
# (u'spacelink.msfc.nasa.gov', 11)
# (u'spaceman.tiac.net', 9)
# (u'sparc10_work4.utsi.edu', 16)
# (u'spartan.gsfc.nasa.gov', 30)
# (u'spider.tbe.com', 1)
# (u'spitfire.systranmt.com', 23)
# (u'splou.earthlink.net', 9)
# (u'sprite30.azstarnet.com', 13)
# (u'sps133.lds.loral.com', 2)
# (u'spui-09.denhaag.dataweb.nl', 13)
# (u'spui-24.denhaag.dataweb.nl', 10)
# (u'spynx.demon.co.uk', 5)
# (u'squid.larc.nasa.gov', 22)
# (u'srl.ford.com', 13)
# (u'srq17.netline.net', 19)
# (u'srv1.freenet.calgary.ab.ca', 4)
# (u'ssbuv.gsfc.nasa.gov', 24)
# (u'sshestok.mis.semi.harris.com', 8)
# (u'ssigw.ssi.co.jp', 12)
# (u'sslip-02.mother.com', 5)
# (u'ssrmoef.lsis.loral.com', 13)
# (u'stand-region3.aquarel.fr', 1)
# (u'star083152.galstar.com', 10)
# (u'star41.hkstar.com', 2)
# (u'star50.tiac.net', 6)
# (u'starbright.ksc.nasa.gov', 12)
# (u'station-01.skylab.csus.edu', 5)
# (u'stemmons39.onramp.net', 10)
# (u'stevew.cais.com', 7)
# (u'stonewire.com', 5)
# (u'stoo.demon.co.uk', 1)
# (u'store.phys.unsw.edu.au', 4)
# (u'storm.cencom.net', 4)
# (u'stortek1.stortek.com', 8)
# (u'stratacom.strata.com', 4)
# (u'strauss.udel.edu', 19)
# (u'stub31pc.stub.uni-frankfurt.de', 1)
# (u'subo7.earthlink.net', 16)
# (u'sugar.h.belgacom.be', 18)
# (u'sun1.bham.ac.uk', 1)
# (u'sun579.rz.ruhr-uni-bochum.de', 1)
# (u'sun7.lrz-muenchen.de', 21)
# (u'sunflower.np.ac.sg', 2)
# (u'sunh35.lisle.tellabs.com', 12)
# (u'sunspot.dtw.etn.com', 12)
# (u'sununx.iscs.nus.sg', 3)
# (u'sunw11.aut.alcatel.at', 6)
# (u'superior.ccs.carleton.ca', 4)
# (u'surveyor.jf.intel.com', 9)
# (u'sute.sltd6.com', 14)
# (u'sutr.novalink.com', 1)
# (u'svcrppp31.epix.net', 4)
# (u'svcrppp32.epix.net', 4)
# (u'sw25-125.iol.it', 18)
# (u'sw25-162.iol.it', 21)
# (u'sw25-167.iol.it', 3)
# (u'swift.embl-heidelberg.de', 1)
# (u'syd-du1-4.opennet.net.au', 11)
# (u'sydney-ts-22.nstn.ca', 32)
# (u'sydney2.world.net', 1)
# (u'symbol.com', 3)
# (u'synapse-07.mindport.net', 14)
# (u'syru47-034.syr.edu', 3)
# (u'syru63-146.syr.edu', 1)
# (u'sys401.lerc.nasa.gov', 15)
# (u't086.is.co.za', 8)
# (u'tactical.ppp.america.com', 6)
# (u'tae1.anet.cz', 14)
# (u'tafel10a.hq1.tafensw.edu.au', 7)
# (u'tait34.tfdl.agro.nl', 8)
# (u'tama.ie.akita-u.ac.jp', 6)
# (u'tampico.usc.edu', 3)
# (u'tappjg.renc.igs.net', 12)
# (u'tarazan.tau.ac.il', 7)
# (u'tbakonyi.interlog.com', 6)
# (u'tboland.cais.com', 3)
# (u'tbrady.jsc.nasa.gov', 8)
# (u'tc1_5.teclink.net', 8)
# (u'tcav.dialup.inch.com', 9)
# (u'tcole.chinalake.navy.mil', 5)
# (u'tcp_ip.ntsc.navy.mil', 2)
# (u'tdmobil.dk', 6)
# (u'te.nada.kth.se', 76)
# (u'tedenac.univ-montp2.fr', 27)
# (u'teebo.roses.rockwell.com', 1)
# (u'teha.pdial.interpath.net', 3)
# (u'teijo.clinet.fi', 12)
# (u'teleport21.shani.co.il', 6)
# (u'teleport26.shani.co.il', 1)
# (u'telly.tc.cornell.edu', 19)
# (u'ten-nash.ten.k12.tn.us', 6)
# (u'tepscogw.tepsco.co.jp', 10)
# (u'term1-3.sb.west.net', 13)
# (u'term1-4.vta.west.net', 6)
# (u'term1-6.sb.west.net', 8)
# (u'terra.cpqd.br', 6)
# (u'test178.larc.nasa.gov', 8)
# (u'tethys-le1.otol.fi', 13)
# (u'th.behavnet.com', 3)
# (u'thalia.demon.co.uk', 15)
# (u'theoris.rz.uni-konstanz.de', 1)
# (u'theory.caltech.edu', 6)
# (u'thibeaultr.nl.nuwc.navy.mil', 13)
# (u'thimble-d226.sierra.net', 3)
# (u'throgsneck.delphi.com', 4)
# (u'tia1.eskimo.com', 11)
# (u'tibalt.supernet.ab.ca', 4)
# (u'tiber.gsfc.nasa.gov', 22)
# (u'tiger.premier.net', 5)
# (u'tiger2.ocs.lsu.edu', 22)
# (u'timmerg.mayo.edu', 5)
# (u'timms.mindspring.com', 14)
# (u'titan', 4)
# (u'titan.rdc.puc-rio.br', 12)
# (u'tjdean.forestry.lsu.edu', 21)
# (u'tka.com', 2)
# (u'tkindy10.tkw.co.at', 1)
# (u'tmerrit_pc.micron.com', 1)
# (u'tmp.inet.it', 7)
# (u'toky1ds06.tk.mesh.ad.jp', 26)
# (u'toky1ds08.tk.mesh.ad.jp', 10)
# (u'tokyo117.infosphere.or.jp', 9)
# (u'tokyo314.infosphere.or.jp', 37)
# (u'tomato.pyrotechnics.com', 9)
# (u'tongkey.kol.co.kr', 1)
# (u'torney.demon.co.uk', 2)
# (u'toronto.cbc.ca', 8)
# (u'tosca.harvard.edu', 3)
# (u'tott.kih.no', 5)
# (u'tpafl2-21.gate.net', 8)
# (u'tpo-ljs-pc.jhuapl.edu', 17)
# (u'tpts1.seed.net.tw', 7)
# (u'trc2.dfrc.nasa.gov', 7)
# (u'treebeard.bbso.caltech.edu', 3)
# (u'triskila.fmi.fi', 3)
# (u'troms1.or.uninett.no', 12)
# (u'troms2.or.uninett.no', 10)
# (u'trothermel.eng.gulfaero.com', 39)
# (u'trujill.larc.nasa.gov', 11)
# (u'trusty.lmsc.lockheed.com', 47)
# (u'ts-20.marin.k12.ca.us', 15)
# (u'ts-a12-1-6.ucc.su.oz.au', 4)
# (u'ts-h08-15-26.ucc.su.oz.au', 37)
# (u'ts00-ind-24.iquest.net', 18)
# (u'ts04-ind-13.iquest.net', 12)
# (u'ts04-ind-14.iquest.net', 2)
# (u'ts1-012.jaxnet.com', 12)
# (u'ts1-11.icis.on.ca', 7)
# (u'ts1-17.net.netbistro.com', 3)
# (u'ts1-and-11.iquest.net', 71)
# (u'ts1-and-17.iquest.net', 10)
# (u'ts1-s2.adeptcom.com', 11)
# (u'ts131214.liv.ac.uk', 1)
# (u'ts2-015.jaxnet.com', 10)
# (u'ts2-021.jaxnet.com', 16)
# (u'ts2-026.jaxnet.com', 8)
# (u'ts2-8.everyday.se', 1)
# (u'ts2-9.everyday.se', 6)
# (u'ts2-p16.dialup.iway.fr', 10)
# (u'ts2-p29.dialup.iway.fr', 1)
# (u'ts3-74.slip.uwo.ca', 8)
# (u'ts3-77.slip.uwo.ca', 7)
# (u'ts3-9.westwood.ts.ucla.edu', 1)
# (u'ts5_port28.planet.eon.net', 2)
# (u'ts6-04.inforamp.net', 16)
# (u'ts7-02.inforamp.net', 6)
# (u'ts7-08.inforamp.net', 5)
# (u'ts700-701.globe.com.ph', 6)
# (u'ts9-09.inforamp.net', 3)
# (u'ts900-1029.singnet.com.sg', 38)
# (u'ts900-1601.singnet.com.sg', 6)
# (u'ts900-1614.singnet.com.sg', 3)
# (u'ts900-406.singnet.com.sg', 9)
# (u'tsa-yyc-04.tcel.com', 3)
# (u'tsd02d.netcom.com', 8)
# (u'tsip56.ionet.net', 8)
# (u'tstanley.ssc.nasa.gov', 26)
# (u'ttacs1.ttu.edu', 3)
# (u'ttiarl130.tamu.edu', 8)
# (u'tty07.com1.oknet.com', 8)
# (u'tty09.com2.houston.net', 24)
# (u'tty10n.mdn.com', 8)
# (u'tty11.com2.oknet.com', 11)
# (u'tty17-07.swipnet.se', 6)
# (u'tty18-04.swipnet.se', 8)
# (u'tty18-23.swipnet.se', 30)
# (u'tty19.com2.houston.net', 3)
# (u'tty22.com3.houston.net', 16)
# (u'ttyb3.shasta.com', 12)
# (u'ttyb5.shasta.com', 9)
# (u'ttyc2.emi.net', 8)
# (u'ttyca.emi.net', 19)
# (u'ttyco.emi.net', 8)
# (u'ttye7.emi.net', 5)
# (u'ttyeb.emi.net', 5)
# (u'ttyr2.tyrell.net', 21)
# (u'ttyx5.tyrell.net', 9)
# (u'tulips.lib.tufts.edu', 1)
# (u'turtle.ee.queensu.ca', 24)
# (u'tweeter.outland.ileaf.com', 22)
# (u'twigg.msfc.nasa.gov', 5)
# (u'twin06.magiclink.com', 17)
# (u'twitch.io.org', 8)
# (u'twolves.asa.utk.edu', 2)
# (u'tyo0069.bekkoame.or.jp', 2)
# (u'tyo0084.bekkoame.or.jp', 14)
# (u'tyo0087.bekkoame.or.jp', 13)
# (u'tyo0129.bekkoame.or.jp', 6)
# (u'tyo1.gate.nec.co.jp', 3)
# (u'typhoon.coedu.usf.edu', 2)
# (u'u810301.cheng.ab.nthu.edu.tw', 24)
# (u'ubmac188.uio.no', 31)
# (u'ubvmsa.cc.buffalo.edu', 1)
# (u'ucen29.flint.umich.edu', 2)
# (u'ucqais.cba.uc.edu', 12)
# (u'ufark10.chem.ufl.edu', 31)
# (u'uiatma.atmos.uiuc.edu', 2)
# (u'uiu2.gsfc.nasa.gov', 16)
# (u'uiu9.gsfc.nasa.gov', 9)
# (u'ujinetfw.uniden.co.jp', 6)
# (u'ukanaix.cc.ukans.edu', 2)
# (u'ukcc.uky.edu', 2)
# (u'ukon.shirai.info.waseda.ac.jp', 4)
# (u'ul0106-d1.ulib.iupui.edu', 12)
# (u'ul0106-p.ulib.iupui.edu', 18)
# (u'uncle_albert.ksc.nasa.gov', 6)
# (u'unknown.ascend.com', 11)
# (u'unknown_184.cadpoint.se', 1)
# (u'uoeh1.uoeh.ufz.de', 5)
# (u'up2-cs3p8.und.nodak.edu', 6)
# (u'ups30.cit.cornell.edu', 63)
# (u'ups36.cit.cornell.edu', 8)
# (u'user-5-40.dial.inet.fi', 2)
# (u'user-port7.lightspeed.net', 21)
# (u'user.8.64.dcccd.edu', 4)
# (u'user03.bnn-net.or.jp', 1)
# (u'user29.bnn-net.or.jp', 6)
# (u'users.tvol.it', 9)
# (u'usmac13.uchicago.edu', 13)
# (u'usr12-dialup12.atlanta.mci.net', 36)
# (u'usr16-dialup15.atlanta.mci.net', 5)
# (u'usr16-dialup32.atlanta.mci.net', 34)
# (u'usr19-dialup49.atlanta.mci.net', 3)
# (u'usr20-dialup20.atlanta.mci.net', 29)
# (u'usr8-dialup34.atlanta.mci.net', 4)
# (u'usstyx.glaxo.com', 5)
# (u'uuneo.neosoft.com', 17)
# (u'uwindsor.ca', 1)
# (u'uwoppa.connect.com.au', 1)
# (u'uzd3.guj.de', 10)
# (u'v2gbtdbs.lsis.loral.com', 11)
# (u'va3jdh.interlog.com', 12)
# (u'vacuum.magna.com.au', 6)
# (u'vagrant.vf.mmc.com', 41)
# (u'van03080.direct.ca', 8)
# (u'van03082.direct.ca', 8)
# (u'van04112.direct.ca', 2)
# (u'van04117.direct.ca', 2)
# (u'van05144.direct.ca', 11)
# (u'van06180.direct.ca', 8)
# (u'van08230.direct.ca', 2)
# (u'van10278.direct.ca', 8)
# (u'van13380.direct.ca', 4)
# (u'van13383.direct.ca', 11)
# (u'van14417.direct.ca', 14)
# (u'van14419.direct.ca', 1)
# (u'van15421.direct.ca', 12)
# (u'vasquez.library.ucg.ie', 11)
# (u'vax1.kcpl.lib.mo.us', 2)
# (u'vaxa.clarion.edu', 9)
# (u'vdggstudent.nac.ac.za', 48)
# (u'vdwalta.sabc.co.za', 10)
# (u'vega.info.isbiel.ch', 7)
# (u'venus.josai.ac.jp', 11)
# (u'vertex143.worldweb.com', 6)
# (u'vessna.arc.nasa.gov', 3)
# (u'vewer.sso.az.honeywell.com', 4)
# (u'vi-e2.hevanet.com', 3)
# (u'vi-ppp01.hevanet.com', 17)
# (u'via-annex4-15.cl.msu.edu', 7)
# (u'vicsd210.dial.gov.bc.ca', 8)
# (u'vifa1.freenet.victoria.bc.ca', 1)
# (u'villcbg.village.ca', 1)
# (u'violett-08.nada.kth.se', 2)
# (u'vivaldi.imed.missouri.edu', 11)
# (u'vivid.autometric.com', 6)
# (u'vm.hacc.edu', 7)
# (u'vm1.si.usherb.ca', 2)
# (u'volrm25.vol.it', 14)
# (u'volrm48.vol.it', 5)
# (u'volto16.vol.it', 4)
# (u'voltv12.vol.it', 13)
# (u'volvr5.vol.it', 2)
# (u'vva2-ts7.databank.net', 6)
# (u'vxa.ocis.uncwil.edu', 4)
# (u'vyger903.nando.net', 9)
# (u'vyger906.nando.net', 11)
# (u'w8sdz.coast.net', 8)
# (u'walkingstick.execpc.com', 31)
# (u'wall.expressen.se', 13)
# (u'wallacepc.gsfc.nasa.gov', 4)
# (u'waller-asy-2.rutgers.edu', 10)
# (u'waller-asy-24.rutgers.edu', 6)
# (u'warped.arc.nasa.gov', 6)
# (u'warum.uni-mannheim.de', 9)
# (u'water.syntex.com', 1)
# (u'waters-gw.starway.net.au', 20)
# (u'watt.lab.eese.bee.qut.edu.au', 18)
# (u'watt.seas.virginia.edu', 1)
# (u'wawa.geo.umass.edu', 17)
# (u'web.kyoto-inet.or.jp', 35)
# (u'webe.hooked.net', 9)
# (u'webgate1.mot.com', 30)
# (u'webster.ctron.com', 32)
# (u'webster.stjohns.k12.fl.us', 2)
# (u'westchester10.voicenet.com', 9)
# (u'westmont.mt.net', 14)
# (u'wgamac05.csd.unsw.edu.au', 11)
# (u'wgreer.cirrus.co.riverside.ca.us', 5)
# (u'whisper.com', 5)
# (u'whopkins.sso.az.honeywell.com', 157)
# (u'wiener.fiz.huji.ac.il', 2)
# (u'wilbur.charweb.org', 4)
# (u'wilma.netinfo.com.au', 9)
# (u'winnie.fit.edu', 2)
# (u'winnie.freenet.mb.ca', 12)
# (u'winnt1.tyler.net', 6)
# (u'winslo.ohio.gov', 1)
# (u'wjones.gsfc.nasa.gov', 3)
# (u'wok-6.memphis.edu', 5)
# (u'woodlawn.uchicago.edu', 2)
# (u'wordup.com', 1)
# (u'worf.ksc.nasa.gov', 6)
# (u'worf.qntm.com', 1)
# (u'world.std.com', 9)
# (u'wpb-106.magg.net', 6)
# (u'wpb-111.magg.net', 10)
# (u'wpb-114.magg.net', 13)
# (u'wpb-118.magg.net', 7)
# (u'wpo.telstra.com.au', 15)
# (u'wrtv27.wrtv.com', 11)
# (u'ws2.demo.uni-linz.ac.at', 6)
# (u'ws214.vironix.co.za', 21)
# (u'ws281.uncc.edu', 8)
# (u'ws5.demo.uni-linz.ac.at', 9)
# (u'wsgr.kyokyo-u.ac.jp', 10)
# (u'wstabnow.gsfc.nasa.gov', 16)
# (u'wtaskr2.ccinet.ab.ca', 19)
# (u'www-a1.proxy.aol.com', 238)
# (u'www-a2.proxy.aol.com', 139)
# (u'www-b1.proxy.aol.com', 118)
# (u'www-b2.proxy.aol.com', 112)
# (u'www-b3.proxy.aol.com', 40)
# (u'www-b4.proxy.aol.com', 97)
# (u'www-b5.proxy.aol.com', 184)
# (u'www-b6.proxy.aol.com', 151)
# (u'www-c1.proxy.aol.com', 109)
# (u'www-c2.proxy.aol.com', 81)
# (u'www-c3.proxy.aol.com', 149)
# (u'www-c4.proxy.aol.com', 95)
# (u'www-c5.proxy.aol.com', 158)
# (u'www-c6.proxy.aol.com', 150)
# (u'www-c8.proxy.aol.com', 124)
# (u'www-c9.proxy.aol.com', 142)
# (u'www-d1.proxy.aol.com', 131)
# (u'www-d2.proxy.aol.com', 105)
# (u'www-d3.proxy.aol.com', 95)
# (u'www-d4.proxy.aol.com', 76)
# (u'www-e1.proxy.aol.com', 7)
# (u'www-e1b.gnn.com', 24)
# (u'www-e1e.gnn.com', 3)
# (u'www-e1f.gnn.com', 22)
# (u'www-e2.proxy.aol.com', 4)
# (u'www-e3.proxy.aol.com', 6)
# (u'www-e4.proxy.aol.com', 7)
# (u'www-e5.proxy.aol.com', 7)
# (u'www-e6.proxy.aol.com', 5)
# (u'www-e8.proxy.aol.com', 3)
# (u'www-e9.proxy.aol.com', 2)
# (u'www-ea.proxy.aol.com', 170)
# (u'www-proxy.crl.research.digital.com', 64)
# (u'www-relay.pa-x.dec.com', 27)
# (u'www.austria.eu.net', 12)
# (u'www.cc.kagoshima-u.ac.jp', 12)
# (u'www.cedarnet.org', 1)
# (u'www.egg.or.jp', 1)
# (u'www.kagawa-u.ac.jp', 21)
# (u'www.mclink.it', 24)
# (u'www.mmjp.or.jp', 6)
# (u'www.neocom.ca', 27)
# (u'www.nthu.edu.tw', 41)
# (u'www.people.or.jp', 2)
# (u'www.rrz.uni-koeln.de', 1)
# (u'www.thyssen.com', 11)
# (u'www1.cern.ch', 7)
# (u'wwwproxy.sanders.com', 49)
# (u'wwwproxy2.ca.sandia.gov', 31)
# (u'wxs2-6.worldaccess.nl', 6)
# (u'wxs3-3.worldaccess.nl', 9)
# (u'wxs4-3.worldaccess.nl', 7)
# (u'wxs5-3.worldaccess.nl', 12)
# (u'wyndmoor1-31.slip.netaxs.com', 8)
# (u'wyndmoor1-43.slip.netaxs.com', 8)
# (u'wynns-mac.jhuapl.edu', 3)
# (u'xavier.dfrc.nasa.gov', 1)
# (u'xl27.hargray.com', 26)
# (u'xnmusc.mit.edu', 3)
# (u'xslip43.csrv.uidaho.edu', 14)
# (u'xyp44p6.ltec.net', 6)
# (u'xyplex1-2-3.intersource.com', 6)
# (u'xyplex3-5-2.ucs.indiana.edu', 22)
# (u'xyplex4-2-10.ucs.indiana.edu', 6)
# (u'xyplex4-2-3.ucs.indiana.edu', 6)
# (u'y1a.kootenay.net', 9)
# (u'yhm0065.bekkoame.or.jp', 6)
# (u'yhm0087.bekkoame.or.jp', 6)
# (u'ylw-ppp-19.cyberstore.ca', 16)
# (u'yoda.chilepac.net', 5)
# (u'yyj-ppp-2.cyberstore.ca', 12)
# (u'z021.euronet.nl', 20)
# (u'z106.euronet.nl', 4)
# (u'z117.euronet.nl', 10)
# (u'zaphod.infomagic.com', 5)
# (u'zeno.math.fsu.edu', 3)
# (u'zombie.agen.ufl.edu', 4)
# (u'zosok1179.unibe.ch', 3)
# (u'ztivax.zfe.siemens.de', 22)
# (u'ztm-129.dial.xs4all.nl', 6)
# (u'ztm-132.dial.xs4all.nl', 41)
# (u'zzjpolla.slip.cc.uq.oz.au', 2)
# (u'zzzzzzzz.mindspring.com', 5)
